# %% [markdown]
# # TLDR:
# * Model: Davit
# * PreProcessing: None
# * Data: DE features
# * Balancing Technique: Weighted random sampler
# * Labels: 0 (Neutral) , 1  Negative (Sad), 2  (Fear) , 3 Positive (Happy)
# * Test Accuracy:

# %%
# !pip install torcheeg==1.1.2 scipy==1.12.0 numpy==1.26.4 -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.5/214.5 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.5/231.5 kB 18.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.1/295.1 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.2/115.2 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 115.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.1 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/ff/ff/847841bacfbefc97a00036e0fce5a0f086b640756dc38caea5e1bb002655/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.2/750.2 kB 40.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.0 MB/s eta 0:00:00
#   Building wheel for torcheeg (setup.py) ... done
#   Building wheel for spectrum (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.12.0 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
# !git clone https://github.com/jiaowoguanren0615/DaViT-Pytorch DaViT
# Out:
# Cloning into 'DaViT'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 27 (delta 2), reused 18 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 30.26 KiB | 7.57 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler
from torcheeg import transforms
from torch.optim.lr_scheduler import CosineAnnealingLR, OneCycleLR
from torcheeg.datasets import SEEDIVFeatureDataset
from DaViT.models.davit import DaViT
from sklearn.model_selection import train_test_split
from torchvision.transforms import RandomErasing

import time
import os
import shutil
import random

import numpy as np

from torcheeg.datasets.constants import SEED_IV_CHANNEL_LOCATION_DICT

# --- THE MAIN SUBJECT LOOP ---
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
# 1. Setup Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
# used for logging
TRIAL_NUMBER = 32

# %%
USE_GPU = 1
BATCH_SIZE = 64
DROPOUT = 0.5
ATTN_DROPOUT = 0.5
LR = 0.0005
WEIGHT_DECAY = 2e-1
EPOCHS_COUNT = 250
patience = 50

# %%
def map_emotions(y):
    # Input y is 0, 1, 2, or 3
    if y == 0: 
        return 0  # Neutral remains 0
    elif y == 1 or y == 2: 
        return 1  # Sad (1) and Fear (2) become Negative (1)
    elif y == 3: 
        return 2  # Happy (3) becomes Positive (2)
    return 0

# %%
class RemapLabel:
    def __call__(self, y):
        return {"y": map_emotions(y)}

# %%
# io_path = "/home/omar/external/python/eeg-emotion/tmp_out/seed_iv_feautres"
# root_path = "./SEED-IV/eeg_feature_smooth/"

io_path="./tmp_out/seed_iv_features"
root_path = "/kaggle/input/seed-iv/eeg_feature_smooth"

# %%
# 3. Load Data
dataset = SEEDIVFeatureDataset(
    # io_path=io_path,
    root_path=root_path,
    feature=["de_LDS"],
    num_worker=4,
    offline_transform=transforms.Compose(
        [
            transforms.BaselineRemoval(),
            transforms.To2d(),
            transforms.ToTensor(),
        ]
    ),
    label_transform=transforms.Compose(
        [
            transforms.Select("emotion"),
            RemapLabel(),
        ]
    ),
    online_transform=transforms.Compose([transforms.MeanStdNormalize()]),
    io_mode="memory",
)
# Out:
# [2026-02-08 22:47:35] INFO (torcheeg/MainThread) 🔍 | Processing EEG data. Processed EEG data has been cached to .torcheeg/datasets_1770590855525_NbrnT.
# [2026-02-08 22:47:35] INFO (torcheeg/MainThread) ⏳ | Monitoring the detailed processing of a record for debugging. The processing of other records will only be reported in percentage to keep it clean.
# [PROCESS]:   0%|          | 0/45 [00:00<?, ?it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 0it [00:00, ?it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 1it [00:00,  4.48it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 714it [00:00, 2783.39it/s]
# [PROCESS]: 100%|██████████| 45/45 [00:10<00:00,  4.22it/s]

# %%
# 1. Get the metadata DataFrame
df = dataset.info

# 2. Count the segments for each emotion
# 0: Neutral, 1: Sad, 2: Fear, 3: Happy
counts = df["emotion"].value_counts().sort_index()
total = len(df)

print(f"Total Segments: {total}")
print("-" * 30)
print("Count per Emotion:")
print(counts)

print("-" * 30)
print("Percentage per Emotion:")
percentages = (counts / total) * 100
print(percentages.round(2))

# 3. Check for Imbalance
# If the difference between max and min is > 10%, we might need a WeightedSampler
max_pct = percentages.max()
min_pct = percentages.min()

if (max_pct - min_pct) > 10:
    print(f"\n⚠️ WARNING: Data is IMBALANCED (Diff: {max_pct - min_pct:.2f}%)")
    print("Consider using a WeightedRandomSampler.")
else:
    print(f"\n✅ Data is reasonably BALANCED (Diff: {max_pct - min_pct:.2f}%)")
# Out:
# Total Segments: 37575
# ------------------------------
# Count per Emotion:
# emotion
# 0    10170
# 1    10245
# 2     9225
# 3     7935
# Name: count, dtype: int64
# ------------------------------
# Percentage per Emotion:
# emotion
# 0    27.07
# 1    27.27
# 2    24.55
# 3    21.12
# Name: count, dtype: float64
#
# ✅ Data is reasonably BALANCED (Diff: 6.15%)

# %%
# 4. Check Data Shape & Setup Model
# We fetch one sample to determine input channels and dimensions
# (using the whole dataset for detection is fine as shape is consistent)
temp_loader = DataLoader(dataset, batch_size=1, shuffle=False)
temp_X, _ = next(iter(temp_loader))
input_channels = temp_X.shape[1]
print(f"Detected Input Shape: {temp_X.shape}")
print(f"Setting model in_chans to: {input_channels}")
# Out:
# Detected Input Shape: torch.Size([1, 1, 62, 5])
# Setting model in_chans to: 1

# %%
def DaViT_eeg(
    pretrained=False, pretrained_cfg=None, pretrained_cfg_overlay=None, **kwargs
):
    model_kwargs = dict(
        patch_size=4,
        in_chans=input_channels,
        window_size=3,
        # Restoring "Tiny" dimensions (User has VRAM headroom)
        # embed_dims=(96, 192, 384, 768),
        # num_heads=(3, 6, 12, 24),
        embed_dims=(64, 128, 256, 512),
        num_heads=(2, 4, 8, 16),
        depths=(1, 1, 1, 1),
        mlp_ratio=4.0,
        overlapped_patch=False,
        num_classes=kwargs.get("_num_classes", 4),
        drop_rate=kwargs.get("dropout", 0.5),
        attn_drop_rate=kwargs.get("attn_dropout", 0.5),
        drop_path_rate=0.3, # Add Stochastic Depth
        **kwargs,
    )

    return DaViT(**model_kwargs)

# model = DaViT_eeg(dropout=dropout, attn_dropout=attn_dropout).to(device)

# %%
subjects = sorted(dataset.info["subject_id"].unique())  # Get list of all 15 subjects

# %%
# --- MIXUP HELPER FUNCTIONS ---
def mixup_data(x, y, alpha=1.0):
    """
    Applies Mixup augmentation to a batch of data.
    
    Logic:
    1. Generate a mixing coefficient (lambda) from a Beta(alpha, alpha) distribution.
       - If alpha is close to 0, lambda is close to 0 or 1 (little mixing).
       - If alpha is large, lambda is close to 0.5 (strong mixing).
    2. Shuffle the batch indices to get a "partner" for every sample.
    3. Create a new "mixed" input: mixed_x = lambda * x + (1 - lambda) * x[shuffled_indices]
    
    Returns:
        mixed_x: The blended input tensor.
        y_a: The original labels.
        y_b: The labels of the shuffled samples.
        lam: The mixing coefficient used.
    """
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(device)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    """
    Calculates the Mixup loss.
    
    Since the input was a mix of two samples (A and B) with weight lambda:
    Loss = lambda * Loss(pred, Label_A) + (1 - lambda) * Loss(pred, Label_B)
    """
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
all_subject_accuracies = []
all_subject_histories = {}
for subject_id in subjects:
    print("\n========================================")
    print(f"  PROCESSING SUBJECT: {subject_id}")
    print("========================================")

    # 1. Filter Data for this Subject
    sub_df = dataset.info[dataset.info["subject_id"] == subject_id]

    # 2. Split by Unique Video (Session + Trial) for this subject
    # CRITICAL: We cannot just split by 'trial_id' because Trial 1 in Session 1 (Sad)
    # is different from Trial 1 in Session 2 (Fear). We must treat them as separate videos.

    # Create a unique ID for every video: "session_trial" (e.g., "1_5", "2_5", "3_5")
    sub_df = sub_df.copy()  # Avoid SettingWithCopy warning
    sub_df["unique_run_id"] = (
        sub_df["session_id"].astype(str) + "_" + sub_df["trial_id"].astype(str)
    )

    # Extract labels per unique run to ensure balanced split
    # We get a single label for each unique run (session_trial)
    # Since every segment in a trial has same label, we just drop duplicates
    run_info = sub_df[["unique_run_id", "emotion"]].drop_duplicates()
    all_runs = run_info["unique_run_id"].values
    all_labels = run_info["emotion"].values

    # Stratified Split at the RUN level
    # This keeps 80/20 ratio and ensures each class is represented in the test set
    train_runs, test_runs = train_test_split(
        all_runs, test_size=0.20, random_state=42, stratify=all_labels
    )

    print(f"Total Unique Videos (Across 3 Sessions): {len(all_runs)}")
    print(f"Training on: {len(train_runs)} | Testing on: {len(test_runs)}")

    # Extract indices (Zero Leakage Guaranteed)
    train_indices = sub_df[sub_df["unique_run_id"].isin(train_runs)].index.tolist()
    test_indices = sub_df[sub_df["unique_run_id"].isin(test_runs)].index.tolist()

    train_set = Subset(dataset, train_indices)
    test_set = Subset(dataset, test_indices)

    y_train_indices = train_set.indices
    raw_labels = dataset.info.iloc[y_train_indices]["emotion"].values

    # 3. Create Specific Sampler for this Subject
    # class_counts = np.bincount(raw_labels)
    # class_weights = 1.0 / class_counts
    # print(class_weights)
    # sample_weights = [class_weights[y] for y in raw_labels]

    mapped_labels = [map_emotions(y) for y in raw_labels]
    print(f"mapped_labels: {np.unique(mapped_labels)}")
    class_counts = np.bincount(mapped_labels)
    class_weights = 1.0 / class_counts
    print(class_weights)
    sample_weights = [class_weights[y] for y in mapped_labels]

    sampler = WeightedRandomSampler(
        weights=sample_weights, num_samples=len(sample_weights), replacement=True
    )

    # 4. Loaders
    train_loader = DataLoader(
        train_set, batch_size=BATCH_SIZE, sampler=sampler, num_workers=0
    )
    test_loader = DataLoader(
        test_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=0
    )
    train_count = len(train_loader)
    test_count = len(test_loader)

    # 5. FRESH Model & Optimizer (Reset for every subject)
    model = DaViT_eeg(dropout=DROPOUT, attn_dropout=ATTN_DROPOUT, _num_classes=len(class_weights)).to(
        device
    )

    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    # Cosine Annealing: Smoothly drops LR from 0.0001 -> 0 over EPOCHS_COUNT
    # This forces the model to settle into the best accuracy at the end
    # scheduler = CosineAnnealingLR(optimizer, T_max=EPOCHS_COUNT, eta_min=1e-6)

    # OneCycleLR is better for transformers (Warmup + Annealing)
    scheduler = OneCycleLR(
        optimizer,
        max_lr=LR,
        epochs=EPOCHS_COUNT,
        steps_per_epoch=len(train_loader),
        pct_start=0.3,  # 30% warmup
        div_factor=10,
        final_div_factor=1000,
    )
    criterion = nn.CrossEntropyLoss(
        weight=torch.tensor(class_weights).to(device).float(), label_smoothing=0.1
    )
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    # 6. Training Loop for this Subject
    best_acc = 0.0
    best_loss = float('inf')
    counter = 0        

    subject_train_acc = []
    subject_val_acc = []
    prinT = 0

    # Initialize Random Erasing
    # p=0.5: 50% chance to apply
    # scale=(0.02, 0.25): Erase smaller chunks to avoid killing too much info
    # ratio=(0.05, 20.0):
    #   - 0.05 means aspect ratio 1:20 (Very wide/flat, erasing a specific band across many channels)
    #   - 20.0 means aspect ratio 20:1 (Very tall/thin, erasing all bands for a few channels)
    # This flexibility suits the 62x5 shape much better than the default (0.3, 3.3).
    eraser = RandomErasing(
        p=0.5, scale=(0.02, 0.25), ratio=(0.05, 20.0), value=0, inplace=False
    )
    
    # --- MAIN LOOP EXTENSION ---
    for epoch in range(EPOCHS_COUNT):  # 40 epochs is usually enough for 1 subject
        startTime = time.time()
        model.train()
        train_loss = 0
        correct = 0
        total = 0



        for batch in train_loader:
            X, y = batch
            # 1. Augmentation: Add Gaussian Noise
            noise = torch.randn_like(X) * 0.05  # 5% noise factor
            X = X + noise

            # 2. Augmentation: Random Erasing
            # Random Erasing expects (B, C, H, W).
            X = eraser(X)

            if prinT:
                print(f"X: {X.shape},y: {y.shape}")
                prinT = 0

            X = X.to(device)
            y = y.to(device).long()

            # 2. Apply Mixup
            X, y_a, y_b, lam = mixup_data(X, y, alpha=0.2)
            X, y_a, y_b = map(torch.autograd.Variable, (X, y_a, y_b))

            optimizer.zero_grad()
            outputs = model(X)

            # 3. Use Mixup Loss
            loss = mixup_criterion(criterion, outputs, y_a, y_b, lam)
            loss.backward()
            optimizer.step()

            # For accuracy, we just compare against the dominant label (or y_a)
            # Mixup creates "soft" accuracy, but standard accuracy is fine for logging
            _, predicted = torch.max(outputs.data, 1)
            total += y.size(0)
            correct += (
                lam * predicted.eq(y_a.data).cpu().sum().float()
                + (1 - lam) * predicted.eq(y_b.data).cpu().sum().float()
            ).item()
            # scheduler step for OneCycleLR is per batch
            scheduler.step()
            train_loss += loss.item()

        train_acc = (correct / total) * 100
        avg_train_loss = train_loss / train_count

        # Validation
        model.eval()
        val_correct = 0
        val_total = 0
        val_loss = 0
        with torch.no_grad():
            for batch in test_loader:
                X, y = batch

                X = X.to(device)
                y = y.to(device).long()

                output = model(X)

                loss = criterion(output, y)
                val_loss += loss.item()
                _, predicted = torch.max(output.data, 1)
                val_total += y.size(0)
                val_correct += (predicted == y).sum().item()

        val_acc = 100 * val_correct / val_total
        avg_val_loss = val_loss / test_count
        current_lr = optimizer.param_groups[0]["lr"]
        elabsedTime = time.time() - startTime
        loss_ratio = avg_train_loss / avg_val_loss
        subject_train_acc.append(train_acc)
        subject_val_acc.append(val_acc)            

        # Early Stopping check (Monitor Validation Loss)
        is_best_acc = False
        if val_acc > best_acc:
            is_best_acc = True
            best_acc = val_acc
        
        # Monitor Loss for Early Stopping (No Model Saving)
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                break

        print(
            f"Epoch {epoch + 1}: Train Acc={train_acc:.2f}% | Val Acc={val_acc:.2f}% | Loss: {avg_train_loss:.4f}/{avg_val_loss:.4f} | Loss Ratio: {loss_ratio:.2f} | LR: {current_lr:.6f} | Elapsed Time: {elabsedTime:.2f} seconds {'[BEST ACC]' if is_best_acc else ''}"
        )

    all_subject_accuracies.append(best_acc)
    all_subject_histories[subject_id] = {
        "train": subject_train_acc,
        "val": subject_val_acc,
    }
# Out:
# ========================================
#   PROCESSING SUBJECT: 1
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# mapped_labels: [0 1 2]
# [0.00195695 0.00097752 0.00257069]
# Epoch 1: Train Acc=34.76% | Val Acc=24.05% | Loss: 1.1155/1.5177 | Loss Ratio: 0.74 | LR: 0.000050 | Elapsed Time: 2.83 seconds [BEST ACC]
# Epoch 2: Train Acc=34.06% | Val Acc=24.05% | Loss: 1.0448/1.3723 | Loss Ratio: 0.76 | LR: 0.000051 | Elapsed Time: 1.70 seconds
# Epoch 3: Train Acc=34.67% | Val Acc=28.69% | Loss: 1.0220/1.2716 | Loss Ratio: 0.80 | LR: 0.000052 | Elapsed Time: 1.76 seconds [BEST ACC]
# Epoch 4: Train Acc=37.79% | Val Acc=40.03% | Loss: 1.0291/1.2511 | Loss Ratio: 0.82 | LR: 0.000053 | Elapsed Time: 1.71 seconds [BEST ACC]
# Epoch 5: Train Acc=40.97% | Val Acc=24.05% | Loss: 0.9869/1.3130 | Loss Ratio: 0.75 | LR: 0.000055 | Elapsed Time: 1.71 seconds
# Epoch 6: Train Acc=42.57% | Val Acc=24.05% | Loss: 0.9859/1.2985 | Loss Ratio: 0.76 | LR: 0.000057 | Elapsed Time: 1.71 seconds
# Epoch 7: Train Acc=41.25% | Val Acc=36.94% | Loss: 0.9958/1.2659 | Loss Ratio: 0.79 | LR: 0.000060 | Elapsed Time: 1.73 seconds
# Epoch 8: Train Acc=48.32% | Val Acc=31.96% | Loss: 0.9062/1.2783 | Loss Ratio: 0.71 | LR: 0.000063 | Elapsed Time: 1.73 seconds
# Epoch 9: Train Acc=61.03% | Val Acc=62.37% | Loss: 0.7890/1.2111 | Loss Ratio: 0.65 | LR: 0.000066 | Elapsed Time: 1.74 seconds [BEST ACC]
# Epoch 10: Train Acc=62.47% | Val Acc=44.85% | Loss: 0.8225/1.1411 | Loss Ratio: 0.72 | LR: 0.000069 | Elapsed Time: 1.73 seconds
# Epoch 11: Train Acc=63.20% | Val Acc=54.81% | Loss: 0.8158/1.0848 | Loss Ratio: 0.75 | LR: 0.000073 | Elapsed Time: 1.72 seconds
# Epoch 12: Train Acc=64.95% | Val Acc=51.20% | Loss: 0.7740/1.1053 | Loss Ratio: 0.70 | LR: 0.000078 | Elapsed Time: 1.71 seconds
# Epoch 13: Train Acc=52.72% | Val Acc=54.30% | Loss: 0.8982/1.0931 | Loss Ratio: 0.82 | LR: 0.000083 | Elapsed Time: 1.74 seconds
# Epoch 14: Train Acc=72.73% | Val Acc=56.01% | Loss: 0.6993/1.0040 | Loss Ratio: 0.70 | LR: 0.000088 | Elapsed Time: 1.72 seconds
# Epoch 15: Train Acc=70.46% | Val Acc=46.56% | Loss: 0.6796/1.0613 | Loss Ratio: 0.64 | LR: 0.000093 | Elapsed Time: 1.74 seconds
# Epoch 16: Train Acc=75.30% | Val Acc=48.97% | Loss: 0.6188/1.0439 | Loss Ratio: 0.59 | LR: 0.000099 | Elapsed Time: 1.73 seconds
# Epoch 17: Train Acc=72.67% | Val Acc=55.50% | Loss: 0.7210/1.1837 | Loss Ratio: 0.61 | LR: 0.000105 | Elapsed Time: 1.73 seconds
# Epoch 18: Train Acc=69.21% | Val Acc=46.56% | Loss: 0.7200/1.0633 | Loss Ratio: 0.68 | LR: 0.000111 | Elapsed Time: 1.71 seconds
# Epoch 19: Train Acc=74.58% | Val Acc=47.08% | Loss: 0.6262/1.1828 | Loss Ratio: 0.53 | LR: 0.000118 | Elapsed Time: 1.71 seconds
# Epoch 20: Train Acc=76.00% | Val Acc=41.75% | Loss: 0.6621/1.1949 | Loss Ratio: 0.55 | LR: 0.000125 | Elapsed Time: 1.71 seconds
# Epoch 21: Train Acc=69.33% | Val Acc=63.92% | Loss: 0.7422/0.9832 | Loss Ratio: 0.75 | LR: 0.000132 | Elapsed Time: 1.76 seconds [BEST ACC]
# Epoch 22: Train Acc=74.41% | Val Acc=63.92% | Loss: 0.6485/0.9431 | Loss Ratio: 0.69 | LR: 0.000139 | Elapsed Time: 1.73 seconds
# Epoch 23: Train Acc=71.39% | Val Acc=63.57% | Loss: 0.7005/1.0010 | Loss Ratio: 0.70 | LR: 0.000147 | Elapsed Time: 1.70 seconds
# Epoch 24: Train Acc=78.18% | Val Acc=51.37% | Loss: 0.6067/1.1226 | Loss Ratio: 0.54 | LR: 0.000155 | Elapsed Time: 1.70 seconds
# Epoch 25: Train Acc=81.07% | Val Acc=61.17% | Loss: 0.5772/0.9917 | Loss Ratio: 0.58 | LR: 0.000163 | Elapsed Time: 1.71 seconds
# Epoch 26: Train Acc=79.54% | Val Acc=56.87% | Loss: 0.6144/1.0670 | Loss Ratio: 0.58 | LR: 0.000171 | Elapsed Time: 1.73 seconds
# Epoch 27: Train Acc=79.63% | Val Acc=41.75% | Loss: 0.5604/1.1880 | Loss Ratio: 0.47 | LR: 0.000179 | Elapsed Time: 1.75 seconds
# Epoch 28: Train Acc=82.67% | Val Acc=57.90% | Loss: 0.5581/1.0396 | Loss Ratio: 0.54 | LR: 0.000188 | Elapsed Time: 1.71 seconds
# Epoch 29: Train Acc=81.71% | Val Acc=73.02% | Loss: 0.5795/0.9721 | Loss Ratio: 0.60 | LR: 0.000197 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 30: Train Acc=84.12% | Val Acc=46.56% | Loss: 0.5525/1.2196 | Loss Ratio: 0.45 | LR: 0.000206 | Elapsed Time: 1.72 seconds
# Epoch 31: Train Acc=83.34% | Val Acc=61.86% | Loss: 0.5497/1.1597 | Loss Ratio: 0.47 | LR: 0.000215 | Elapsed Time: 1.71 seconds
# Epoch 32: Train Acc=77.25% | Val Acc=59.28% | Loss: 0.6141/1.1049 | Loss Ratio: 0.56 | LR: 0.000224 | Elapsed Time: 1.73 seconds
# Epoch 33: Train Acc=86.08% | Val Acc=49.48% | Loss: 0.5053/1.1182 | Loss Ratio: 0.45 | LR: 0.000233 | Elapsed Time: 1.72 seconds
# Epoch 34: Train Acc=83.64% | Val Acc=65.81% | Loss: 0.5439/0.9899 | Loss Ratio: 0.55 | LR: 0.000242 | Elapsed Time: 1.70 seconds
# Epoch 35: Train Acc=79.47% | Val Acc=50.69% | Loss: 0.6033/1.1777 | Loss Ratio: 0.51 | LR: 0.000252 | Elapsed Time: 1.73 seconds
# Epoch 36: Train Acc=86.88% | Val Acc=54.47% | Loss: 0.5076/1.5195 | Loss Ratio: 0.33 | LR: 0.000261 | Elapsed Time: 1.72 seconds
# Epoch 37: Train Acc=85.92% | Val Acc=49.66% | Loss: 0.5091/1.4157 | Loss Ratio: 0.36 | LR: 0.000270 | Elapsed Time: 1.72 seconds
# Epoch 38: Train Acc=84.33% | Val Acc=65.46% | Loss: 0.5431/0.9277 | Loss Ratio: 0.59 | LR: 0.000280 | Elapsed Time: 1.75 seconds
# Epoch 39: Train Acc=86.17% | Val Acc=59.62% | Loss: 0.5218/0.9852 | Loss Ratio: 0.53 | LR: 0.000289 | Elapsed Time: 1.72 seconds
# Epoch 40: Train Acc=82.59% | Val Acc=68.04% | Loss: 0.5447/0.9232 | Loss Ratio: 0.59 | LR: 0.000299 | Elapsed Time: 1.71 seconds
# Epoch 41: Train Acc=84.09% | Val Acc=74.57% | Loss: 0.5361/0.8156 | Loss Ratio: 0.66 | LR: 0.000308 | Elapsed Time: 1.70 seconds [BEST ACC]
# Epoch 42: Train Acc=85.48% | Val Acc=46.56% | Loss: 0.5327/1.5530 | Loss Ratio: 0.34 | LR: 0.000317 | Elapsed Time: 1.70 seconds
# Epoch 43: Train Acc=89.64% | Val Acc=62.37% | Loss: 0.4728/1.2706 | Loss Ratio: 0.37 | LR: 0.000327 | Elapsed Time: 1.71 seconds
# Epoch 44: Train Acc=94.51% | Val Acc=66.32% | Loss: 0.3986/0.9774 | Loss Ratio: 0.41 | LR: 0.000336 | Elapsed Time: 1.72 seconds
# Epoch 45: Train Acc=87.92% | Val Acc=73.37% | Loss: 0.4853/0.8469 | Loss Ratio: 0.57 | LR: 0.000345 | Elapsed Time: 1.70 seconds
# Epoch 46: Train Acc=85.63% | Val Acc=65.46% | Loss: 0.5305/1.0149 | Loss Ratio: 0.52 | LR: 0.000354 | Elapsed Time: 1.71 seconds
# Epoch 47: Train Acc=89.68% | Val Acc=71.65% | Loss: 0.4659/0.9194 | Loss Ratio: 0.51 | LR: 0.000362 | Elapsed Time: 1.70 seconds
# Epoch 48: Train Acc=89.57% | Val Acc=64.78% | Loss: 0.4538/0.9605 | Loss Ratio: 0.47 | LR: 0.000371 | Elapsed Time: 1.71 seconds
# Epoch 49: Train Acc=86.61% | Val Acc=51.37% | Loss: 0.5370/1.1928 | Loss Ratio: 0.45 | LR: 0.000379 | Elapsed Time: 1.72 seconds
# Epoch 50: Train Acc=79.95% | Val Acc=55.33% | Loss: 0.5967/1.1735 | Loss Ratio: 0.51 | LR: 0.000388 | Elapsed Time: 1.73 seconds
# Epoch 51: Train Acc=86.96% | Val Acc=41.75% | Loss: 0.4909/1.4026 | Loss Ratio: 0.35 | LR: 0.000396 | Elapsed Time: 1.72 seconds
# Epoch 52: Train Acc=78.78% | Val Acc=66.32% | Loss: 0.6140/0.9298 | Loss Ratio: 0.66 | LR: 0.000404 | Elapsed Time: 1.72 seconds
# Epoch 53: Train Acc=82.87% | Val Acc=73.02% | Loss: 0.5563/0.8611 | Loss Ratio: 0.65 | LR: 0.000411 | Elapsed Time: 1.75 seconds
# Epoch 54: Train Acc=85.83% | Val Acc=73.02% | Loss: 0.5057/1.0292 | Loss Ratio: 0.49 | LR: 0.000419 | Elapsed Time: 1.72 seconds
# Epoch 55: Train Acc=89.43% | Val Acc=59.11% | Loss: 0.4744/1.0299 | Loss Ratio: 0.46 | LR: 0.000426 | Elapsed Time: 1.73 seconds
# Epoch 56: Train Acc=88.39% | Val Acc=64.95% | Loss: 0.4827/1.0235 | Loss Ratio: 0.47 | LR: 0.000433 | Elapsed Time: 1.73 seconds
# Epoch 57: Train Acc=83.04% | Val Acc=59.97% | Loss: 0.5615/0.8624 | Loss Ratio: 0.65 | LR: 0.000439 | Elapsed Time: 1.74 seconds
# Epoch 58: Train Acc=83.70% | Val Acc=65.98% | Loss: 0.5571/1.1129 | Loss Ratio: 0.50 | LR: 0.000445 | Elapsed Time: 1.71 seconds
# Epoch 59: Train Acc=88.46% | Val Acc=56.01% | Loss: 0.4963/1.3856 | Loss Ratio: 0.36 | LR: 0.000451 | Elapsed Time: 1.70 seconds
# Epoch 60: Train Acc=90.90% | Val Acc=69.59% | Loss: 0.4571/0.9317 | Loss Ratio: 0.49 | LR: 0.000457 | Elapsed Time: 1.71 seconds
# Epoch 61: Train Acc=87.76% | Val Acc=58.76% | Loss: 0.4745/1.4078 | Loss Ratio: 0.34 | LR: 0.000463 | Elapsed Time: 1.76 seconds
# Epoch 62: Train Acc=83.79% | Val Acc=70.62% | Loss: 0.5484/1.0502 | Loss Ratio: 0.52 | LR: 0.000468 | Elapsed Time: 1.72 seconds
# Epoch 63: Train Acc=88.28% | Val Acc=70.62% | Loss: 0.4824/1.0482 | Loss Ratio: 0.46 | LR: 0.000472 | Elapsed Time: 1.71 seconds
# Epoch 64: Train Acc=91.12% | Val Acc=74.91% | Loss: 0.4667/0.9223 | Loss Ratio: 0.51 | LR: 0.000477 | Elapsed Time: 1.71 seconds [BEST ACC]
# Epoch 65: Train Acc=89.30% | Val Acc=48.45% | Loss: 0.4777/1.2380 | Loss Ratio: 0.39 | LR: 0.000481 | Elapsed Time: 1.73 seconds
# Epoch 66: Train Acc=90.23% | Val Acc=74.57% | Loss: 0.4554/0.8854 | Loss Ratio: 0.51 | LR: 0.000484 | Elapsed Time: 1.70 seconds
# Epoch 67: Train Acc=88.50% | Val Acc=67.18% | Loss: 0.4939/0.9507 | Loss Ratio: 0.52 | LR: 0.000488 | Elapsed Time: 1.73 seconds
# Epoch 68: Train Acc=86.62% | Val Acc=63.75% | Loss: 0.4967/1.1505 | Loss Ratio: 0.43 | LR: 0.000490 | Elapsed Time: 1.71 seconds
# Epoch 69: Train Acc=87.54% | Val Acc=54.30% | Loss: 0.5084/1.0691 | Loss Ratio: 0.48 | LR: 0.000493 | Elapsed Time: 1.70 seconds
# Epoch 70: Train Acc=86.57% | Val Acc=78.69% | Loss: 0.5155/0.7858 | Loss Ratio: 0.66 | LR: 0.000495 | Elapsed Time: 1.70 seconds [BEST ACC]
# Epoch 71: Train Acc=86.21% | Val Acc=62.89% | Loss: 0.5108/0.9722 | Loss Ratio: 0.53 | LR: 0.000497 | Elapsed Time: 1.70 seconds
# Epoch 72: Train Acc=87.41% | Val Acc=71.48% | Loss: 0.5235/0.8374 | Loss Ratio: 0.63 | LR: 0.000498 | Elapsed Time: 1.71 seconds
# Epoch 73: Train Acc=86.81% | Val Acc=73.88% | Loss: 0.4878/0.9290 | Loss Ratio: 0.53 | LR: 0.000499 | Elapsed Time: 1.71 seconds
# Epoch 74: Train Acc=91.05% | Val Acc=65.81% | Loss: 0.4378/1.0161 | Loss Ratio: 0.43 | LR: 0.000500 | Elapsed Time: 1.69 seconds
# Epoch 75: Train Acc=88.91% | Val Acc=68.04% | Loss: 0.4740/1.0560 | Loss Ratio: 0.45 | LR: 0.000500 | Elapsed Time: 1.69 seconds
# Epoch 76: Train Acc=91.03% | Val Acc=68.04% | Loss: 0.4434/0.8311 | Loss Ratio: 0.53 | LR: 0.000500 | Elapsed Time: 1.69 seconds
# Epoch 77: Train Acc=87.68% | Val Acc=71.65% | Loss: 0.5228/1.1255 | Loss Ratio: 0.46 | LR: 0.000500 | Elapsed Time: 1.70 seconds
# Epoch 78: Train Acc=83.55% | Val Acc=63.92% | Loss: 0.5664/1.1214 | Loss Ratio: 0.51 | LR: 0.000500 | Elapsed Time: 1.70 seconds
# Epoch 79: Train Acc=92.37% | Val Acc=73.02% | Loss: 0.4242/0.8964 | Loss Ratio: 0.47 | LR: 0.000499 | Elapsed Time: 1.73 seconds
# Epoch 80: Train Acc=90.39% | Val Acc=70.62% | Loss: 0.4643/0.9368 | Loss Ratio: 0.50 | LR: 0.000499 | Elapsed Time: 1.71 seconds
# Epoch 81: Train Acc=87.86% | Val Acc=61.00% | Loss: 0.4878/1.2747 | Loss Ratio: 0.38 | LR: 0.000499 | Elapsed Time: 1.70 seconds
# Epoch 82: Train Acc=90.97% | Val Acc=81.10% | Loss: 0.4404/0.7602 | Loss Ratio: 0.58 | LR: 0.000498 | Elapsed Time: 1.69 seconds [BEST ACC]
# Epoch 83: Train Acc=92.93% | Val Acc=72.34% | Loss: 0.4235/0.7327 | Loss Ratio: 0.58 | LR: 0.000497 | Elapsed Time: 1.70 seconds
# Epoch 84: Train Acc=89.06% | Val Acc=68.56% | Loss: 0.4707/0.9127 | Loss Ratio: 0.52 | LR: 0.000497 | Elapsed Time: 1.69 seconds
# Epoch 85: Train Acc=91.15% | Val Acc=67.70% | Loss: 0.4682/0.8739 | Loss Ratio: 0.54 | LR: 0.000496 | Elapsed Time: 1.73 seconds
# Epoch 86: Train Acc=85.82% | Val Acc=74.05% | Loss: 0.5197/0.8207 | Loss Ratio: 0.63 | LR: 0.000495 | Elapsed Time: 1.68 seconds
# Epoch 87: Train Acc=86.02% | Val Acc=63.92% | Loss: 0.5387/1.0650 | Loss Ratio: 0.51 | LR: 0.000494 | Elapsed Time: 1.68 seconds
# Epoch 88: Train Acc=90.95% | Val Acc=73.02% | Loss: 0.4550/0.7853 | Loss Ratio: 0.58 | LR: 0.000493 | Elapsed Time: 1.70 seconds
# Epoch 89: Train Acc=92.18% | Val Acc=73.02% | Loss: 0.4308/0.9836 | Loss Ratio: 0.44 | LR: 0.000492 | Elapsed Time: 1.70 seconds
# Epoch 90: Train Acc=92.05% | Val Acc=66.32% | Loss: 0.4288/1.0938 | Loss Ratio: 0.39 | LR: 0.000491 | Elapsed Time: 1.72 seconds
# Epoch 91: Train Acc=88.84% | Val Acc=71.48% | Loss: 0.4785/0.9991 | Loss Ratio: 0.48 | LR: 0.000490 | Elapsed Time: 1.73 seconds
# Epoch 92: Train Acc=89.66% | Val Acc=69.24% | Loss: 0.4727/0.9985 | Loss Ratio: 0.47 | LR: 0.000488 | Elapsed Time: 1.72 seconds
# Epoch 93: Train Acc=94.20% | Val Acc=70.62% | Loss: 0.3996/0.9943 | Loss Ratio: 0.40 | LR: 0.000487 | Elapsed Time: 1.72 seconds
# Epoch 94: Train Acc=91.50% | Val Acc=79.55% | Loss: 0.4491/0.7748 | Loss Ratio: 0.58 | LR: 0.000486 | Elapsed Time: 1.73 seconds
# Epoch 95: Train Acc=92.30% | Val Acc=73.88% | Loss: 0.4172/0.9068 | Loss Ratio: 0.46 | LR: 0.000484 | Elapsed Time: 1.70 seconds
# Epoch 96: Train Acc=91.86% | Val Acc=70.62% | Loss: 0.4330/0.9140 | Loss Ratio: 0.47 | LR: 0.000482 | Elapsed Time: 1.73 seconds
# Epoch 97: Train Acc=92.82% | Val Acc=77.84% | Loss: 0.4089/0.6811 | Loss Ratio: 0.60 | LR: 0.000481 | Elapsed Time: 1.73 seconds
# Epoch 98: Train Acc=90.33% | Val Acc=75.77% | Loss: 0.4693/0.8023 | Loss Ratio: 0.58 | LR: 0.000479 | Elapsed Time: 1.71 seconds
# Epoch 99: Train Acc=90.57% | Val Acc=71.13% | Loss: 0.4639/0.9889 | Loss Ratio: 0.47 | LR: 0.000477 | Elapsed Time: 1.70 seconds
# Epoch 100: Train Acc=93.65% | Val Acc=71.99% | Loss: 0.4070/1.0293 | Loss Ratio: 0.40 | LR: 0.000475 | Elapsed Time: 1.71 seconds
# Epoch 101: Train Acc=90.79% | Val Acc=72.34% | Loss: 0.4425/0.8441 | Loss Ratio: 0.52 | LR: 0.000473 | Elapsed Time: 1.72 seconds
# Epoch 102: Train Acc=93.92% | Val Acc=86.77% | Loss: 0.4089/0.7308 | Loss Ratio: 0.56 | LR: 0.000471 | Elapsed Time: 1.75 seconds [BEST ACC]
# Epoch 103: Train Acc=89.85% | Val Acc=78.69% | Loss: 0.4714/0.7361 | Loss Ratio: 0.64 | LR: 0.000469 | Elapsed Time: 1.70 seconds
# Epoch 104: Train Acc=92.88% | Val Acc=78.87% | Loss: 0.4264/0.8112 | Loss Ratio: 0.53 | LR: 0.000467 | Elapsed Time: 1.70 seconds
# Epoch 105: Train Acc=92.99% | Val Acc=62.37% | Loss: 0.4212/1.2613 | Loss Ratio: 0.33 | LR: 0.000465 | Elapsed Time: 1.69 seconds
# Epoch 106: Train Acc=90.27% | Val Acc=73.88% | Loss: 0.4519/0.9829 | Loss Ratio: 0.46 | LR: 0.000462 | Elapsed Time: 1.69 seconds
# Epoch 107: Train Acc=93.18% | Val Acc=77.84% | Loss: 0.4118/0.7179 | Loss Ratio: 0.57 | LR: 0.000460 | Elapsed Time: 1.69 seconds
# Epoch 108: Train Acc=90.19% | Val Acc=70.62% | Loss: 0.4630/0.8579 | Loss Ratio: 0.54 | LR: 0.000457 | Elapsed Time: 1.72 seconds
# Epoch 109: Train Acc=91.09% | Val Acc=81.27% | Loss: 0.4525/0.7201 | Loss Ratio: 0.63 | LR: 0.000455 | Elapsed Time: 1.69 seconds
# Epoch 110: Train Acc=92.51% | Val Acc=69.07% | Loss: 0.4169/0.9061 | Loss Ratio: 0.46 | LR: 0.000452 | Elapsed Time: 1.70 seconds
# Epoch 111: Train Acc=89.61% | Val Acc=79.90% | Loss: 0.4670/0.7826 | Loss Ratio: 0.60 | LR: 0.000450 | Elapsed Time: 1.70 seconds
# Epoch 112: Train Acc=93.85% | Val Acc=74.23% | Loss: 0.4123/0.8409 | Loss Ratio: 0.49 | LR: 0.000447 | Elapsed Time: 1.70 seconds
# Epoch 113: Train Acc=96.89% | Val Acc=71.48% | Loss: 0.3397/0.9107 | Loss Ratio: 0.37 | LR: 0.000444 | Elapsed Time: 1.69 seconds
# Epoch 114: Train Acc=90.11% | Val Acc=73.88% | Loss: 0.4628/0.9216 | Loss Ratio: 0.50 | LR: 0.000441 | Elapsed Time: 1.72 seconds
# Epoch 115: Train Acc=88.81% | Val Acc=71.31% | Loss: 0.4731/0.9167 | Loss Ratio: 0.52 | LR: 0.000438 | Elapsed Time: 1.70 seconds
# Epoch 116: Train Acc=89.75% | Val Acc=76.63% | Loss: 0.4945/0.8420 | Loss Ratio: 0.59 | LR: 0.000435 | Elapsed Time: 1.70 seconds
# Epoch 117: Train Acc=90.77% | Val Acc=78.87% | Loss: 0.4506/0.7581 | Loss Ratio: 0.59 | LR: 0.000432 | Elapsed Time: 1.69 seconds
# Epoch 118: Train Acc=94.97% | Val Acc=75.09% | Loss: 0.3959/0.8432 | Loss Ratio: 0.47 | LR: 0.000429 | Elapsed Time: 1.70 seconds
# Epoch 119: Train Acc=88.96% | Val Acc=66.67% | Loss: 0.4797/1.0501 | Loss Ratio: 0.46 | LR: 0.000426 | Elapsed Time: 1.71 seconds
# Epoch 120: Train Acc=95.55% | Val Acc=71.13% | Loss: 0.3727/0.8482 | Loss Ratio: 0.44 | LR: 0.000423 | Elapsed Time: 1.72 seconds
# Epoch 121: Train Acc=93.28% | Val Acc=81.10% | Loss: 0.4054/0.7926 | Loss Ratio: 0.51 | LR: 0.000419 | Elapsed Time: 1.70 seconds
# Epoch 122: Train Acc=94.66% | Val Acc=67.18% | Loss: 0.3911/1.0451 | Loss Ratio: 0.37 | LR: 0.000416 | Elapsed Time: 1.69 seconds
# Epoch 123: Train Acc=90.83% | Val Acc=78.52% | Loss: 0.4358/0.9080 | Loss Ratio: 0.48 | LR: 0.000413 | Elapsed Time: 1.69 seconds
# Epoch 124: Train Acc=90.03% | Val Acc=78.01% | Loss: 0.4642/0.8284 | Loss Ratio: 0.56 | LR: 0.000409 | Elapsed Time: 1.69 seconds
# Epoch 125: Train Acc=90.97% | Val Acc=78.87% | Loss: 0.4479/0.7809 | Loss Ratio: 0.57 | LR: 0.000406 | Elapsed Time: 1.69 seconds
# Epoch 126: Train Acc=95.62% | Val Acc=77.15% | Loss: 0.3727/0.9293 | Loss Ratio: 0.40 | LR: 0.000402 | Elapsed Time: 1.71 seconds
# Epoch 127: Train Acc=94.11% | Val Acc=81.10% | Loss: 0.3947/0.7952 | Loss Ratio: 0.50 | LR: 0.000399 | Elapsed Time: 1.71 seconds
# Epoch 128: Train Acc=92.26% | Val Acc=69.93% | Loss: 0.4243/0.8848 | Loss Ratio: 0.48 | LR: 0.000395 | Elapsed Time: 1.69 seconds
# Epoch 129: Train Acc=91.24% | Val Acc=66.15% | Loss: 0.4377/0.8200 | Loss Ratio: 0.53 | LR: 0.000391 | Elapsed Time: 1.73 seconds
# Epoch 130: Train Acc=91.47% | Val Acc=81.10% | Loss: 0.4426/0.7438 | Loss Ratio: 0.60 | LR: 0.000388 | Elapsed Time: 1.71 seconds
# Epoch 131: Train Acc=95.72% | Val Acc=79.21% | Loss: 0.3793/0.8158 | Loss Ratio: 0.46 | LR: 0.000384 | Elapsed Time: 1.70 seconds
# Epoch 132: Train Acc=89.89% | Val Acc=74.74% | Loss: 0.4706/0.8069 | Loss Ratio: 0.58 | LR: 0.000380 | Elapsed Time: 1.77 seconds
# Epoch 133: Train Acc=87.08% | Val Acc=77.66% | Loss: 0.5045/0.7984 | Loss Ratio: 0.63 | LR: 0.000376 | Elapsed Time: 1.73 seconds
# Epoch 134: Train Acc=92.21% | Val Acc=67.53% | Loss: 0.4206/0.8995 | Loss Ratio: 0.47 | LR: 0.000372 | Elapsed Time: 1.71 seconds
# Epoch 135: Train Acc=92.36% | Val Acc=75.09% | Loss: 0.4356/0.7765 | Loss Ratio: 0.56 | LR: 0.000368 | Elapsed Time: 1.71 seconds
# Epoch 136: Train Acc=92.75% | Val Acc=66.32% | Loss: 0.4103/1.0494 | Loss Ratio: 0.39 | LR: 0.000364 | Elapsed Time: 1.73 seconds
# Epoch 137: Train Acc=92.25% | Val Acc=75.43% | Loss: 0.4296/0.8125 | Loss Ratio: 0.53 | LR: 0.000360 | Elapsed Time: 1.72 seconds
# Epoch 138: Train Acc=90.09% | Val Acc=73.88% | Loss: 0.4608/0.8868 | Loss Ratio: 0.52 | LR: 0.000356 | Elapsed Time: 1.72 seconds
# Epoch 139: Train Acc=87.05% | Val Acc=59.11% | Loss: 0.5146/1.0295 | Loss Ratio: 0.50 | LR: 0.000352 | Elapsed Time: 1.71 seconds
# Epoch 140: Train Acc=89.27% | Val Acc=77.84% | Loss: 0.4470/0.9830 | Loss Ratio: 0.45 | LR: 0.000348 | Elapsed Time: 1.69 seconds
# Epoch 141: Train Acc=89.30% | Val Acc=74.40% | Loss: 0.4697/1.1381 | Loss Ratio: 0.41 | LR: 0.000344 | Elapsed Time: 1.70 seconds
# Epoch 142: Train Acc=90.32% | Val Acc=79.90% | Loss: 0.4762/0.7678 | Loss Ratio: 0.62 | LR: 0.000340 | Elapsed Time: 1.71 seconds
# Epoch 143: Train Acc=91.26% | Val Acc=74.91% | Loss: 0.4312/0.8058 | Loss Ratio: 0.54 | LR: 0.000336 | Elapsed Time: 1.75 seconds
# Epoch 144: Train Acc=87.86% | Val Acc=67.70% | Loss: 0.4886/1.2117 | Loss Ratio: 0.40 | LR: 0.000331 | Elapsed Time: 1.71 seconds
# Epoch 145: Train Acc=90.21% | Val Acc=72.34% | Loss: 0.4541/0.9429 | Loss Ratio: 0.48 | LR: 0.000327 | Elapsed Time: 1.73 seconds
# Epoch 146: Train Acc=93.69% | Val Acc=79.55% | Loss: 0.4025/0.8587 | Loss Ratio: 0.47 | LR: 0.000323 | Elapsed Time: 1.72 seconds
#
# ========================================
#   PROCESSING SUBJECT: 2
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# mapped_labels: [0 1 2]
# [0.00195695 0.00097752 0.00257069]
# Epoch 1: Train Acc=35.87% | Val Acc=33.16% | Loss: 1.0776/1.1255 | Loss Ratio: 0.96 | LR: 0.000050 | Elapsed Time: 1.74 seconds [BEST ACC]
# Epoch 2: Train Acc=46.79% | Val Acc=52.75% | Loss: 0.9384/1.0669 | Loss Ratio: 0.88 | LR: 0.000051 | Elapsed Time: 1.75 seconds [BEST ACC]
# Epoch 3: Train Acc=59.14% | Val Acc=52.75% | Loss: 0.7854/1.3911 | Loss Ratio: 0.56 | LR: 0.000052 | Elapsed Time: 1.71 seconds
# Epoch 4: Train Acc=59.29% | Val Acc=52.75% | Loss: 0.7756/1.2655 | Loss Ratio: 0.61 | LR: 0.000053 | Elapsed Time: 1.71 seconds
# Epoch 5: Train Acc=65.26% | Val Acc=63.92% | Loss: 0.7227/1.1063 | Loss Ratio: 0.65 | LR: 0.000055 | Elapsed Time: 1.71 seconds [BEST ACC]
# Epoch 6: Train Acc=70.20% | Val Acc=54.98% | Loss: 0.6578/1.1334 | Loss Ratio: 0.58 | LR: 0.000057 | Elapsed Time: 1.72 seconds
# Epoch 7: Train Acc=70.46% | Val Acc=56.70% | Loss: 0.7042/0.9100 | Loss Ratio: 0.77 | LR: 0.000060 | Elapsed Time: 1.71 seconds
# Epoch 8: Train Acc=67.73% | Val Acc=58.76% | Loss: 0.7152/0.9395 | Loss Ratio: 0.76 | LR: 0.000063 | Elapsed Time: 1.75 seconds
# Epoch 9: Train Acc=67.28% | Val Acc=72.16% | Loss: 0.7297/0.7856 | Loss Ratio: 0.93 | LR: 0.000066 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 10: Train Acc=68.43% | Val Acc=52.75% | Loss: 0.7185/1.1291 | Loss Ratio: 0.64 | LR: 0.000069 | Elapsed Time: 1.72 seconds
# Epoch 11: Train Acc=63.51% | Val Acc=56.19% | Loss: 0.7270/1.2906 | Loss Ratio: 0.56 | LR: 0.000073 | Elapsed Time: 1.71 seconds
# Epoch 12: Train Acc=75.56% | Val Acc=46.39% | Loss: 0.6118/1.0040 | Loss Ratio: 0.61 | LR: 0.000078 | Elapsed Time: 1.74 seconds
# Epoch 13: Train Acc=78.96% | Val Acc=58.25% | Loss: 0.5769/0.9575 | Loss Ratio: 0.60 | LR: 0.000083 | Elapsed Time: 1.74 seconds
# Epoch 14: Train Acc=76.76% | Val Acc=60.65% | Loss: 0.5954/0.7995 | Loss Ratio: 0.74 | LR: 0.000088 | Elapsed Time: 1.73 seconds
# Epoch 15: Train Acc=84.36% | Val Acc=50.34% | Loss: 0.5462/0.8858 | Loss Ratio: 0.62 | LR: 0.000093 | Elapsed Time: 1.74 seconds
# Epoch 16: Train Acc=79.91% | Val Acc=51.72% | Loss: 0.5832/0.8931 | Loss Ratio: 0.65 | LR: 0.000099 | Elapsed Time: 1.71 seconds
# Epoch 17: Train Acc=79.04% | Val Acc=51.55% | Loss: 0.6042/0.8904 | Loss Ratio: 0.68 | LR: 0.000105 | Elapsed Time: 1.72 seconds
# Epoch 18: Train Acc=83.33% | Val Acc=54.81% | Loss: 0.5517/0.8355 | Loss Ratio: 0.66 | LR: 0.000111 | Elapsed Time: 1.73 seconds
# Epoch 19: Train Acc=78.84% | Val Acc=55.67% | Loss: 0.5792/0.9699 | Loss Ratio: 0.60 | LR: 0.000118 | Elapsed Time: 1.76 seconds
# Epoch 20: Train Acc=82.31% | Val Acc=60.31% | Loss: 0.5360/0.8361 | Loss Ratio: 0.64 | LR: 0.000125 | Elapsed Time: 1.72 seconds
# Epoch 21: Train Acc=89.12% | Val Acc=75.26% | Loss: 0.4764/0.6957 | Loss Ratio: 0.68 | LR: 0.000132 | Elapsed Time: 1.71 seconds [BEST ACC]
# Epoch 22: Train Acc=89.37% | Val Acc=64.09% | Loss: 0.4575/0.7204 | Loss Ratio: 0.64 | LR: 0.000139 | Elapsed Time: 1.72 seconds
# Epoch 23: Train Acc=87.17% | Val Acc=53.09% | Loss: 0.5106/0.9017 | Loss Ratio: 0.57 | LR: 0.000147 | Elapsed Time: 1.73 seconds
# Epoch 24: Train Acc=85.92% | Val Acc=63.57% | Loss: 0.4980/0.7890 | Loss Ratio: 0.63 | LR: 0.000155 | Elapsed Time: 1.73 seconds
# Epoch 25: Train Acc=91.39% | Val Acc=81.96% | Loss: 0.4404/0.7654 | Loss Ratio: 0.58 | LR: 0.000163 | Elapsed Time: 1.76 seconds [BEST ACC]
# Epoch 26: Train Acc=73.72% | Val Acc=54.64% | Loss: 0.6335/0.9313 | Loss Ratio: 0.68 | LR: 0.000171 | Elapsed Time: 1.72 seconds
# Epoch 27: Train Acc=79.63% | Val Acc=52.41% | Loss: 0.5817/0.8934 | Loss Ratio: 0.65 | LR: 0.000179 | Elapsed Time: 1.76 seconds
# Epoch 28: Train Acc=85.78% | Val Acc=42.27% | Loss: 0.4985/1.5364 | Loss Ratio: 0.32 | LR: 0.000188 | Elapsed Time: 1.93 seconds
# Epoch 29: Train Acc=85.77% | Val Acc=52.23% | Loss: 0.4999/1.0478 | Loss Ratio: 0.48 | LR: 0.000197 | Elapsed Time: 1.73 seconds
# Epoch 30: Train Acc=89.21% | Val Acc=68.90% | Loss: 0.4597/0.9052 | Loss Ratio: 0.51 | LR: 0.000206 | Elapsed Time: 1.72 seconds
# Epoch 31: Train Acc=86.49% | Val Acc=70.62% | Loss: 0.4914/0.8300 | Loss Ratio: 0.59 | LR: 0.000215 | Elapsed Time: 1.73 seconds
# Epoch 32: Train Acc=85.14% | Val Acc=63.92% | Loss: 0.5302/0.8644 | Loss Ratio: 0.61 | LR: 0.000224 | Elapsed Time: 1.72 seconds
# Epoch 33: Train Acc=87.79% | Val Acc=61.51% | Loss: 0.5033/0.7448 | Loss Ratio: 0.68 | LR: 0.000233 | Elapsed Time: 1.71 seconds
# Epoch 34: Train Acc=90.92% | Val Acc=80.07% | Loss: 0.4566/0.7405 | Loss Ratio: 0.62 | LR: 0.000242 | Elapsed Time: 1.74 seconds
# Epoch 35: Train Acc=86.99% | Val Acc=63.40% | Loss: 0.4929/0.8815 | Loss Ratio: 0.56 | LR: 0.000252 | Elapsed Time: 1.71 seconds
# Epoch 36: Train Acc=92.83% | Val Acc=53.09% | Loss: 0.4362/1.1711 | Loss Ratio: 0.37 | LR: 0.000261 | Elapsed Time: 1.72 seconds
# Epoch 37: Train Acc=91.43% | Val Acc=62.37% | Loss: 0.4342/0.8772 | Loss Ratio: 0.50 | LR: 0.000270 | Elapsed Time: 1.74 seconds
# Epoch 38: Train Acc=88.72% | Val Acc=77.84% | Loss: 0.4831/0.7401 | Loss Ratio: 0.65 | LR: 0.000280 | Elapsed Time: 1.72 seconds
# Epoch 39: Train Acc=91.01% | Val Acc=62.20% | Loss: 0.4630/1.0031 | Loss Ratio: 0.46 | LR: 0.000289 | Elapsed Time: 1.72 seconds
# Epoch 40: Train Acc=81.94% | Val Acc=75.95% | Loss: 0.5938/0.7950 | Loss Ratio: 0.75 | LR: 0.000299 | Elapsed Time: 1.71 seconds
# Epoch 41: Train Acc=83.36% | Val Acc=90.03% | Loss: 0.5524/0.5560 | Loss Ratio: 0.99 | LR: 0.000308 | Elapsed Time: 1.71 seconds [BEST ACC]
# Epoch 42: Train Acc=85.18% | Val Acc=56.19% | Loss: 0.5372/0.8657 | Loss Ratio: 0.62 | LR: 0.000317 | Elapsed Time: 1.74 seconds
# Epoch 43: Train Acc=90.30% | Val Acc=63.40% | Loss: 0.4598/0.8499 | Loss Ratio: 0.54 | LR: 0.000327 | Elapsed Time: 1.72 seconds
# Epoch 44: Train Acc=88.86% | Val Acc=65.12% | Loss: 0.4900/1.0287 | Loss Ratio: 0.48 | LR: 0.000336 | Elapsed Time: 1.71 seconds
# Epoch 45: Train Acc=83.76% | Val Acc=87.97% | Loss: 0.5400/0.6043 | Loss Ratio: 0.89 | LR: 0.000345 | Elapsed Time: 1.71 seconds
# Epoch 46: Train Acc=88.68% | Val Acc=79.55% | Loss: 0.4849/0.6856 | Loss Ratio: 0.71 | LR: 0.000354 | Elapsed Time: 1.72 seconds
# Epoch 47: Train Acc=89.34% | Val Acc=81.27% | Loss: 0.4707/0.6476 | Loss Ratio: 0.73 | LR: 0.000362 | Elapsed Time: 1.72 seconds
# Epoch 48: Train Acc=82.67% | Val Acc=77.66% | Loss: 0.5850/0.7673 | Loss Ratio: 0.76 | LR: 0.000371 | Elapsed Time: 1.74 seconds
# Epoch 49: Train Acc=86.72% | Val Acc=65.81% | Loss: 0.5190/0.8896 | Loss Ratio: 0.58 | LR: 0.000379 | Elapsed Time: 1.70 seconds
# Epoch 50: Train Acc=84.01% | Val Acc=93.81% | Loss: 0.5572/0.5440 | Loss Ratio: 1.02 | LR: 0.000388 | Elapsed Time: 1.71 seconds [BEST ACC]
# Epoch 51: Train Acc=88.10% | Val Acc=81.79% | Loss: 0.4923/0.6631 | Loss Ratio: 0.74 | LR: 0.000396 | Elapsed Time: 1.73 seconds
# Epoch 52: Train Acc=86.30% | Val Acc=82.82% | Loss: 0.5158/0.6816 | Loss Ratio: 0.76 | LR: 0.000404 | Elapsed Time: 1.71 seconds
# Epoch 53: Train Acc=91.16% | Val Acc=74.74% | Loss: 0.4511/0.7710 | Loss Ratio: 0.59 | LR: 0.000411 | Elapsed Time: 1.74 seconds
# Epoch 54: Train Acc=93.47% | Val Acc=69.59% | Loss: 0.4164/0.8398 | Loss Ratio: 0.50 | LR: 0.000419 | Elapsed Time: 1.77 seconds
# Epoch 55: Train Acc=92.02% | Val Acc=73.20% | Loss: 0.4458/0.8827 | Loss Ratio: 0.51 | LR: 0.000426 | Elapsed Time: 1.71 seconds
# Epoch 56: Train Acc=92.20% | Val Acc=61.86% | Loss: 0.4236/0.8266 | Loss Ratio: 0.51 | LR: 0.000433 | Elapsed Time: 1.71 seconds
# Epoch 57: Train Acc=91.65% | Val Acc=58.25% | Loss: 0.4382/1.2196 | Loss Ratio: 0.36 | LR: 0.000439 | Elapsed Time: 1.72 seconds
# Epoch 58: Train Acc=87.95% | Val Acc=80.76% | Loss: 0.4844/0.7482 | Loss Ratio: 0.65 | LR: 0.000445 | Elapsed Time: 1.73 seconds
# Epoch 59: Train Acc=88.03% | Val Acc=72.85% | Loss: 0.5041/0.7201 | Loss Ratio: 0.70 | LR: 0.000451 | Elapsed Time: 1.71 seconds
# Epoch 60: Train Acc=90.01% | Val Acc=82.30% | Loss: 0.4626/0.6722 | Loss Ratio: 0.69 | LR: 0.000457 | Elapsed Time: 1.76 seconds
# Epoch 61: Train Acc=89.94% | Val Acc=66.49% | Loss: 0.4639/0.8281 | Loss Ratio: 0.56 | LR: 0.000463 | Elapsed Time: 1.75 seconds
# Epoch 62: Train Acc=92.38% | Val Acc=65.46% | Loss: 0.4289/0.9287 | Loss Ratio: 0.46 | LR: 0.000468 | Elapsed Time: 1.73 seconds
# Epoch 63: Train Acc=91.05% | Val Acc=78.01% | Loss: 0.4599/0.7599 | Loss Ratio: 0.61 | LR: 0.000472 | Elapsed Time: 1.72 seconds
# Epoch 64: Train Acc=87.57% | Val Acc=61.68% | Loss: 0.5129/1.0010 | Loss Ratio: 0.51 | LR: 0.000477 | Elapsed Time: 1.73 seconds
# Epoch 65: Train Acc=89.06% | Val Acc=74.57% | Loss: 0.4692/0.7048 | Loss Ratio: 0.67 | LR: 0.000481 | Elapsed Time: 1.75 seconds
# Epoch 66: Train Acc=88.57% | Val Acc=77.66% | Loss: 0.4781/0.7185 | Loss Ratio: 0.67 | LR: 0.000484 | Elapsed Time: 1.76 seconds
# Epoch 67: Train Acc=90.64% | Val Acc=62.37% | Loss: 0.4708/0.9065 | Loss Ratio: 0.52 | LR: 0.000488 | Elapsed Time: 1.75 seconds
# Epoch 68: Train Acc=92.48% | Val Acc=81.27% | Loss: 0.4227/0.7460 | Loss Ratio: 0.57 | LR: 0.000490 | Elapsed Time: 1.72 seconds
# Epoch 69: Train Acc=91.51% | Val Acc=69.76% | Loss: 0.4566/0.7260 | Loss Ratio: 0.63 | LR: 0.000493 | Elapsed Time: 1.71 seconds
# Epoch 70: Train Acc=92.33% | Val Acc=72.68% | Loss: 0.4260/0.7875 | Loss Ratio: 0.54 | LR: 0.000495 | Elapsed Time: 1.71 seconds
# Epoch 71: Train Acc=88.06% | Val Acc=85.22% | Loss: 0.4744/0.5959 | Loss Ratio: 0.80 | LR: 0.000497 | Elapsed Time: 1.75 seconds
# Epoch 72: Train Acc=88.60% | Val Acc=91.75% | Loss: 0.4861/0.5441 | Loss Ratio: 0.89 | LR: 0.000498 | Elapsed Time: 1.73 seconds
# Epoch 73: Train Acc=92.36% | Val Acc=64.78% | Loss: 0.4110/0.7148 | Loss Ratio: 0.58 | LR: 0.000499 | Elapsed Time: 1.72 seconds
# Epoch 74: Train Acc=84.40% | Val Acc=70.96% | Loss: 0.5243/0.6936 | Loss Ratio: 0.76 | LR: 0.000500 | Elapsed Time: 1.72 seconds
# Epoch 75: Train Acc=91.04% | Val Acc=68.73% | Loss: 0.4496/0.7732 | Loss Ratio: 0.58 | LR: 0.000500 | Elapsed Time: 1.72 seconds
# Epoch 76: Train Acc=92.32% | Val Acc=62.89% | Loss: 0.4168/0.8840 | Loss Ratio: 0.47 | LR: 0.000500 | Elapsed Time: 1.71 seconds
# Epoch 77: Train Acc=91.00% | Val Acc=69.93% | Loss: 0.4459/0.8213 | Loss Ratio: 0.54 | LR: 0.000500 | Elapsed Time: 1.76 seconds
# Epoch 78: Train Acc=88.67% | Val Acc=80.93% | Loss: 0.4907/0.7118 | Loss Ratio: 0.69 | LR: 0.000500 | Elapsed Time: 1.72 seconds
# Epoch 79: Train Acc=87.36% | Val Acc=81.44% | Loss: 0.4841/0.5924 | Loss Ratio: 0.82 | LR: 0.000499 | Elapsed Time: 1.72 seconds
# Epoch 80: Train Acc=92.64% | Val Acc=84.36% | Loss: 0.4066/0.6915 | Loss Ratio: 0.59 | LR: 0.000499 | Elapsed Time: 1.74 seconds
# Epoch 81: Train Acc=88.49% | Val Acc=68.73% | Loss: 0.4848/0.8193 | Loss Ratio: 0.59 | LR: 0.000499 | Elapsed Time: 1.71 seconds
# Epoch 82: Train Acc=91.29% | Val Acc=73.20% | Loss: 0.4476/0.8043 | Loss Ratio: 0.56 | LR: 0.000498 | Elapsed Time: 1.71 seconds
# Epoch 83: Train Acc=91.78% | Val Acc=78.35% | Loss: 0.4304/0.6466 | Loss Ratio: 0.67 | LR: 0.000497 | Elapsed Time: 1.74 seconds
# Epoch 84: Train Acc=90.16% | Val Acc=70.62% | Loss: 0.4564/0.7262 | Loss Ratio: 0.63 | LR: 0.000497 | Elapsed Time: 1.71 seconds
# Epoch 85: Train Acc=92.74% | Val Acc=66.15% | Loss: 0.4133/0.7781 | Loss Ratio: 0.53 | LR: 0.000496 | Elapsed Time: 1.70 seconds
# Epoch 86: Train Acc=93.51% | Val Acc=84.36% | Loss: 0.4011/0.7235 | Loss Ratio: 0.55 | LR: 0.000495 | Elapsed Time: 1.70 seconds
# Epoch 87: Train Acc=90.66% | Val Acc=74.23% | Loss: 0.4504/0.7090 | Loss Ratio: 0.64 | LR: 0.000494 | Elapsed Time: 1.70 seconds
# Epoch 88: Train Acc=89.62% | Val Acc=77.49% | Loss: 0.4702/0.6040 | Loss Ratio: 0.78 | LR: 0.000493 | Elapsed Time: 1.69 seconds
# Epoch 89: Train Acc=93.64% | Val Acc=68.90% | Loss: 0.3988/0.6544 | Loss Ratio: 0.61 | LR: 0.000492 | Elapsed Time: 1.76 seconds
# Epoch 90: Train Acc=92.23% | Val Acc=53.61% | Loss: 0.4326/0.8960 | Loss Ratio: 0.48 | LR: 0.000491 | Elapsed Time: 1.74 seconds
# Epoch 91: Train Acc=88.82% | Val Acc=74.74% | Loss: 0.4832/0.7200 | Loss Ratio: 0.67 | LR: 0.000490 | Elapsed Time: 1.72 seconds
# Epoch 92: Train Acc=87.83% | Val Acc=77.84% | Loss: 0.4917/0.6657 | Loss Ratio: 0.74 | LR: 0.000488 | Elapsed Time: 1.70 seconds
# Epoch 93: Train Acc=90.16% | Val Acc=70.96% | Loss: 0.4494/0.7853 | Loss Ratio: 0.57 | LR: 0.000487 | Elapsed Time: 1.70 seconds
# Epoch 94: Train Acc=86.99% | Val Acc=75.26% | Loss: 0.5090/0.8349 | Loss Ratio: 0.61 | LR: 0.000486 | Elapsed Time: 1.72 seconds
# Epoch 95: Train Acc=91.79% | Val Acc=81.96% | Loss: 0.4212/0.6293 | Loss Ratio: 0.67 | LR: 0.000484 | Elapsed Time: 1.73 seconds
# Epoch 96: Train Acc=93.77% | Val Acc=78.69% | Loss: 0.4056/0.6732 | Loss Ratio: 0.60 | LR: 0.000482 | Elapsed Time: 1.71 seconds
# Epoch 97: Train Acc=94.20% | Val Acc=58.25% | Loss: 0.4018/0.8200 | Loss Ratio: 0.49 | LR: 0.000481 | Elapsed Time: 1.70 seconds
# Epoch 98: Train Acc=93.73% | Val Acc=69.07% | Loss: 0.4001/0.7711 | Loss Ratio: 0.52 | LR: 0.000479 | Elapsed Time: 1.71 seconds
# Epoch 99: Train Acc=91.25% | Val Acc=73.71% | Loss: 0.4274/0.7091 | Loss Ratio: 0.60 | LR: 0.000477 | Elapsed Time: 1.71 seconds
#
# ========================================
#   PROCESSING SUBJECT: 3
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# mapped_labels: [0 1 2]
# [0.00195695 0.00097752 0.00257069]
# Epoch 1: Train Acc=34.25% | Val Acc=24.05% | Loss: 1.0924/1.2167 | Loss Ratio: 0.90 | LR: 0.000050 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 2: Train Acc=40.19% | Val Acc=29.90% | Loss: 1.0051/1.1901 | Loss Ratio: 0.84 | LR: 0.000051 | Elapsed Time: 1.70 seconds [BEST ACC]
# Epoch 3: Train Acc=45.49% | Val Acc=41.41% | Loss: 0.9607/1.0979 | Loss Ratio: 0.88 | LR: 0.000052 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 4: Train Acc=50.33% | Val Acc=36.60% | Loss: 0.9257/1.3534 | Loss Ratio: 0.68 | LR: 0.000053 | Elapsed Time: 1.74 seconds
# Epoch 5: Train Acc=54.89% | Val Acc=69.24% | Loss: 0.8560/0.9732 | Loss Ratio: 0.88 | LR: 0.000055 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 6: Train Acc=51.03% | Val Acc=39.86% | Loss: 0.9049/1.0898 | Loss Ratio: 0.83 | LR: 0.000057 | Elapsed Time: 1.73 seconds
# Epoch 7: Train Acc=59.43% | Val Acc=43.81% | Loss: 0.7808/1.1288 | Loss Ratio: 0.69 | LR: 0.000060 | Elapsed Time: 1.71 seconds
# Epoch 8: Train Acc=62.29% | Val Acc=62.89% | Loss: 0.7593/1.0135 | Loss Ratio: 0.75 | LR: 0.000063 | Elapsed Time: 1.72 seconds
# Epoch 9: Train Acc=69.36% | Val Acc=68.04% | Loss: 0.7106/0.7620 | Loss Ratio: 0.93 | LR: 0.000066 | Elapsed Time: 1.71 seconds
# Epoch 10: Train Acc=68.75% | Val Acc=54.12% | Loss: 0.7203/0.9436 | Loss Ratio: 0.76 | LR: 0.000069 | Elapsed Time: 1.71 seconds
# Epoch 11: Train Acc=64.73% | Val Acc=66.67% | Loss: 0.7650/1.0290 | Loss Ratio: 0.74 | LR: 0.000073 | Elapsed Time: 1.71 seconds
# Epoch 12: Train Acc=67.29% | Val Acc=53.95% | Loss: 0.7400/1.0449 | Loss Ratio: 0.71 | LR: 0.000078 | Elapsed Time: 1.73 seconds
# Epoch 13: Train Acc=63.54% | Val Acc=46.91% | Loss: 0.8167/1.1249 | Loss Ratio: 0.73 | LR: 0.000083 | Elapsed Time: 1.70 seconds
# Epoch 14: Train Acc=65.58% | Val Acc=72.68% | Loss: 0.7330/0.9012 | Loss Ratio: 0.81 | LR: 0.000088 | Elapsed Time: 1.71 seconds [BEST ACC]
# Epoch 15: Train Acc=70.44% | Val Acc=59.79% | Loss: 0.6810/0.9023 | Loss Ratio: 0.75 | LR: 0.000093 | Elapsed Time: 1.70 seconds
# Epoch 16: Train Acc=74.92% | Val Acc=69.76% | Loss: 0.6262/0.8618 | Loss Ratio: 0.73 | LR: 0.000099 | Elapsed Time: 1.70 seconds
# Epoch 17: Train Acc=74.12% | Val Acc=80.41% | Loss: 0.6475/0.9127 | Loss Ratio: 0.71 | LR: 0.000105 | Elapsed Time: 1.70 seconds [BEST ACC]
# Epoch 18: Train Acc=78.08% | Val Acc=68.73% | Loss: 0.5933/0.9993 | Loss Ratio: 0.59 | LR: 0.000111 | Elapsed Time: 1.72 seconds
# Epoch 19: Train Acc=75.29% | Val Acc=78.52% | Loss: 0.6329/0.8816 | Loss Ratio: 0.72 | LR: 0.000118 | Elapsed Time: 1.71 seconds
# Epoch 20: Train Acc=75.68% | Val Acc=65.81% | Loss: 0.6400/1.2351 | Loss Ratio: 0.52 | LR: 0.000125 | Elapsed Time: 1.70 seconds
# Epoch 21: Train Acc=75.50% | Val Acc=69.07% | Loss: 0.6550/1.0521 | Loss Ratio: 0.62 | LR: 0.000132 | Elapsed Time: 1.70 seconds
# Epoch 22: Train Acc=78.69% | Val Acc=73.37% | Loss: 0.6169/1.0247 | Loss Ratio: 0.60 | LR: 0.000139 | Elapsed Time: 1.70 seconds
# Epoch 23: Train Acc=69.84% | Val Acc=71.99% | Loss: 0.7116/0.9622 | Loss Ratio: 0.74 | LR: 0.000147 | Elapsed Time: 1.70 seconds
# Epoch 24: Train Acc=80.63% | Val Acc=63.40% | Loss: 0.5676/0.9938 | Loss Ratio: 0.57 | LR: 0.000155 | Elapsed Time: 1.74 seconds
# Epoch 25: Train Acc=74.46% | Val Acc=79.73% | Loss: 0.6552/0.8307 | Loss Ratio: 0.79 | LR: 0.000163 | Elapsed Time: 1.70 seconds
# Epoch 26: Train Acc=76.83% | Val Acc=80.07% | Loss: 0.6341/0.9806 | Loss Ratio: 0.65 | LR: 0.000171 | Elapsed Time: 1.72 seconds
# Epoch 27: Train Acc=82.84% | Val Acc=48.97% | Loss: 0.5420/1.4489 | Loss Ratio: 0.37 | LR: 0.000179 | Elapsed Time: 1.71 seconds
# Epoch 28: Train Acc=78.83% | Val Acc=66.67% | Loss: 0.5846/0.8802 | Loss Ratio: 0.66 | LR: 0.000188 | Elapsed Time: 1.70 seconds
# Epoch 29: Train Acc=79.34% | Val Acc=67.87% | Loss: 0.5785/0.9374 | Loss Ratio: 0.62 | LR: 0.000197 | Elapsed Time: 1.72 seconds
# Epoch 30: Train Acc=83.68% | Val Acc=70.79% | Loss: 0.5748/1.1399 | Loss Ratio: 0.50 | LR: 0.000206 | Elapsed Time: 1.73 seconds
# Epoch 31: Train Acc=77.83% | Val Acc=61.34% | Loss: 0.6286/1.1961 | Loss Ratio: 0.53 | LR: 0.000215 | Elapsed Time: 1.70 seconds
# Epoch 32: Train Acc=78.87% | Val Acc=64.60% | Loss: 0.6062/1.0509 | Loss Ratio: 0.58 | LR: 0.000224 | Elapsed Time: 1.70 seconds
# Epoch 33: Train Acc=79.92% | Val Acc=66.32% | Loss: 0.5847/1.3754 | Loss Ratio: 0.43 | LR: 0.000233 | Elapsed Time: 1.70 seconds
# Epoch 34: Train Acc=89.48% | Val Acc=66.84% | Loss: 0.4548/1.2952 | Loss Ratio: 0.35 | LR: 0.000242 | Elapsed Time: 1.69 seconds
# Epoch 35: Train Acc=88.47% | Val Acc=64.09% | Loss: 0.4777/0.9492 | Loss Ratio: 0.50 | LR: 0.000252 | Elapsed Time: 1.71 seconds
# Epoch 36: Train Acc=84.89% | Val Acc=67.87% | Loss: 0.5336/0.8700 | Loss Ratio: 0.61 | LR: 0.000261 | Elapsed Time: 1.72 seconds
# Epoch 37: Train Acc=88.90% | Val Acc=68.38% | Loss: 0.4806/1.3002 | Loss Ratio: 0.37 | LR: 0.000270 | Elapsed Time: 1.69 seconds
# Epoch 38: Train Acc=82.62% | Val Acc=51.20% | Loss: 0.5511/1.3148 | Loss Ratio: 0.42 | LR: 0.000280 | Elapsed Time: 1.71 seconds
# Epoch 39: Train Acc=79.70% | Val Acc=67.35% | Loss: 0.5921/1.2730 | Loss Ratio: 0.47 | LR: 0.000289 | Elapsed Time: 1.71 seconds
# Epoch 40: Train Acc=83.78% | Val Acc=60.31% | Loss: 0.5449/0.9658 | Loss Ratio: 0.56 | LR: 0.000299 | Elapsed Time: 1.70 seconds
# Epoch 41: Train Acc=85.59% | Val Acc=81.62% | Loss: 0.5041/0.9615 | Loss Ratio: 0.52 | LR: 0.000308 | Elapsed Time: 1.77 seconds [BEST ACC]
# Epoch 42: Train Acc=82.19% | Val Acc=69.76% | Loss: 0.5700/1.3888 | Loss Ratio: 0.41 | LR: 0.000317 | Elapsed Time: 1.73 seconds
# Epoch 43: Train Acc=78.60% | Val Acc=77.15% | Loss: 0.6062/1.1838 | Loss Ratio: 0.51 | LR: 0.000327 | Elapsed Time: 1.72 seconds
# Epoch 44: Train Acc=85.02% | Val Acc=68.73% | Loss: 0.5184/1.0805 | Loss Ratio: 0.48 | LR: 0.000336 | Elapsed Time: 1.73 seconds
# Epoch 45: Train Acc=87.92% | Val Acc=69.07% | Loss: 0.4778/1.2041 | Loss Ratio: 0.40 | LR: 0.000345 | Elapsed Time: 1.75 seconds
# Epoch 46: Train Acc=83.73% | Val Acc=70.62% | Loss: 0.5649/1.1844 | Loss Ratio: 0.48 | LR: 0.000354 | Elapsed Time: 1.73 seconds
# Epoch 47: Train Acc=89.70% | Val Acc=62.03% | Loss: 0.4723/1.2487 | Loss Ratio: 0.38 | LR: 0.000362 | Elapsed Time: 1.73 seconds
# Epoch 48: Train Acc=85.98% | Val Acc=62.03% | Loss: 0.5274/1.2911 | Loss Ratio: 0.41 | LR: 0.000371 | Elapsed Time: 1.72 seconds
# Epoch 49: Train Acc=87.20% | Val Acc=64.26% | Loss: 0.5045/1.2252 | Loss Ratio: 0.41 | LR: 0.000379 | Elapsed Time: 1.71 seconds
# Epoch 50: Train Acc=81.45% | Val Acc=71.13% | Loss: 0.5806/1.1556 | Loss Ratio: 0.50 | LR: 0.000388 | Elapsed Time: 1.70 seconds
# Epoch 51: Train Acc=80.54% | Val Acc=66.84% | Loss: 0.5955/0.9412 | Loss Ratio: 0.63 | LR: 0.000396 | Elapsed Time: 1.70 seconds
# Epoch 52: Train Acc=83.93% | Val Acc=66.32% | Loss: 0.5608/1.1188 | Loss Ratio: 0.50 | LR: 0.000404 | Elapsed Time: 1.72 seconds
# Epoch 53: Train Acc=88.75% | Val Acc=66.84% | Loss: 0.4731/1.1232 | Loss Ratio: 0.42 | LR: 0.000411 | Elapsed Time: 1.74 seconds
# Epoch 54: Train Acc=89.49% | Val Acc=51.37% | Loss: 0.4799/1.4926 | Loss Ratio: 0.32 | LR: 0.000419 | Elapsed Time: 1.71 seconds
# Epoch 55: Train Acc=84.87% | Val Acc=56.36% | Loss: 0.5409/1.4842 | Loss Ratio: 0.36 | LR: 0.000426 | Elapsed Time: 1.70 seconds
# Epoch 56: Train Acc=84.04% | Val Acc=54.81% | Loss: 0.5165/1.8698 | Loss Ratio: 0.28 | LR: 0.000433 | Elapsed Time: 1.71 seconds
# Epoch 57: Train Acc=79.91% | Val Acc=66.84% | Loss: 0.6071/1.1858 | Loss Ratio: 0.51 | LR: 0.000439 | Elapsed Time: 1.72 seconds
# Epoch 58: Train Acc=86.83% | Val Acc=56.01% | Loss: 0.5035/1.4050 | Loss Ratio: 0.36 | LR: 0.000445 | Elapsed Time: 1.73 seconds
#
# ========================================
#   PROCESSING SUBJECT: 4
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# mapped_labels: [0 1 2]
# [0.00195695 0.00097752 0.00257069]
# Epoch 1: Train Acc=37.18% | Val Acc=24.05% | Loss: 1.0765/1.1686 | Loss Ratio: 0.92 | LR: 0.000050 | Elapsed Time: 1.73 seconds [BEST ACC]
# Epoch 2: Train Acc=41.30% | Val Acc=61.34% | Loss: 1.0144/0.9102 | Loss Ratio: 1.11 | LR: 0.000051 | Elapsed Time: 1.81 seconds [BEST ACC]
# Epoch 3: Train Acc=48.49% | Val Acc=54.81% | Loss: 0.9022/0.9886 | Loss Ratio: 0.91 | LR: 0.000052 | Elapsed Time: 1.83 seconds
# Epoch 4: Train Acc=61.01% | Val Acc=73.37% | Loss: 0.7595/0.7815 | Loss Ratio: 0.97 | LR: 0.000053 | Elapsed Time: 1.77 seconds [BEST ACC]
# Epoch 5: Train Acc=77.54% | Val Acc=92.78% | Loss: 0.6259/0.5895 | Loss Ratio: 1.06 | LR: 0.000055 | Elapsed Time: 1.77 seconds [BEST ACC]
# Epoch 6: Train Acc=78.54% | Val Acc=86.94% | Loss: 0.6243/0.6275 | Loss Ratio: 0.99 | LR: 0.000057 | Elapsed Time: 1.82 seconds
# Epoch 7: Train Acc=84.13% | Val Acc=70.96% | Loss: 0.5790/0.8095 | Loss Ratio: 0.72 | LR: 0.000060 | Elapsed Time: 1.74 seconds
# Epoch 8: Train Acc=81.44% | Val Acc=92.78% | Loss: 0.5787/0.5406 | Loss Ratio: 1.07 | LR: 0.000063 | Elapsed Time: 1.73 seconds
# Epoch 9: Train Acc=84.95% | Val Acc=92.78% | Loss: 0.5401/0.5750 | Loss Ratio: 0.94 | LR: 0.000066 | Elapsed Time: 1.73 seconds
# Epoch 10: Train Acc=82.84% | Val Acc=86.25% | Loss: 0.5862/0.6335 | Loss Ratio: 0.93 | LR: 0.000069 | Elapsed Time: 1.75 seconds
# Epoch 11: Train Acc=77.47% | Val Acc=92.78% | Loss: 0.5906/0.6093 | Loss Ratio: 0.97 | LR: 0.000073 | Elapsed Time: 1.78 seconds
# Epoch 12: Train Acc=85.35% | Val Acc=86.25% | Loss: 0.5264/0.5930 | Loss Ratio: 0.89 | LR: 0.000078 | Elapsed Time: 1.77 seconds
# Epoch 13: Train Acc=88.76% | Val Acc=83.68% | Loss: 0.4938/0.7021 | Loss Ratio: 0.70 | LR: 0.000083 | Elapsed Time: 1.78 seconds
# Epoch 14: Train Acc=86.52% | Val Acc=92.78% | Loss: 0.5231/0.5156 | Loss Ratio: 1.01 | LR: 0.000088 | Elapsed Time: 1.87 seconds
# Epoch 15: Train Acc=86.93% | Val Acc=83.68% | Loss: 0.5339/0.6844 | Loss Ratio: 0.78 | LR: 0.000093 | Elapsed Time: 1.85 seconds
# Epoch 16: Train Acc=82.53% | Val Acc=92.78% | Loss: 0.5710/0.5298 | Loss Ratio: 1.08 | LR: 0.000099 | Elapsed Time: 1.90 seconds
# Epoch 17: Train Acc=86.43% | Val Acc=83.68% | Loss: 0.5029/0.5945 | Loss Ratio: 0.85 | LR: 0.000105 | Elapsed Time: 1.95 seconds
# Epoch 18: Train Acc=90.34% | Val Acc=92.78% | Loss: 0.4562/0.6437 | Loss Ratio: 0.71 | LR: 0.000111 | Elapsed Time: 1.85 seconds
# Epoch 19: Train Acc=87.34% | Val Acc=92.78% | Loss: 0.5036/0.7328 | Loss Ratio: 0.69 | LR: 0.000118 | Elapsed Time: 1.85 seconds
# Epoch 20: Train Acc=85.43% | Val Acc=92.78% | Loss: 0.5236/0.5610 | Loss Ratio: 0.93 | LR: 0.000125 | Elapsed Time: 1.83 seconds
# Epoch 21: Train Acc=84.01% | Val Acc=73.37% | Loss: 0.5374/0.8152 | Loss Ratio: 0.66 | LR: 0.000132 | Elapsed Time: 1.75 seconds
# Epoch 22: Train Acc=87.86% | Val Acc=92.78% | Loss: 0.4969/0.6722 | Loss Ratio: 0.74 | LR: 0.000139 | Elapsed Time: 1.75 seconds
# Epoch 23: Train Acc=87.13% | Val Acc=92.78% | Loss: 0.5002/0.5410 | Loss Ratio: 0.92 | LR: 0.000147 | Elapsed Time: 1.74 seconds
# Epoch 24: Train Acc=87.72% | Val Acc=83.68% | Loss: 0.5022/0.5429 | Loss Ratio: 0.93 | LR: 0.000155 | Elapsed Time: 1.74 seconds
# Epoch 25: Train Acc=93.41% | Val Acc=83.68% | Loss: 0.4168/0.6640 | Loss Ratio: 0.63 | LR: 0.000163 | Elapsed Time: 1.74 seconds
# Epoch 26: Train Acc=89.70% | Val Acc=92.78% | Loss: 0.4509/0.4775 | Loss Ratio: 0.94 | LR: 0.000171 | Elapsed Time: 1.74 seconds
# Epoch 27: Train Acc=92.00% | Val Acc=89.18% | Loss: 0.4351/0.6000 | Loss Ratio: 0.73 | LR: 0.000179 | Elapsed Time: 1.73 seconds
# Epoch 28: Train Acc=90.27% | Val Acc=83.68% | Loss: 0.4595/0.6927 | Loss Ratio: 0.66 | LR: 0.000188 | Elapsed Time: 1.77 seconds
# Epoch 29: Train Acc=88.88% | Val Acc=95.02% | Loss: 0.4971/0.5054 | Loss Ratio: 0.98 | LR: 0.000197 | Elapsed Time: 1.76 seconds [BEST ACC]
# Epoch 30: Train Acc=85.27% | Val Acc=92.78% | Loss: 0.5428/0.6422 | Loss Ratio: 0.85 | LR: 0.000206 | Elapsed Time: 1.74 seconds
# Epoch 31: Train Acc=83.27% | Val Acc=91.41% | Loss: 0.5561/0.4863 | Loss Ratio: 1.14 | LR: 0.000215 | Elapsed Time: 1.74 seconds
# Epoch 32: Train Acc=85.22% | Val Acc=89.00% | Loss: 0.5580/0.6700 | Loss Ratio: 0.83 | LR: 0.000224 | Elapsed Time: 1.77 seconds
# Epoch 33: Train Acc=84.82% | Val Acc=91.24% | Loss: 0.5052/0.5455 | Loss Ratio: 0.93 | LR: 0.000233 | Elapsed Time: 1.76 seconds
# Epoch 34: Train Acc=90.09% | Val Acc=83.68% | Loss: 0.4871/0.6236 | Loss Ratio: 0.78 | LR: 0.000242 | Elapsed Time: 1.74 seconds
# Epoch 35: Train Acc=88.41% | Val Acc=91.58% | Loss: 0.5167/0.6515 | Loss Ratio: 0.79 | LR: 0.000252 | Elapsed Time: 1.76 seconds
# Epoch 36: Train Acc=85.57% | Val Acc=84.71% | Loss: 0.5276/0.5463 | Loss Ratio: 0.97 | LR: 0.000261 | Elapsed Time: 1.74 seconds
# Epoch 37: Train Acc=90.80% | Val Acc=83.68% | Loss: 0.4532/0.6986 | Loss Ratio: 0.65 | LR: 0.000270 | Elapsed Time: 1.73 seconds
# Epoch 38: Train Acc=86.90% | Val Acc=92.78% | Loss: 0.5027/0.6913 | Loss Ratio: 0.73 | LR: 0.000280 | Elapsed Time: 1.76 seconds
# Epoch 39: Train Acc=91.02% | Val Acc=75.95% | Loss: 0.4691/0.7755 | Loss Ratio: 0.60 | LR: 0.000289 | Elapsed Time: 1.76 seconds
# Epoch 40: Train Acc=88.73% | Val Acc=88.66% | Loss: 0.5137/0.5877 | Loss Ratio: 0.87 | LR: 0.000299 | Elapsed Time: 1.74 seconds
# Epoch 41: Train Acc=85.39% | Val Acc=83.68% | Loss: 0.5623/0.7131 | Loss Ratio: 0.79 | LR: 0.000308 | Elapsed Time: 1.73 seconds
# Epoch 42: Train Acc=85.94% | Val Acc=75.95% | Loss: 0.5493/0.5836 | Loss Ratio: 0.94 | LR: 0.000317 | Elapsed Time: 1.72 seconds
# Epoch 43: Train Acc=81.14% | Val Acc=84.02% | Loss: 0.5690/0.6695 | Loss Ratio: 0.85 | LR: 0.000327 | Elapsed Time: 1.72 seconds
# Epoch 44: Train Acc=90.21% | Val Acc=83.68% | Loss: 0.4491/0.6110 | Loss Ratio: 0.74 | LR: 0.000336 | Elapsed Time: 1.74 seconds
# Epoch 45: Train Acc=90.26% | Val Acc=83.68% | Loss: 0.4557/0.7488 | Loss Ratio: 0.61 | LR: 0.000345 | Elapsed Time: 1.75 seconds
# Epoch 46: Train Acc=91.47% | Val Acc=83.68% | Loss: 0.4786/0.7416 | Loss Ratio: 0.65 | LR: 0.000354 | Elapsed Time: 1.73 seconds
# Epoch 47: Train Acc=93.72% | Val Acc=83.68% | Loss: 0.4120/0.7289 | Loss Ratio: 0.57 | LR: 0.000362 | Elapsed Time: 1.72 seconds
# Epoch 48: Train Acc=91.19% | Val Acc=83.68% | Loss: 0.4616/0.7651 | Loss Ratio: 0.60 | LR: 0.000371 | Elapsed Time: 1.71 seconds
# Epoch 49: Train Acc=88.34% | Val Acc=83.68% | Loss: 0.4955/0.7404 | Loss Ratio: 0.67 | LR: 0.000379 | Elapsed Time: 1.72 seconds
# Epoch 50: Train Acc=90.07% | Val Acc=83.68% | Loss: 0.4636/0.6946 | Loss Ratio: 0.67 | LR: 0.000388 | Elapsed Time: 1.72 seconds
# Epoch 51: Train Acc=93.46% | Val Acc=75.43% | Loss: 0.4029/0.6683 | Loss Ratio: 0.60 | LR: 0.000396 | Elapsed Time: 1.75 seconds
# Epoch 52: Train Acc=91.14% | Val Acc=83.68% | Loss: 0.4577/0.6932 | Loss Ratio: 0.66 | LR: 0.000404 | Elapsed Time: 1.71 seconds
# Epoch 53: Train Acc=92.52% | Val Acc=83.68% | Loss: 0.4203/0.7289 | Loss Ratio: 0.58 | LR: 0.000411 | Elapsed Time: 1.71 seconds
# Epoch 54: Train Acc=92.83% | Val Acc=90.55% | Loss: 0.4334/0.6867 | Loss Ratio: 0.63 | LR: 0.000419 | Elapsed Time: 1.72 seconds
# Epoch 55: Train Acc=94.44% | Val Acc=90.38% | Loss: 0.4006/0.6534 | Loss Ratio: 0.61 | LR: 0.000426 | Elapsed Time: 1.71 seconds
# Epoch 56: Train Acc=89.88% | Val Acc=83.68% | Loss: 0.4704/0.8759 | Loss Ratio: 0.54 | LR: 0.000433 | Elapsed Time: 1.73 seconds
# ...
# Epoch 54: Train Acc=87.65% | Val Acc=59.62% | Loss: 0.5004/1.0743 | Loss Ratio: 0.47 | LR: 0.000419 | Elapsed Time: 1.71 seconds
# Epoch 55: Train Acc=88.78% | Val Acc=54.47% | Loss: 0.4745/1.0515 | Loss Ratio: 0.45 | LR: 0.000426 | Elapsed Time: 1.69 seconds
# Epoch 56: Train Acc=94.78% | Val Acc=79.21% | Loss: 0.3885/0.9049 | Loss Ratio: 0.43 | LR: 0.000433 | Elapsed Time: 1.70 seconds
# Epoch 57: Train Acc=91.73% | Val Acc=68.21% | Loss: 0.4501/1.0030 | Loss Ratio: 0.45 | LR: 0.000439 | Elapsed Time: 1.72 seconds
# Epoch 58: Train Acc=88.52% | Val Acc=70.27% | Loss: 0.5228/0.9963 | Loss Ratio: 0.52 | LR: 0.000445 | Elapsed Time: 1.70 seconds
# Epoch 59: Train Acc=86.06% | Val Acc=70.27% | Loss: 0.5214/1.0486 | Loss Ratio: 0.50 | LR: 0.000451 | Elapsed Time: 1.71 seconds
# Epoch 60: Train Acc=87.53% | Val Acc=69.93% | Loss: 0.5109/0.8148 | Loss Ratio: 0.63 | LR: 0.000457 | Elapsed Time: 1.70 seconds
# Epoch 61: Train Acc=92.51% | Val Acc=76.98% | Loss: 0.4233/0.9331 | Loss Ratio: 0.45 | LR: 0.000463 | Elapsed Time: 1.70 seconds
# Epoch 62: Train Acc=92.53% | Val Acc=70.27% | Loss: 0.4247/0.8924 | Loss Ratio: 0.48 | LR: 0.000468 | Elapsed Time: 1.70 seconds
# Epoch 63: Train Acc=82.90% | Val Acc=73.02% | Loss: 0.5744/0.8843 | Loss Ratio: 0.65 | LR: 0.000472 | Elapsed Time: 1.72 seconds
# Epoch 64: Train Acc=86.29% | Val Acc=64.60% | Loss: 0.5140/0.9665 | Loss Ratio: 0.53 | LR: 0.000477 | Elapsed Time: 1.72 seconds
# Epoch 65: Train Acc=91.06% | Val Acc=58.93% | Loss: 0.4803/1.3515 | Loss Ratio: 0.36 | LR: 0.000481 | Elapsed Time: 1.70 seconds
# Epoch 66: Train Acc=85.21% | Val Acc=70.79% | Loss: 0.5355/0.9666 | Loss Ratio: 0.55 | LR: 0.000484 | Elapsed Time: 1.70 seconds
# Epoch 67: Train Acc=91.19% | Val Acc=69.24% | Loss: 0.4604/1.0672 | Loss Ratio: 0.43 | LR: 0.000488 | Elapsed Time: 1.70 seconds
#
# ========================================
#   PROCESSING SUBJECT: 15
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# mapped_labels: [0 1 2]
# [0.00195695 0.00097752 0.00257069]
# Epoch 1: Train Acc=39.49% | Val Acc=33.16% | Loss: 1.0610/1.1652 | Loss Ratio: 0.91 | LR: 0.000050 | Elapsed Time: 1.74 seconds [BEST ACC]
# Epoch 2: Train Acc=52.48% | Val Acc=72.51% | Loss: 0.8431/1.0616 | Loss Ratio: 0.79 | LR: 0.000051 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 3: Train Acc=68.24% | Val Acc=56.87% | Loss: 0.7012/1.1991 | Loss Ratio: 0.58 | LR: 0.000052 | Elapsed Time: 1.68 seconds
# Epoch 4: Train Acc=66.04% | Val Acc=51.20% | Loss: 0.7836/1.1546 | Loss Ratio: 0.68 | LR: 0.000053 | Elapsed Time: 1.69 seconds
# Epoch 5: Train Acc=69.84% | Val Acc=56.70% | Loss: 0.6803/1.2709 | Loss Ratio: 0.54 | LR: 0.000055 | Elapsed Time: 1.68 seconds
# Epoch 6: Train Acc=78.18% | Val Acc=66.15% | Loss: 0.5972/0.8826 | Loss Ratio: 0.68 | LR: 0.000057 | Elapsed Time: 1.69 seconds
# Epoch 7: Train Acc=82.92% | Val Acc=61.86% | Loss: 0.5356/0.7755 | Loss Ratio: 0.69 | LR: 0.000060 | Elapsed Time: 1.69 seconds
# Epoch 8: Train Acc=83.45% | Val Acc=79.04% | Loss: 0.5249/0.8128 | Loss Ratio: 0.65 | LR: 0.000063 | Elapsed Time: 1.70 seconds [BEST ACC]
# Epoch 9: Train Acc=85.28% | Val Acc=83.85% | Loss: 0.5199/0.6222 | Loss Ratio: 0.84 | LR: 0.000066 | Elapsed Time: 1.70 seconds [BEST ACC]
# Epoch 10: Train Acc=83.04% | Val Acc=83.85% | Loss: 0.5619/0.7056 | Loss Ratio: 0.80 | LR: 0.000069 | Elapsed Time: 1.70 seconds
# Epoch 11: Train Acc=84.57% | Val Acc=77.15% | Loss: 0.5437/0.8039 | Loss Ratio: 0.68 | LR: 0.000073 | Elapsed Time: 1.71 seconds
# Epoch 12: Train Acc=81.09% | Val Acc=64.09% | Loss: 0.5950/0.8017 | Loss Ratio: 0.74 | LR: 0.000078 | Elapsed Time: 1.70 seconds
# Epoch 13: Train Acc=86.14% | Val Acc=85.91% | Loss: 0.4985/0.5723 | Loss Ratio: 0.87 | LR: 0.000083 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 14: Train Acc=80.49% | Val Acc=79.04% | Loss: 0.5951/0.7712 | Loss Ratio: 0.77 | LR: 0.000088 | Elapsed Time: 1.70 seconds
# Epoch 15: Train Acc=89.74% | Val Acc=83.85% | Loss: 0.4776/0.6001 | Loss Ratio: 0.80 | LR: 0.000093 | Elapsed Time: 1.80 seconds
# Epoch 16: Train Acc=84.32% | Val Acc=90.72% | Loss: 0.5600/0.5634 | Loss Ratio: 0.99 | LR: 0.000099 | Elapsed Time: 1.81 seconds [BEST ACC]
# Epoch 17: Train Acc=90.14% | Val Acc=89.18% | Loss: 0.4701/0.6297 | Loss Ratio: 0.75 | LR: 0.000105 | Elapsed Time: 1.71 seconds
# Epoch 18: Train Acc=89.95% | Val Acc=94.85% | Loss: 0.4756/0.5171 | Loss Ratio: 0.92 | LR: 0.000111 | Elapsed Time: 1.76 seconds [BEST ACC]
# Epoch 19: Train Acc=88.83% | Val Acc=89.86% | Loss: 0.5021/0.5636 | Loss Ratio: 0.89 | LR: 0.000118 | Elapsed Time: 1.72 seconds
# Epoch 20: Train Acc=86.50% | Val Acc=87.46% | Loss: 0.5145/0.5594 | Loss Ratio: 0.92 | LR: 0.000125 | Elapsed Time: 1.71 seconds
# Epoch 21: Train Acc=91.69% | Val Acc=93.30% | Loss: 0.4267/0.5575 | Loss Ratio: 0.77 | LR: 0.000132 | Elapsed Time: 1.70 seconds
# Epoch 22: Train Acc=91.23% | Val Acc=83.85% | Loss: 0.4538/0.7923 | Loss Ratio: 0.57 | LR: 0.000139 | Elapsed Time: 1.72 seconds
# Epoch 23: Train Acc=90.90% | Val Acc=83.85% | Loss: 0.4615/0.7756 | Loss Ratio: 0.59 | LR: 0.000147 | Elapsed Time: 1.70 seconds
# Epoch 24: Train Acc=90.74% | Val Acc=92.96% | Loss: 0.4366/0.5329 | Loss Ratio: 0.82 | LR: 0.000155 | Elapsed Time: 1.73 seconds
# Epoch 25: Train Acc=90.31% | Val Acc=83.85% | Loss: 0.4481/0.5920 | Loss Ratio: 0.76 | LR: 0.000163 | Elapsed Time: 1.75 seconds
# Epoch 26: Train Acc=91.89% | Val Acc=82.47% | Loss: 0.4574/0.6257 | Loss Ratio: 0.73 | LR: 0.000171 | Elapsed Time: 1.89 seconds
# Epoch 27: Train Acc=90.60% | Val Acc=92.96% | Loss: 0.4674/0.5091 | Loss Ratio: 0.92 | LR: 0.000179 | Elapsed Time: 1.70 seconds
# Epoch 28: Train Acc=89.59% | Val Acc=93.30% | Loss: 0.4897/0.5188 | Loss Ratio: 0.94 | LR: 0.000188 | Elapsed Time: 1.73 seconds
# Epoch 29: Train Acc=87.41% | Val Acc=93.30% | Loss: 0.5158/0.5876 | Loss Ratio: 0.88 | LR: 0.000197 | Elapsed Time: 1.71 seconds
# Epoch 30: Train Acc=94.23% | Val Acc=83.85% | Loss: 0.4104/0.5805 | Loss Ratio: 0.71 | LR: 0.000206 | Elapsed Time: 1.75 seconds
# Epoch 31: Train Acc=92.30% | Val Acc=93.30% | Loss: 0.4550/0.4854 | Loss Ratio: 0.94 | LR: 0.000215 | Elapsed Time: 1.72 seconds
# Epoch 32: Train Acc=90.35% | Val Acc=93.30% | Loss: 0.4824/0.6129 | Loss Ratio: 0.79 | LR: 0.000224 | Elapsed Time: 1.72 seconds
# Epoch 33: Train Acc=92.43% | Val Acc=93.30% | Loss: 0.4332/0.6502 | Loss Ratio: 0.67 | LR: 0.000233 | Elapsed Time: 1.72 seconds
# Epoch 34: Train Acc=91.85% | Val Acc=95.88% | Loss: 0.4499/0.4798 | Loss Ratio: 0.94 | LR: 0.000242 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 35: Train Acc=89.27% | Val Acc=83.85% | Loss: 0.4925/0.6614 | Loss Ratio: 0.74 | LR: 0.000252 | Elapsed Time: 1.73 seconds
# Epoch 36: Train Acc=91.93% | Val Acc=93.30% | Loss: 0.4526/0.5841 | Loss Ratio: 0.77 | LR: 0.000261 | Elapsed Time: 1.75 seconds
# Epoch 37: Train Acc=88.74% | Val Acc=97.94% | Loss: 0.5002/0.4938 | Loss Ratio: 1.01 | LR: 0.000270 | Elapsed Time: 1.73 seconds [BEST ACC]
# Epoch 38: Train Acc=93.44% | Val Acc=92.96% | Loss: 0.4177/0.5220 | Loss Ratio: 0.80 | LR: 0.000280 | Elapsed Time: 1.72 seconds
# Epoch 39: Train Acc=90.52% | Val Acc=78.52% | Loss: 0.4748/0.7438 | Loss Ratio: 0.64 | LR: 0.000289 | Elapsed Time: 1.71 seconds
# Epoch 40: Train Acc=90.96% | Val Acc=76.80% | Loss: 0.4581/0.7293 | Loss Ratio: 0.63 | LR: 0.000299 | Elapsed Time: 1.72 seconds
# Epoch 41: Train Acc=84.44% | Val Acc=68.73% | Loss: 0.5750/0.8139 | Loss Ratio: 0.71 | LR: 0.000308 | Elapsed Time: 1.76 seconds
# Epoch 42: Train Acc=86.70% | Val Acc=93.30% | Loss: 0.5147/0.7692 | Loss Ratio: 0.67 | LR: 0.000317 | Elapsed Time: 1.73 seconds
# Epoch 43: Train Acc=90.48% | Val Acc=92.96% | Loss: 0.4505/0.5349 | Loss Ratio: 0.84 | LR: 0.000327 | Elapsed Time: 1.70 seconds
# Epoch 44: Train Acc=93.27% | Val Acc=86.25% | Loss: 0.4207/0.6427 | Loss Ratio: 0.65 | LR: 0.000336 | Elapsed Time: 1.69 seconds
# Epoch 45: Train Acc=90.62% | Val Acc=78.69% | Loss: 0.4640/0.7845 | Loss Ratio: 0.59 | LR: 0.000345 | Elapsed Time: 1.69 seconds
# Epoch 46: Train Acc=88.81% | Val Acc=85.74% | Loss: 0.4986/0.7886 | Loss Ratio: 0.63 | LR: 0.000354 | Elapsed Time: 1.69 seconds
# Epoch 47: Train Acc=90.83% | Val Acc=93.30% | Loss: 0.4613/0.6216 | Loss Ratio: 0.74 | LR: 0.000362 | Elapsed Time: 1.76 seconds
# Epoch 48: Train Acc=92.98% | Val Acc=81.44% | Loss: 0.4102/0.6881 | Loss Ratio: 0.60 | LR: 0.000371 | Elapsed Time: 1.71 seconds
# Epoch 49: Train Acc=90.99% | Val Acc=89.18% | Loss: 0.4581/0.5550 | Loss Ratio: 0.83 | LR: 0.000379 | Elapsed Time: 1.70 seconds
# Epoch 50: Train Acc=88.51% | Val Acc=79.73% | Loss: 0.4926/0.6250 | Loss Ratio: 0.79 | LR: 0.000388 | Elapsed Time: 1.71 seconds
# Epoch 51: Train Acc=93.31% | Val Acc=76.80% | Loss: 0.4314/0.6198 | Loss Ratio: 0.70 | LR: 0.000396 | Elapsed Time: 1.71 seconds
# Epoch 52: Train Acc=88.95% | Val Acc=80.41% | Loss: 0.4783/0.5792 | Loss Ratio: 0.83 | LR: 0.000404 | Elapsed Time: 1.74 seconds
# Epoch 53: Train Acc=92.80% | Val Acc=90.89% | Loss: 0.4236/0.5709 | Loss Ratio: 0.74 | LR: 0.000411 | Elapsed Time: 1.75 seconds
# Epoch 54: Train Acc=90.10% | Val Acc=64.09% | Loss: 0.4668/0.9181 | Loss Ratio: 0.51 | LR: 0.000419 | Elapsed Time: 1.71 seconds
# Epoch 55: Train Acc=91.01% | Val Acc=92.96% | Loss: 0.4578/0.5232 | Loss Ratio: 0.88 | LR: 0.000426 | Elapsed Time: 1.71 seconds
# Epoch 56: Train Acc=89.73% | Val Acc=93.30% | Loss: 0.4540/0.5251 | Loss Ratio: 0.86 | LR: 0.000433 | Elapsed Time: 1.72 seconds
# Epoch 57: Train Acc=87.83% | Val Acc=100.00% | Loss: 0.4843/0.4662 | Loss Ratio: 1.04 | LR: 0.000439 | Elapsed Time: 1.72 seconds [BEST ACC]
# Epoch 58: Train Acc=92.67% | Val Acc=95.88% | Loss: 0.4363/0.5219 | Loss Ratio: 0.84 | LR: 0.000445 | Elapsed Time: 1.73 seconds
# Epoch 59: Train Acc=88.12% | Val Acc=92.96% | Loss: 0.4984/0.4987 | Loss Ratio: 1.00 | LR: 0.000451 | Elapsed Time: 1.74 seconds
# Epoch 60: Train Acc=88.87% | Val Acc=93.30% | Loss: 0.4724/0.6175 | Loss Ratio: 0.77 | LR: 0.000457 | Elapsed Time: 1.71 seconds
# Epoch 61: Train Acc=93.09% | Val Acc=82.82% | Loss: 0.4249/0.5945 | Loss Ratio: 0.71 | LR: 0.000463 | Elapsed Time: 1.72 seconds
# Epoch 62: Train Acc=90.84% | Val Acc=93.30% | Loss: 0.4292/0.6291 | Loss Ratio: 0.68 | LR: 0.000468 | Elapsed Time: 1.71 seconds
# Epoch 63: Train Acc=91.75% | Val Acc=56.01% | Loss: 0.4310/1.0826 | Loss Ratio: 0.40 | LR: 0.000472 | Elapsed Time: 1.72 seconds
# Epoch 64: Train Acc=89.94% | Val Acc=95.88% | Loss: 0.4646/0.4867 | Loss Ratio: 0.95 | LR: 0.000477 | Elapsed Time: 1.72 seconds
# Epoch 65: Train Acc=91.72% | Val Acc=92.96% | Loss: 0.4288/0.4823 | Loss Ratio: 0.89 | LR: 0.000481 | Elapsed Time: 1.75 seconds
# Epoch 66: Train Acc=92.18% | Val Acc=90.21% | Loss: 0.4430/0.6826 | Loss Ratio: 0.65 | LR: 0.000484 | Elapsed Time: 1.73 seconds
# Epoch 67: Train Acc=88.13% | Val Acc=93.30% | Loss: 0.4904/0.5407 | Loss Ratio: 0.91 | LR: 0.000488 | Elapsed Time: 1.74 seconds
# Epoch 68: Train Acc=86.85% | Val Acc=89.69% | Loss: 0.4987/0.5556 | Loss Ratio: 0.90 | LR: 0.000490 | Elapsed Time: 1.72 seconds
# Epoch 69: Train Acc=93.53% | Val Acc=93.30% | Loss: 0.3988/0.7510 | Loss Ratio: 0.53 | LR: 0.000493 | Elapsed Time: 1.73 seconds
# Epoch 70: Train Acc=89.84% | Val Acc=88.83% | Loss: 0.4629/0.5588 | Loss Ratio: 0.83 | LR: 0.000495 | Elapsed Time: 1.73 seconds
# Epoch 71: Train Acc=91.40% | Val Acc=86.25% | Loss: 0.4391/0.5617 | Loss Ratio: 0.78 | LR: 0.000497 | Elapsed Time: 1.76 seconds
# Epoch 72: Train Acc=92.87% | Val Acc=73.02% | Loss: 0.4253/0.6263 | Loss Ratio: 0.68 | LR: 0.000498 | Elapsed Time: 1.73 seconds
# Epoch 73: Train Acc=94.46% | Val Acc=77.84% | Loss: 0.4077/0.6942 | Loss Ratio: 0.59 | LR: 0.000499 | Elapsed Time: 1.72 seconds
# Epoch 74: Train Acc=95.60% | Val Acc=92.96% | Loss: 0.3757/0.5136 | Loss Ratio: 0.73 | LR: 0.000500 | Elapsed Time: 1.73 seconds
# Epoch 75: Train Acc=93.32% | Val Acc=93.30% | Loss: 0.3886/0.7274 | Loss Ratio: 0.53 | LR: 0.000500 | Elapsed Time: 1.75 seconds
# Epoch 76: Train Acc=90.30% | Val Acc=82.47% | Loss: 0.4398/0.8713 | Loss Ratio: 0.50 | LR: 0.000500 | Elapsed Time: 1.76 seconds
# Epoch 77: Train Acc=89.61% | Val Acc=73.54% | Loss: 0.4796/0.6502 | Loss Ratio: 0.74 | LR: 0.000500 | Elapsed Time: 1.70 seconds
# Epoch 78: Train Acc=90.91% | Val Acc=95.36% | Loss: 0.4396/0.5132 | Loss Ratio: 0.86 | LR: 0.000500 | Elapsed Time: 1.71 seconds
# Epoch 79: Train Acc=93.35% | Val Acc=94.50% | Loss: 0.4132/0.5229 | Loss Ratio: 0.79 | LR: 0.000499 | Elapsed Time: 1.69 seconds
# Epoch 80: Train Acc=92.84% | Val Acc=87.80% | Loss: 0.4262/0.5714 | Loss Ratio: 0.75 | LR: 0.000499 | Elapsed Time: 1.71 seconds
# Epoch 81: Train Acc=91.89% | Val Acc=86.25% | Loss: 0.4271/0.5558 | Loss Ratio: 0.77 | LR: 0.000499 | Elapsed Time: 1.71 seconds
# Epoch 82: Train Acc=92.78% | Val Acc=80.93% | Loss: 0.4210/0.6893 | Loss Ratio: 0.61 | LR: 0.000498 | Elapsed Time: 1.72 seconds
# Epoch 83: Train Acc=94.39% | Val Acc=89.18% | Loss: 0.4145/0.5813 | Loss Ratio: 0.71 | LR: 0.000497 | Elapsed Time: 1.71 seconds
# Epoch 84: Train Acc=90.19% | Val Acc=87.80% | Loss: 0.4506/0.5801 | Loss Ratio: 0.78 | LR: 0.000497 | Elapsed Time: 1.72 seconds
# Epoch 85: Train Acc=93.03% | Val Acc=93.13% | Loss: 0.4102/0.5450 | Loss Ratio: 0.75 | LR: 0.000496 | Elapsed Time: 1.70 seconds
# Epoch 86: Train Acc=91.58% | Val Acc=69.59% | Loss: 0.4203/0.6364 | Loss Ratio: 0.66 | LR: 0.000495 | Elapsed Time: 1.70 seconds
# Epoch 87: Train Acc=90.49% | Val Acc=87.46% | Loss: 0.4570/0.5330 | Loss Ratio: 0.86 | LR: 0.000494 | Elapsed Time: 1.70 seconds
# Epoch 88: Train Acc=91.79% | Val Acc=93.30% | Loss: 0.4475/0.5757 | Loss Ratio: 0.78 | LR: 0.000493 | Elapsed Time: 1.72 seconds
# Epoch 89: Train Acc=91.72% | Val Acc=94.67% | Loss: 0.4280/0.5455 | Loss Ratio: 0.78 | LR: 0.000492 | Elapsed Time: 1.71 seconds
# Epoch 90: Train Acc=93.17% | Val Acc=92.96% | Loss: 0.4052/0.5392 | Loss Ratio: 0.75 | LR: 0.000491 | Elapsed Time: 1.70 seconds
# Epoch 91: Train Acc=95.34% | Val Acc=91.07% | Loss: 0.3691/0.5193 | Loss Ratio: 0.71 | LR: 0.000490 | Elapsed Time: 1.70 seconds
# Epoch 92: Train Acc=90.85% | Val Acc=83.85% | Loss: 0.4584/0.7574 | Loss Ratio: 0.61 | LR: 0.000488 | Elapsed Time: 1.71 seconds
# Epoch 93: Train Acc=92.48% | Val Acc=89.18% | Loss: 0.4163/0.5381 | Loss Ratio: 0.77 | LR: 0.000487 | Elapsed Time: 1.73 seconds
# Epoch 94: Train Acc=91.94% | Val Acc=86.25% | Loss: 0.4382/0.5696 | Loss Ratio: 0.77 | LR: 0.000486 | Elapsed Time: 1.76 seconds
# Epoch 95: Train Acc=96.76% | Val Acc=93.81% | Loss: 0.3630/0.5320 | Loss Ratio: 0.68 | LR: 0.000484 | Elapsed Time: 1.73 seconds
# Epoch 96: Train Acc=90.19% | Val Acc=71.82% | Loss: 0.4420/0.6497 | Loss Ratio: 0.68 | LR: 0.000482 | Elapsed Time: 1.72 seconds
# Epoch 97: Train Acc=92.06% | Val Acc=85.91% | Loss: 0.4164/0.7727 | Loss Ratio: 0.54 | LR: 0.000481 | Elapsed Time: 1.71 seconds
# Epoch 98: Train Acc=91.39% | Val Acc=93.30% | Loss: 0.4455/0.7079 | Loss Ratio: 0.63 | LR: 0.000479 | Elapsed Time: 1.71 seconds
# Epoch 99: Train Acc=92.39% | Val Acc=83.85% | Loss: 0.4480/0.5923 | Loss Ratio: 0.76 | LR: 0.000477 | Elapsed Time: 1.71 seconds
# Epoch 100: Train Acc=91.45% | Val Acc=89.52% | Loss: 0.4301/0.5985 | Loss Ratio: 0.72 | LR: 0.000475 | Elapsed Time: 1.75 seconds
# Epoch 101: Train Acc=91.31% | Val Acc=87.29% | Loss: 0.4496/0.6673 | Loss Ratio: 0.67 | LR: 0.000473 | Elapsed Time: 1.71 seconds
# Epoch 102: Train Acc=90.31% | Val Acc=93.30% | Loss: 0.4562/0.5387 | Loss Ratio: 0.85 | LR: 0.000471 | Elapsed Time: 1.70 seconds
# Epoch 103: Train Acc=94.58% | Val Acc=89.18% | Loss: 0.3962/0.5511 | Loss Ratio: 0.72 | LR: 0.000469 | Elapsed Time: 1.70 seconds
# Epoch 104: Train Acc=93.83% | Val Acc=89.18% | Loss: 0.3987/0.6268 | Loss Ratio: 0.64 | LR: 0.000467 | Elapsed Time: 1.71 seconds
# Epoch 105: Train Acc=90.40% | Val Acc=82.82% | Loss: 0.4512/0.7067 | Loss Ratio: 0.64 | LR: 0.000465 | Elapsed Time: 1.71 seconds
# Epoch 106: Train Acc=89.01% | Val Acc=92.96% | Loss: 0.4808/0.5324 | Loss Ratio: 0.90 | LR: 0.000462 | Elapsed Time: 1.71 seconds

# %%
# --- FINAL RESULTS ---
avg_acc = sum(all_subject_accuracies) / len(all_subject_accuracies)
print(f"\n========================================")
print(f"FINAL AVERAGE ACCURACY: {avg_acc:.2f}%")
print(f"Detailed: {all_subject_accuracies}")
print(f"========================================")
# Out:
# ========================================
# FINAL AVERAGE ACCURACY: 88.25%
# Detailed: [86.76975945017182, 93.81443298969072, 81.61512027491409, 95.01718213058419, 96.73539518900344, 91.40893470790378, 100.0, 98.96907216494846, 89.17525773195877, 90.893470790378, 63.91752577319588, 75.94501718213058, 79.55326460481099, 79.89690721649484, 100.0]
# ========================================

# %%
# --- PLOTTING ---
# 1. 5x3 Grid for individual subjects
fig, axes = plt.subplots(5, 3, figsize=(20, 15))
axes = axes.flatten()

for i, subject_id in enumerate(subjects):
    if i < len(axes):
        ax = axes[i]
        if subject_id in all_subject_histories:
            h = all_subject_histories[subject_id]
            ax.plot(h["train"], label="Train Acc")
            ax.plot(h["val"], label="Val Acc")
            ax.set_title(f"Subject {subject_id}")
            ax.set_xlabel("Epoch")
            ax.set_ylabel("Accuracy (%)")
            ax.legend()
            ax.grid(True)

plt.tight_layout()
plt.savefig("subject_accuracies.png")
print("Saved subject_accuracies.png")
plt.show()
# Out:
# Saved subject_accuracies.png

# %%
# 2. Average Plot
plt.figure(figsize=(10, 6))

# Find max epochs across all runs
max_epochs = 0
for h in all_subject_histories.values():
    max_epochs = max(max_epochs, len(h["train"]))

avg_train = []
avg_val = []

for e in range(max_epochs):
    t_vals = []
    v_vals = []
    for h in all_subject_histories.values():
        # Use last value if a subject finished early
        idx = min(e, len(h["train"]) - 1)
        t_vals.append(h["train"][idx])
        v_vals.append(h["val"][idx])

    avg_train.append(np.mean(t_vals))
    avg_val.append(np.mean(v_vals))

plt.plot(avg_train, label="Average Train Acc", linewidth=2)
plt.plot(avg_val, label="Average Val Acc", linewidth=2)
plt.title("Average Accuracy Across All Subjects")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True)
plt.savefig("average_accuracy.png")
print("Saved average_accuracy.png")
plt.show()
# Out:
# Saved average_accuracy.png
