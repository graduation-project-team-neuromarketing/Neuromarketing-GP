# %% [markdown]
# # TLDR:
# * Model: Davit
# * PreProcessing: None
# * Data: DE features
# * Balancing Technique: Weighted random sampler
# * Labels: 0 (Neutral) , 1  Negative (Sad), 2  (Fear) , 3 Positive (Happy)
# * Test Accuracy:

# %%
# !pip install torcheeg==1.1.2 scipy==1.12.0 numpy==1.26.4 -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.5/214.5 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.5/231.5 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 54.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.1/295.1 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.2/115.2 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.2/750.2 kB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 78.7 MB/s eta 0:00:00
#   Building wheel for torcheeg (setup.py) ... done
#   Building wheel for spectrum (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.12.0 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
# !git clone https://github.com/jiaowoguanren0615/DaViT-Pytorch DaViT
# Out:
# Cloning into 'DaViT'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 27 (delta 2), reused 18 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 30.26 KiB | 7.57 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler
from torcheeg import transforms
from torch.optim.lr_scheduler import CosineAnnealingLR, OneCycleLR
from torcheeg.datasets import SEEDIVFeatureDataset
from DaViT.models.davit import DaViT
from sklearn.model_selection import train_test_split
from torchvision.transforms import RandomErasing

import time
import os
import shutil
import random

import numpy as np

from torcheeg.datasets.constants import SEED_IV_CHANNEL_LOCATION_DICT

# --- THE MAIN SUBJECT LOOP ---
import numpy as np
import matplotlib.pyplot as plt

from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
# Emotiv EPOC+
target_channels = [
    "AF3",
    "AF4",
    "F7",
    "F8",
    "F3",
    "F4",
    "FC5",
    "FC6",
    "T7",
    "T8",
    "P7",
    "P8",
    "O1",
    "O2",
]

# %%
all_channels = list(SEED_IV_CHANNEL_LOCATION_DICT.keys())
target_indices = [all_channels.index(ch) for ch in target_channels]

# %%
# 1. Setup Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
# used for logging
TRIAL_NUMBER = 61

# %%
USE_GPU = 1
BATCH_SIZE = 16
DROPOUT = 0.5
ATTN_DROPOUT = 0.5
LR = 0.0005
WEIGHT_DECAY = 2e-1
EPOCHS_COUNT = 500
patience = 25

# %%
two_no_neutral = {
    0: "UNREACHABLE",  # Neutral
    1: 0,  # Sad
    2: 0,  # Fear
    3: 1,  # Happy
}

two_with_neutral = {
    0: 0,  # Neutral
    1: 0,  # Sad
    2: 0,  # Fear
    3: 1,  # Happy
}

three = {
    0: 0,  # Neutral
    1: 1,  # Sad
    2: 1,  # Fear
    3: 2,  # Happy
}

four = {
    0: 0,  # Neutral
    1: 1,  # Sad
    2: 2,  # Fear
    3: 3,  # Happy
}

emotions_table = two_with_neutral

# %%
class RemapLabel:
    def __call__(self, y):
        return {"y": emotions_table[y]}

# %%
# io_path = "/home/omar/external/python/eeg-emotion/tmp_out/seed_iv_feautres"
# root_path = "./SEED-IV/eeg_feature_smooth/"

io_path= f"./tmp_out/seed_iv_features_{TRIAL_NUMBER}"
root_path = "/kaggle/input/seed-iv/eeg_feature_smooth"

# %%
# 3. Load Data
dataset = SEEDIVFeatureDataset(
    # io_path=io_path,
    root_path=root_path,
    feature=["de_LDS"],
    num_worker=4,
    offline_transform=transforms.Compose(
        [
            # transforms.PickElectrode(target_indices),
            transforms.To2d(),
            transforms.ToTensor(),
        ]
    ),
    label_transform=transforms.Compose(
        [
            transforms.Select("emotion"),
            RemapLabel(),
        ]
    ),
    online_transform=transforms.Compose([transforms.MeanStdNormalize()]),
    io_mode="memory",
)
# Out:
# [2026-02-19 01:52:56] INFO (torcheeg/MainThread) 🔍 | Processing EEG data. Processed EEG data has been cached to .torcheeg/datasets_1771465976893_NbrnT.
# [2026-02-19 01:52:56] INFO (torcheeg/MainThread) ⏳ | Monitoring the detailed processing of a record for debugging. The processing of other records will only be reported in percentage to keep it clean.
# [PROCESS]:   0%|          | 0/45 [00:00<?, ?it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 0it [00:00, ?it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 1it [00:00,  4.13it/s]
# [RECORD /kaggle/input/seed-iv/eeg_feature_smooth/1/4_20151111.mat]: 804it [00:00, 2981.04it/s]
# [PROCESS]: 100%|██████████| 45/45 [00:10<00:00,  4.11it/s]

# %%
# 1. Get the metadata DataFrame
df = dataset.info

# 2. Count the segments for each emotion
# 0: Neutral, 1: Sad, 2: Fear, 3: Happy
counts = df["emotion"].value_counts().sort_index()
total = len(df)

print(f"Total Segments: {total}")
print("-" * 30)
print("Count per Emotion:")
print(counts)

print("-" * 30)
print("Percentage per Emotion:")
percentages = (counts / total) * 100
print(percentages.round(2))

# 3. Check for Imbalance
# If the difference between max and min is > 10%, we might need a WeightedSampler
max_pct = percentages.max()
min_pct = percentages.min()

if (max_pct - min_pct) > 10:
    print(f"\n⚠️ WARNING: Data is IMBALANCED (Diff: {max_pct - min_pct:.2f}%)")
    print("Consider using a WeightedRandomSampler.")
else:
    print(f"\n✅ Data is reasonably BALANCED (Diff: {max_pct - min_pct:.2f}%)")
# Out:
# Total Segments: 37575
# ------------------------------
# Count per Emotion:
# emotion
# 0    10170
# 1    10245
# 2     9225
# 3     7935
# Name: count, dtype: int64
# ------------------------------
# Percentage per Emotion:
# emotion
# 0    27.07
# 1    27.27
# 2    24.55
# 3    21.12
# Name: count, dtype: float64
#
# ✅ Data is reasonably BALANCED (Diff: 6.15%)

# %%
# 4. Check Data Shape & Setup Model
# We fetch one sample to determine input channels and dimensions
# (using the whole dataset for detection is fine as shape is consistent)
temp_loader = DataLoader(dataset, batch_size=1, shuffle=False)
temp_X, _ = next(iter(temp_loader))
input_channels = temp_X.shape[1]
print(f"Detected Input Shape: {temp_X.shape}")
print(f"Setting model in_chans to: {input_channels}")
# Out:
# Detected Input Shape: torch.Size([1, 1, 62, 5])
# Setting model in_chans to: 1

# %%
def DaViT_eeg(
    pretrained=False, pretrained_cfg=None, pretrained_cfg_overlay=None, **kwargs
):
    model_kwargs = dict(
        patch_size=4,
        in_chans=input_channels,
        window_size=3,
        # Restoring "Tiny" dimensions (User has VRAM headroom)
        # embed_dims=(96, 192, 384, 768),
        # num_heads=(3, 6, 12, 24),
        embed_dims=(64, 128, 256, 512),
        num_heads=(2, 4, 8, 16),
        depths=(1, 1, 1, 1),
        mlp_ratio=4.0,
        overlapped_patch=False,
        num_classes=kwargs.get("_num_classes", 4),
        drop_rate=kwargs.get("dropout", 0.5),
        attn_drop_rate=kwargs.get("attn_dropout", 0.5),
        drop_path_rate=0.3, # Add Stochastic Depth
        **kwargs,
    )

    return DaViT(**model_kwargs)

# model = DaViT_eeg(dropout=dropout, attn_dropout=attn_dropout).to(device)

# %%
subjects = sorted(dataset.info["subject_id"].unique())  # Get list of all 15 subjects

# %%
# --- MIXUP HELPER FUNCTIONS ---
def mixup_data(x, y, alpha=1.0):
    """
    Applies Mixup augmentation to a batch of data.
    
    Logic:
    1. Generate a mixing coefficient (lambda) from a Beta(alpha, alpha) distribution.
       - If alpha is close to 0, lambda is close to 0 or 1 (little mixing).
       - If alpha is large, lambda is close to 0.5 (strong mixing).
    2. Shuffle the batch indices to get a "partner" for every sample.
    3. Create a new "mixed" input: mixed_x = lambda * x + (1 - lambda) * x[shuffled_indices]
    
    Returns:
        mixed_x: The blended input tensor.
        y_a: The original labels.
        y_b: The labels of the shuffled samples.
        lam: The mixing coefficient used.
    """
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(device)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    """
    Calculates the Mixup loss.
    
    Since the input was a mix of two samples (A and B) with weight lambda:
    Loss = lambda * Loss(pred, Label_A) + (1 - lambda) * Loss(pred, Label_B)
    """
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
# Initialize Random Erasing
# p=0.5: 50% chance to apply
# scale=(0.02, 0.25): Erase smaller chunks to avoid killing too much info
# ratio=(0.05, 20.0):
#   - 0.05 means aspect ratio 1:20 (Very wide/flat, erasing a specific band across many channels)
#   - 20.0 means aspect ratio 20:1 (Very tall/thin, erasing all bands for a few channels)
# This flexibility suits the 62x5 shape much better than the default (0.3, 3.3).

train_transforms = transforms.Compose([
    transforms.RandomMask(p=0.2),
    transforms.RandomNoise(p=0.1),
])

# %%
all_subject_accuracies = []
all_subject_histories = {}
for subject_id in subjects:
    print("\n========================================")
    print(f"  PROCESSING SUBJECT: {subject_id}")
    print("========================================")

    # 1. Filter Data for this Subject
    sub_df = dataset.info[dataset.info["subject_id"] == subject_id]

    # 2. Split by Unique Video (Session + Trial) for this subject
    # CRITICAL: We cannot just split by 'trial_id' because Trial 1 in Session 1 (Sad)
    # is different from Trial 1 in Session 2 (Fear). We must treat them as separate videos.

    # Create a unique ID for every video: "session_trial" (e.g., "1_5", "2_5", "3_5")
    sub_df = sub_df.copy()  # Avoid SettingWithCopy warning
    sub_df["unique_run_id"] = (
        sub_df["session_id"].astype(str) + "_" + sub_df["trial_id"].astype(str)
    )

    # Extract labels per unique run to ensure balanced split
    # We get a single label for each unique run (session_trial)
    # Since every segment in a trial has same label, we just drop duplicates
    run_info = sub_df[["unique_run_id", "emotion"]].drop_duplicates()
    all_runs = run_info["unique_run_id"].values
    all_labels = run_info["emotion"].values

    # Stratified Split at the RUN level
    # This keeps 80/20 ratio and ensures each class is represented in the test set
    train_runs, test_runs = train_test_split(
        all_runs, test_size=0.20, random_state=42, stratify=all_labels
    )

    print(f"Total Unique Videos (Across 3 Sessions): {len(all_runs)}")
    print(f"Training on: {len(train_runs)} | Testing on: {len(test_runs)}")

    # Extract indices (Zero Leakage Guaranteed)
    train_indices = sub_df[sub_df["unique_run_id"].isin(train_runs)].index.tolist()
    test_indices = sub_df[sub_df["unique_run_id"].isin(test_runs)].index.tolist()

    train_set = Subset(dataset, train_indices)
    test_set = Subset(dataset, test_indices)

    y_train_indices = train_set.indices
    raw_labels = dataset.info.iloc[y_train_indices]["emotion"].values

    # 3. Create Specific Sampler for this Subject
    # class_counts = np.bincount(raw_labels)
    # class_weights = 1.0 / class_counts
    # print(class_weights)
    # sample_weights = [class_weights[y] for y in raw_labels]

    mapped_labels = [emotions_table[y] for y in raw_labels]
    class_counts = np.bincount(mapped_labels)
    classes_ = np.unique(mapped_labels)
    # class_weights = 1.0 / class_counts
    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=classes_,
        y=mapped_labels,
    )
    print(class_weights)
    
    # sample_weights = [class_weights[y] for y in mapped_labels]
    # sampler = WeightedRandomSampler(
    #     weights=sample_weights, num_samples=len(sample_weights), replacement=True
    # )

    # 4. Loaders
    train_loader = DataLoader(
        train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=0
    )
    test_loader = DataLoader(
        test_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=0
    )
    train_count = len(train_loader)
    test_count = len(test_loader)

    # 5. FRESH Model & Optimizer (Reset for every subject)
    model = DaViT_eeg(dropout=DROPOUT, attn_dropout=ATTN_DROPOUT, _num_classes=len(class_weights)).to(
        device
    )

    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    # Cosine Annealing: Smoothly drops LR from 0.0001 -> 0 over EPOCHS_COUNT
    # This forces the model to settle into the best accuracy at the end
    # scheduler = CosineAnnealingLR(optimizer, T_max=EPOCHS_COUNT, eta_min=1e-6)

    # OneCycleLR is better for transformers (Warmup + Annealing)
    scheduler = OneCycleLR(
        optimizer,
        max_lr=LR,
        epochs=EPOCHS_COUNT,
        steps_per_epoch=len(train_loader),
        pct_start=0.3,  # 30% warmup
        div_factor=10,
        final_div_factor=1000,
    )
    criterion = nn.CrossEntropyLoss(
        weight=torch.tensor(class_weights).to(device).float(), label_smoothing=0.1
    )
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    # 6. Training Loop for this Subject
    best_acc = 0.0
    best_tacc = 0.0
    best_loss = float('inf')
    counter = 0        

    subject_train_acc = []
    subject_val_acc = []
    prinT = 0


    
    # --- MAIN LOOP EXTENSION ---
    for epoch in range(EPOCHS_COUNT):  # 40 epochs is usually enough for 1 subject
        startTime = time.time()
        model.train()
        train_loss = 0
        correct = 0
        total = 0



        for batch in train_loader:
            X, y = batch
            # Augmentation:
            X = train_transforms(eeg=X)['eeg']

            if prinT:
                print(f"X: {X.shape},y: {y.shape}")
                prinT = 0

            X = X.to(device)
            y = y.to(device).long()

            # 2. Apply Mixup
            X, y_a, y_b, lam = mixup_data(X, y, alpha=0.6)
            X, y_a, y_b = map(torch.autograd.Variable, (X, y_a, y_b))

            optimizer.zero_grad()
            outputs = model(X)

            # 3. Use Mixup Loss
            loss = mixup_criterion(criterion, outputs, y_a, y_b, lam)
            loss.backward()
            optimizer.step()

            # For accuracy, we just compare against the dominant label (or y_a)
            # Mixup creates "soft" accuracy, but standard accuracy is fine for logging
            _, predicted = torch.max(outputs.data, 1)
            total += y.size(0)
            correct += (
                lam * predicted.eq(y_a.data).cpu().sum().float()
                + (1 - lam) * predicted.eq(y_b.data).cpu().sum().float()
            ).item()
            # scheduler step for OneCycleLR is per batch
            scheduler.step()
            train_loss += loss.item()

        train_acc = (correct / total) * 100
        avg_train_loss = train_loss / train_count

        # Validation
        model.eval()
        val_correct = 0
        val_total = 0
        val_loss = 0
        with torch.no_grad():
            for batch in test_loader:
                X, y = batch

                X = X.to(device)
                y = y.to(device).long()

                output = model(X)

                loss = criterion(output, y)
                val_loss += loss.item()
                _, predicted = torch.max(output.data, 1)
                val_total += y.size(0)
                val_correct += (predicted == y).sum().item()

        val_acc = 100 * val_correct / val_total
        avg_val_loss = val_loss / test_count
        current_lr = optimizer.param_groups[0]["lr"]
        elabsedTime = time.time() - startTime
        loss_ratio = avg_train_loss / avg_val_loss
        subject_train_acc.append(train_acc)
        subject_val_acc.append(val_acc)            

        # Early Stopping check (Monitor Validation Loss)
        is_best_acc = False
        if  (val_acc > best_acc) or (
            (best_acc - val_acc) <= 0.5 and train_acc >= best_tacc ):
            is_best_acc = True
            best_acc = val_acc
            best_tacc = train_acc
            counter = 0
            
        else:
            counter += 1
            if counter >= patience:
                break

        print(
            f"Epoch {epoch + 1}: Train Acc={train_acc:.2f}% | Val Acc={val_acc:.2f}% | Loss: {avg_train_loss:.4f}/{avg_val_loss:.4f} | Loss Ratio: {loss_ratio:.2f} | LR: {current_lr:.6f} | Elapsed Time: {elabsedTime:.2f} seconds {'[BEST ACC]' if is_best_acc else ''}"
        )

    all_subject_accuracies.append(best_acc)
    all_subject_histories[subject_id] = {
        "train": subject_train_acc,
        "val": subject_val_acc,
    }
# Out:
# ========================================
#   PROCESSING SUBJECT: 1
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=45.21% | Val Acc=24.05% | Loss: 0.7821/0.8632 | Loss Ratio: 0.91 | LR: 0.000050 | Elapsed Time: 5.70 seconds [BEST ACC]
# Epoch 2: Train Acc=48.70% | Val Acc=24.05% | Loss: 0.7334/0.8082 | Loss Ratio: 0.91 | LR: 0.000050 | Elapsed Time: 4.97 seconds [BEST ACC]
# Epoch 3: Train Acc=49.25% | Val Acc=62.20% | Loss: 0.7372/0.7596 | Loss Ratio: 0.97 | LR: 0.000050 | Elapsed Time: 4.83 seconds [BEST ACC]
# Epoch 4: Train Acc=59.33% | Val Acc=62.03% | Loss: 0.6960/0.7760 | Loss Ratio: 0.90 | LR: 0.000051 | Elapsed Time: 4.86 seconds [BEST ACC]
# Epoch 5: Train Acc=59.20% | Val Acc=65.46% | Loss: 0.7055/0.7731 | Loss Ratio: 0.91 | LR: 0.000051 | Elapsed Time: 4.86 seconds [BEST ACC]
# Epoch 6: Train Acc=65.42% | Val Acc=78.01% | Loss: 0.6681/0.7153 | Loss Ratio: 0.93 | LR: 0.000052 | Elapsed Time: 4.89 seconds [BEST ACC]
# Epoch 7: Train Acc=67.40% | Val Acc=71.13% | Loss: 0.6587/0.7340 | Loss Ratio: 0.90 | LR: 0.000052 | Elapsed Time: 4.86 seconds
# Epoch 8: Train Acc=72.50% | Val Acc=78.69% | Loss: 0.6086/0.6845 | Loss Ratio: 0.89 | LR: 0.000053 | Elapsed Time: 4.87 seconds [BEST ACC]
# Epoch 9: Train Acc=69.90% | Val Acc=81.96% | Loss: 0.6170/0.7988 | Loss Ratio: 0.77 | LR: 0.000054 | Elapsed Time: 4.81 seconds [BEST ACC]
# Epoch 10: Train Acc=71.50% | Val Acc=81.96% | Loss: 0.6223/0.6403 | Loss Ratio: 0.97 | LR: 0.000055 | Elapsed Time: 4.86 seconds [BEST ACC]
# Epoch 11: Train Acc=76.60% | Val Acc=77.49% | Loss: 0.5688/0.7418 | Loss Ratio: 0.77 | LR: 0.000056 | Elapsed Time: 4.79 seconds
# Epoch 12: Train Acc=79.60% | Val Acc=76.29% | Loss: 0.5508/0.7827 | Loss Ratio: 0.70 | LR: 0.000057 | Elapsed Time: 4.82 seconds
# Epoch 13: Train Acc=80.35% | Val Acc=73.02% | Loss: 0.5496/0.7810 | Loss Ratio: 0.70 | LR: 0.000058 | Elapsed Time: 4.85 seconds
# Epoch 14: Train Acc=80.53% | Val Acc=73.02% | Loss: 0.5319/0.7912 | Loss Ratio: 0.67 | LR: 0.000060 | Elapsed Time: 4.89 seconds
# Epoch 15: Train Acc=82.92% | Val Acc=73.02% | Loss: 0.5358/0.7465 | Loss Ratio: 0.72 | LR: 0.000061 | Elapsed Time: 4.82 seconds
# Epoch 16: Train Acc=78.88% | Val Acc=73.02% | Loss: 0.5527/0.7839 | Loss Ratio: 0.71 | LR: 0.000063 | Elapsed Time: 4.89 seconds
# Epoch 17: Train Acc=79.32% | Val Acc=73.02% | Loss: 0.5433/0.7749 | Loss Ratio: 0.70 | LR: 0.000064 | Elapsed Time: 4.85 seconds
# Epoch 18: Train Acc=83.25% | Val Acc=81.96% | Loss: 0.4996/0.6268 | Loss Ratio: 0.80 | LR: 0.000066 | Elapsed Time: 4.91 seconds [BEST ACC]
# Epoch 19: Train Acc=84.62% | Val Acc=81.96% | Loss: 0.5086/0.7159 | Loss Ratio: 0.71 | LR: 0.000068 | Elapsed Time: 4.89 seconds [BEST ACC]
# Epoch 20: Train Acc=84.61% | Val Acc=78.52% | Loss: 0.5169/0.6661 | Loss Ratio: 0.78 | LR: 0.000069 | Elapsed Time: 4.92 seconds
# Epoch 21: Train Acc=82.30% | Val Acc=77.49% | Loss: 0.5175/0.6465 | Loss Ratio: 0.80 | LR: 0.000071 | Elapsed Time: 4.89 seconds
# Epoch 22: Train Acc=81.06% | Val Acc=81.96% | Loss: 0.5338/0.6890 | Loss Ratio: 0.77 | LR: 0.000073 | Elapsed Time: 4.86 seconds
# Epoch 23: Train Acc=78.68% | Val Acc=73.02% | Loss: 0.5316/0.8078 | Loss Ratio: 0.66 | LR: 0.000076 | Elapsed Time: 4.81 seconds
# Epoch 24: Train Acc=83.81% | Val Acc=76.12% | Loss: 0.5045/0.6801 | Loss Ratio: 0.74 | LR: 0.000078 | Elapsed Time: 4.87 seconds
# Epoch 25: Train Acc=80.15% | Val Acc=73.37% | Loss: 0.5272/0.7005 | Loss Ratio: 0.75 | LR: 0.000080 | Elapsed Time: 4.83 seconds
# Epoch 26: Train Acc=82.46% | Val Acc=83.51% | Loss: 0.5180/0.6206 | Loss Ratio: 0.83 | LR: 0.000083 | Elapsed Time: 4.90 seconds [BEST ACC]
# Epoch 27: Train Acc=78.51% | Val Acc=69.93% | Loss: 0.5313/0.9050 | Loss Ratio: 0.59 | LR: 0.000085 | Elapsed Time: 4.80 seconds
# Epoch 28: Train Acc=77.63% | Val Acc=73.02% | Loss: 0.5357/0.8118 | Loss Ratio: 0.66 | LR: 0.000088 | Elapsed Time: 4.84 seconds
# Epoch 29: Train Acc=85.34% | Val Acc=73.02% | Loss: 0.5008/0.6920 | Loss Ratio: 0.72 | LR: 0.000090 | Elapsed Time: 4.78 seconds
# Epoch 30: Train Acc=77.42% | Val Acc=73.02% | Loss: 0.5258/0.7161 | Loss Ratio: 0.73 | LR: 0.000093 | Elapsed Time: 4.81 seconds
# Epoch 31: Train Acc=83.11% | Val Acc=73.02% | Loss: 0.5136/0.6886 | Loss Ratio: 0.75 | LR: 0.000096 | Elapsed Time: 4.87 seconds
# Epoch 32: Train Acc=79.54% | Val Acc=76.29% | Loss: 0.5341/0.6767 | Loss Ratio: 0.79 | LR: 0.000099 | Elapsed Time: 4.85 seconds
# Epoch 33: Train Acc=79.20% | Val Acc=86.77% | Loss: 0.5356/0.6184 | Loss Ratio: 0.87 | LR: 0.000102 | Elapsed Time: 4.90 seconds [BEST ACC]
# Epoch 34: Train Acc=81.72% | Val Acc=73.02% | Loss: 0.5269/0.7842 | Loss Ratio: 0.67 | LR: 0.000105 | Elapsed Time: 4.83 seconds
# Epoch 35: Train Acc=78.48% | Val Acc=73.02% | Loss: 0.5405/1.0220 | Loss Ratio: 0.53 | LR: 0.000108 | Elapsed Time: 4.84 seconds
# Epoch 36: Train Acc=80.88% | Val Acc=68.90% | Loss: 0.5309/0.7502 | Loss Ratio: 0.71 | LR: 0.000111 | Elapsed Time: 4.80 seconds
# Epoch 37: Train Acc=79.32% | Val Acc=73.02% | Loss: 0.5346/0.8792 | Loss Ratio: 0.61 | LR: 0.000114 | Elapsed Time: 4.86 seconds
# Epoch 38: Train Acc=78.50% | Val Acc=76.29% | Loss: 0.5445/0.6277 | Loss Ratio: 0.87 | LR: 0.000118 | Elapsed Time: 4.81 seconds
# Epoch 39: Train Acc=83.86% | Val Acc=73.02% | Loss: 0.5111/0.7149 | Loss Ratio: 0.71 | LR: 0.000121 | Elapsed Time: 4.92 seconds
# Epoch 40: Train Acc=81.10% | Val Acc=73.02% | Loss: 0.5016/0.6724 | Loss Ratio: 0.75 | LR: 0.000124 | Elapsed Time: 4.82 seconds
# Epoch 41: Train Acc=79.47% | Val Acc=77.66% | Loss: 0.5189/0.7741 | Loss Ratio: 0.67 | LR: 0.000128 | Elapsed Time: 4.86 seconds
# Epoch 42: Train Acc=83.89% | Val Acc=79.73% | Loss: 0.5082/0.6397 | Loss Ratio: 0.79 | LR: 0.000132 | Elapsed Time: 4.80 seconds
# Epoch 43: Train Acc=79.66% | Val Acc=73.02% | Loss: 0.5173/0.8281 | Loss Ratio: 0.62 | LR: 0.000135 | Elapsed Time: 4.86 seconds
# Epoch 44: Train Acc=79.76% | Val Acc=73.02% | Loss: 0.5278/0.7548 | Loss Ratio: 0.70 | LR: 0.000139 | Elapsed Time: 4.83 seconds
# Epoch 45: Train Acc=81.46% | Val Acc=69.93% | Loss: 0.5349/0.7600 | Loss Ratio: 0.70 | LR: 0.000143 | Elapsed Time: 4.80 seconds
# Epoch 46: Train Acc=81.56% | Val Acc=75.43% | Loss: 0.5247/0.7216 | Loss Ratio: 0.73 | LR: 0.000147 | Elapsed Time: 4.79 seconds
# Epoch 47: Train Acc=80.41% | Val Acc=73.02% | Loss: 0.5193/0.7701 | Loss Ratio: 0.67 | LR: 0.000150 | Elapsed Time: 4.89 seconds
# Epoch 48: Train Acc=81.02% | Val Acc=63.75% | Loss: 0.5101/0.8633 | Loss Ratio: 0.59 | LR: 0.000154 | Elapsed Time: 4.80 seconds
# Epoch 49: Train Acc=82.61% | Val Acc=73.02% | Loss: 0.5060/0.7130 | Loss Ratio: 0.71 | LR: 0.000158 | Elapsed Time: 4.82 seconds
# Epoch 50: Train Acc=81.82% | Val Acc=73.02% | Loss: 0.4991/0.7040 | Loss Ratio: 0.71 | LR: 0.000163 | Elapsed Time: 4.78 seconds
# Epoch 51: Train Acc=80.42% | Val Acc=78.01% | Loss: 0.5069/0.6213 | Loss Ratio: 0.82 | LR: 0.000167 | Elapsed Time: 4.86 seconds
# Epoch 52: Train Acc=78.71% | Val Acc=73.02% | Loss: 0.5186/0.6474 | Loss Ratio: 0.80 | LR: 0.000171 | Elapsed Time: 4.81 seconds
# Epoch 53: Train Acc=81.00% | Val Acc=59.28% | Loss: 0.5257/0.9037 | Loss Ratio: 0.58 | LR: 0.000175 | Elapsed Time: 4.85 seconds
# Epoch 54: Train Acc=75.55% | Val Acc=73.02% | Loss: 0.5571/0.7090 | Loss Ratio: 0.79 | LR: 0.000179 | Elapsed Time: 4.81 seconds
# Epoch 55: Train Acc=77.72% | Val Acc=73.02% | Loss: 0.5262/0.7095 | Loss Ratio: 0.74 | LR: 0.000183 | Elapsed Time: 4.84 seconds
# Epoch 56: Train Acc=82.39% | Val Acc=82.13% | Loss: 0.4934/0.6397 | Loss Ratio: 0.77 | LR: 0.000188 | Elapsed Time: 4.79 seconds
# Epoch 57: Train Acc=84.03% | Val Acc=71.65% | Loss: 0.4910/0.6262 | Loss Ratio: 0.78 | LR: 0.000192 | Elapsed Time: 4.85 seconds
#
# ========================================
#   PROCESSING SUBJECT: 2
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=53.64% | Val Acc=26.80% | Loss: 0.7586/0.7935 | Loss Ratio: 0.96 | LR: 0.000050 | Elapsed Time: 4.80 seconds [BEST ACC]
# Epoch 2: Train Acc=58.52% | Val Acc=75.26% | Loss: 0.6930/0.6993 | Loss Ratio: 0.99 | LR: 0.000050 | Elapsed Time: 4.73 seconds [BEST ACC]
# Epoch 3: Train Acc=67.34% | Val Acc=80.58% | Loss: 0.6691/0.7869 | Loss Ratio: 0.85 | LR: 0.000050 | Elapsed Time: 4.69 seconds [BEST ACC]
# Epoch 4: Train Acc=70.04% | Val Acc=80.58% | Loss: 0.6389/0.6251 | Loss Ratio: 1.02 | LR: 0.000051 | Elapsed Time: 4.96 seconds [BEST ACC]
# Epoch 5: Train Acc=76.06% | Val Acc=80.58% | Loss: 0.5951/0.7452 | Loss Ratio: 0.80 | LR: 0.000051 | Elapsed Time: 4.71 seconds [BEST ACC]
# Epoch 6: Train Acc=75.68% | Val Acc=91.07% | Loss: 0.6042/0.5346 | Loss Ratio: 1.13 | LR: 0.000052 | Elapsed Time: 4.68 seconds [BEST ACC]
# Epoch 7: Train Acc=78.23% | Val Acc=70.96% | Loss: 0.5740/0.6608 | Loss Ratio: 0.87 | LR: 0.000052 | Elapsed Time: 4.65 seconds
# Epoch 8: Train Acc=81.42% | Val Acc=84.54% | Loss: 0.5478/0.5589 | Loss Ratio: 0.98 | LR: 0.000053 | Elapsed Time: 4.66 seconds
# Epoch 9: Train Acc=85.83% | Val Acc=84.36% | Loss: 0.5054/0.4831 | Loss Ratio: 1.05 | LR: 0.000054 | Elapsed Time: 4.71 seconds
# Epoch 10: Train Acc=80.77% | Val Acc=68.90% | Loss: 0.5581/0.6576 | Loss Ratio: 0.85 | LR: 0.000055 | Elapsed Time: 4.68 seconds
# Epoch 11: Train Acc=80.75% | Val Acc=60.31% | Loss: 0.5502/0.7497 | Loss Ratio: 0.73 | LR: 0.000056 | Elapsed Time: 4.64 seconds
# Epoch 12: Train Acc=82.36% | Val Acc=91.75% | Loss: 0.5539/0.4816 | Loss Ratio: 1.15 | LR: 0.000057 | Elapsed Time: 4.73 seconds [BEST ACC]
# Epoch 13: Train Acc=85.98% | Val Acc=70.45% | Loss: 0.5055/0.6216 | Loss Ratio: 0.81 | LR: 0.000058 | Elapsed Time: 4.57 seconds
# Epoch 14: Train Acc=80.06% | Val Acc=100.00% | Loss: 0.5530/0.4307 | Loss Ratio: 1.28 | LR: 0.000060 | Elapsed Time: 4.66 seconds [BEST ACC]
# Epoch 15: Train Acc=79.68% | Val Acc=74.57% | Loss: 0.5502/0.7054 | Loss Ratio: 0.78 | LR: 0.000061 | Elapsed Time: 4.63 seconds
# Epoch 16: Train Acc=86.26% | Val Acc=78.35% | Loss: 0.4999/0.5142 | Loss Ratio: 0.97 | LR: 0.000063 | Elapsed Time: 4.68 seconds
# Epoch 17: Train Acc=82.66% | Val Acc=67.18% | Loss: 0.5364/0.6810 | Loss Ratio: 0.79 | LR: 0.000064 | Elapsed Time: 4.60 seconds
# Epoch 18: Train Acc=82.62% | Val Acc=94.16% | Loss: 0.5201/0.4804 | Loss Ratio: 1.08 | LR: 0.000066 | Elapsed Time: 4.64 seconds
# Epoch 19: Train Acc=82.71% | Val Acc=75.95% | Loss: 0.5271/0.5935 | Loss Ratio: 0.89 | LR: 0.000068 | Elapsed Time: 4.65 seconds
# Epoch 20: Train Acc=85.54% | Val Acc=85.91% | Loss: 0.5036/0.5167 | Loss Ratio: 0.97 | LR: 0.000069 | Elapsed Time: 4.71 seconds
# Epoch 21: Train Acc=83.99% | Val Acc=87.80% | Loss: 0.5221/0.5204 | Loss Ratio: 1.00 | LR: 0.000071 | Elapsed Time: 4.61 seconds
# Epoch 22: Train Acc=85.28% | Val Acc=71.82% | Loss: 0.5070/0.6157 | Loss Ratio: 0.82 | LR: 0.000073 | Elapsed Time: 4.65 seconds
# Epoch 23: Train Acc=85.46% | Val Acc=100.00% | Loss: 0.5144/0.4611 | Loss Ratio: 1.12 | LR: 0.000076 | Elapsed Time: 4.70 seconds [BEST ACC]
# Epoch 24: Train Acc=84.88% | Val Acc=84.54% | Loss: 0.5178/0.6120 | Loss Ratio: 0.85 | LR: 0.000078 | Elapsed Time: 4.70 seconds
# Epoch 25: Train Acc=84.99% | Val Acc=65.12% | Loss: 0.5126/0.6615 | Loss Ratio: 0.77 | LR: 0.000080 | Elapsed Time: 4.73 seconds
# Epoch 26: Train Acc=85.27% | Val Acc=64.26% | Loss: 0.5199/0.7582 | Loss Ratio: 0.69 | LR: 0.000083 | Elapsed Time: 4.70 seconds
# Epoch 27: Train Acc=86.39% | Val Acc=89.35% | Loss: 0.5018/0.4961 | Loss Ratio: 1.01 | LR: 0.000085 | Elapsed Time: 4.74 seconds
# Epoch 28: Train Acc=83.38% | Val Acc=78.35% | Loss: 0.5095/0.5566 | Loss Ratio: 0.92 | LR: 0.000088 | Elapsed Time: 4.69 seconds
# Epoch 29: Train Acc=84.75% | Val Acc=86.77% | Loss: 0.5123/0.4941 | Loss Ratio: 1.04 | LR: 0.000090 | Elapsed Time: 4.71 seconds
# Epoch 30: Train Acc=84.80% | Val Acc=84.36% | Loss: 0.5110/0.5060 | Loss Ratio: 1.01 | LR: 0.000093 | Elapsed Time: 4.68 seconds
# Epoch 31: Train Acc=85.00% | Val Acc=82.82% | Loss: 0.5112/0.5640 | Loss Ratio: 0.91 | LR: 0.000096 | Elapsed Time: 4.65 seconds
# Epoch 32: Train Acc=85.08% | Val Acc=71.65% | Loss: 0.5162/0.6452 | Loss Ratio: 0.80 | LR: 0.000099 | Elapsed Time: 4.59 seconds
# Epoch 33: Train Acc=83.78% | Val Acc=54.12% | Loss: 0.5127/1.0007 | Loss Ratio: 0.51 | LR: 0.000102 | Elapsed Time: 4.60 seconds
# Epoch 34: Train Acc=82.73% | Val Acc=61.86% | Loss: 0.5375/0.6658 | Loss Ratio: 0.81 | LR: 0.000105 | Elapsed Time: 4.67 seconds
# Epoch 35: Train Acc=85.84% | Val Acc=69.24% | Loss: 0.5011/0.5726 | Loss Ratio: 0.88 | LR: 0.000108 | Elapsed Time: 4.67 seconds
# Epoch 36: Train Acc=84.47% | Val Acc=68.21% | Loss: 0.5099/0.5972 | Loss Ratio: 0.85 | LR: 0.000111 | Elapsed Time: 4.67 seconds
# Epoch 37: Train Acc=86.89% | Val Acc=62.37% | Loss: 0.4855/0.6887 | Loss Ratio: 0.70 | LR: 0.000114 | Elapsed Time: 4.66 seconds
# Epoch 38: Train Acc=86.47% | Val Acc=83.68% | Loss: 0.4984/0.5473 | Loss Ratio: 0.91 | LR: 0.000118 | Elapsed Time: 4.67 seconds
# Epoch 39: Train Acc=84.28% | Val Acc=67.87% | Loss: 0.5063/0.5797 | Loss Ratio: 0.87 | LR: 0.000121 | Elapsed Time: 4.66 seconds
# Epoch 40: Train Acc=85.24% | Val Acc=100.00% | Loss: 0.4980/0.4414 | Loss Ratio: 1.13 | LR: 0.000124 | Elapsed Time: 4.63 seconds
# Epoch 41: Train Acc=85.55% | Val Acc=63.23% | Loss: 0.5074/0.6061 | Loss Ratio: 0.84 | LR: 0.000128 | Elapsed Time: 4.60 seconds
# Epoch 42: Train Acc=83.88% | Val Acc=81.44% | Loss: 0.5135/0.5453 | Loss Ratio: 0.94 | LR: 0.000132 | Elapsed Time: 4.67 seconds
# Epoch 43: Train Acc=89.06% | Val Acc=78.01% | Loss: 0.4746/0.5529 | Loss Ratio: 0.86 | LR: 0.000135 | Elapsed Time: 4.61 seconds
# Epoch 44: Train Acc=84.76% | Val Acc=100.00% | Loss: 0.5063/0.4321 | Loss Ratio: 1.17 | LR: 0.000139 | Elapsed Time: 4.67 seconds
# Epoch 45: Train Acc=79.68% | Val Acc=87.80% | Loss: 0.5504/0.5186 | Loss Ratio: 1.06 | LR: 0.000143 | Elapsed Time: 4.68 seconds
# Epoch 46: Train Acc=85.62% | Val Acc=69.24% | Loss: 0.5054/0.5953 | Loss Ratio: 0.85 | LR: 0.000147 | Elapsed Time: 4.67 seconds
# Epoch 47: Train Acc=79.69% | Val Acc=91.41% | Loss: 0.5343/0.5301 | Loss Ratio: 1.01 | LR: 0.000150 | Elapsed Time: 4.65 seconds
#
# ========================================
#   PROCESSING SUBJECT: 3
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=51.74% | Val Acc=52.41% | Loss: 0.7720/0.8256 | Loss Ratio: 0.94 | LR: 0.000050 | Elapsed Time: 4.63 seconds [BEST ACC]
# Epoch 2: Train Acc=58.08% | Val Acc=58.76% | Loss: 0.7062/0.7453 | Loss Ratio: 0.95 | LR: 0.000050 | Elapsed Time: 4.59 seconds [BEST ACC]
# Epoch 3: Train Acc=61.73% | Val Acc=75.95% | Loss: 0.6842/0.7155 | Loss Ratio: 0.96 | LR: 0.000050 | Elapsed Time: 4.71 seconds [BEST ACC]
# Epoch 4: Train Acc=67.63% | Val Acc=81.62% | Loss: 0.6465/0.6406 | Loss Ratio: 1.01 | LR: 0.000051 | Elapsed Time: 4.64 seconds [BEST ACC]
# Epoch 5: Train Acc=68.92% | Val Acc=59.97% | Loss: 0.6563/0.6985 | Loss Ratio: 0.94 | LR: 0.000051 | Elapsed Time: 4.65 seconds
# Epoch 6: Train Acc=73.03% | Val Acc=87.11% | Loss: 0.6142/0.5953 | Loss Ratio: 1.03 | LR: 0.000052 | Elapsed Time: 4.71 seconds [BEST ACC]
# Epoch 7: Train Acc=74.63% | Val Acc=87.11% | Loss: 0.6088/0.6020 | Loss Ratio: 1.01 | LR: 0.000052 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 8: Train Acc=78.92% | Val Acc=87.11% | Loss: 0.5778/0.6053 | Loss Ratio: 0.95 | LR: 0.000053 | Elapsed Time: 4.69 seconds [BEST ACC]
# Epoch 9: Train Acc=79.29% | Val Acc=87.11% | Loss: 0.5635/0.5906 | Loss Ratio: 0.95 | LR: 0.000054 | Elapsed Time: 4.71 seconds [BEST ACC]
# Epoch 10: Train Acc=78.57% | Val Acc=87.11% | Loss: 0.5844/0.5679 | Loss Ratio: 1.03 | LR: 0.000055 | Elapsed Time: 4.63 seconds
# Epoch 11: Train Acc=71.97% | Val Acc=87.11% | Loss: 0.6184/0.6190 | Loss Ratio: 1.00 | LR: 0.000056 | Elapsed Time: 4.68 seconds
# Epoch 12: Train Acc=81.60% | Val Acc=87.11% | Loss: 0.5375/0.6272 | Loss Ratio: 0.86 | LR: 0.000057 | Elapsed Time: 4.64 seconds [BEST ACC]
# Epoch 13: Train Acc=78.58% | Val Acc=87.11% | Loss: 0.5862/0.5776 | Loss Ratio: 1.01 | LR: 0.000058 | Elapsed Time: 4.75 seconds
# Epoch 14: Train Acc=83.00% | Val Acc=83.68% | Loss: 0.5237/0.5204 | Loss Ratio: 1.01 | LR: 0.000060 | Elapsed Time: 4.65 seconds
# Epoch 15: Train Acc=85.31% | Val Acc=87.11% | Loss: 0.5161/0.6198 | Loss Ratio: 0.83 | LR: 0.000061 | Elapsed Time: 4.71 seconds [BEST ACC]
# Epoch 16: Train Acc=79.60% | Val Acc=87.11% | Loss: 0.5452/0.5761 | Loss Ratio: 0.95 | LR: 0.000063 | Elapsed Time: 4.63 seconds
# Epoch 17: Train Acc=81.15% | Val Acc=89.18% | Loss: 0.5431/0.5055 | Loss Ratio: 1.07 | LR: 0.000064 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 18: Train Acc=81.55% | Val Acc=87.11% | Loss: 0.5553/0.5823 | Loss Ratio: 0.95 | LR: 0.000066 | Elapsed Time: 4.65 seconds
# Epoch 19: Train Acc=83.55% | Val Acc=74.40% | Loss: 0.5329/0.5944 | Loss Ratio: 0.90 | LR: 0.000068 | Elapsed Time: 4.73 seconds
# Epoch 20: Train Acc=81.81% | Val Acc=87.11% | Loss: 0.5279/0.5674 | Loss Ratio: 0.93 | LR: 0.000069 | Elapsed Time: 4.67 seconds
# Epoch 21: Train Acc=80.39% | Val Acc=87.11% | Loss: 0.5429/0.6132 | Loss Ratio: 0.89 | LR: 0.000071 | Elapsed Time: 4.66 seconds
# Epoch 22: Train Acc=77.14% | Val Acc=88.66% | Loss: 0.5701/0.5062 | Loss Ratio: 1.13 | LR: 0.000073 | Elapsed Time: 4.68 seconds
# Epoch 23: Train Acc=83.65% | Val Acc=87.11% | Loss: 0.5234/0.5389 | Loss Ratio: 0.97 | LR: 0.000076 | Elapsed Time: 4.64 seconds
# Epoch 24: Train Acc=77.68% | Val Acc=78.18% | Loss: 0.5665/0.6521 | Loss Ratio: 0.87 | LR: 0.000078 | Elapsed Time: 4.69 seconds
# Epoch 25: Train Acc=83.87% | Val Acc=85.91% | Loss: 0.5237/0.6025 | Loss Ratio: 0.87 | LR: 0.000080 | Elapsed Time: 4.70 seconds
# Epoch 26: Train Acc=82.37% | Val Acc=83.85% | Loss: 0.5326/0.6882 | Loss Ratio: 0.77 | LR: 0.000083 | Elapsed Time: 4.71 seconds
# Epoch 27: Train Acc=81.92% | Val Acc=77.15% | Loss: 0.5361/0.7148 | Loss Ratio: 0.75 | LR: 0.000085 | Elapsed Time: 4.65 seconds
# Epoch 28: Train Acc=80.94% | Val Acc=85.91% | Loss: 0.5417/0.5720 | Loss Ratio: 0.95 | LR: 0.000088 | Elapsed Time: 4.76 seconds
# Epoch 29: Train Acc=81.98% | Val Acc=94.16% | Loss: 0.5327/0.5469 | Loss Ratio: 0.97 | LR: 0.000090 | Elapsed Time: 4.64 seconds [BEST ACC]
# Epoch 30: Train Acc=84.28% | Val Acc=91.75% | Loss: 0.5354/0.5020 | Loss Ratio: 1.07 | LR: 0.000093 | Elapsed Time: 4.79 seconds
# Epoch 31: Train Acc=85.01% | Val Acc=78.18% | Loss: 0.5067/0.6084 | Loss Ratio: 0.83 | LR: 0.000096 | Elapsed Time: 4.68 seconds
# Epoch 32: Train Acc=81.76% | Val Acc=94.16% | Loss: 0.5314/0.5348 | Loss Ratio: 0.99 | LR: 0.000099 | Elapsed Time: 4.73 seconds
# Epoch 33: Train Acc=81.55% | Val Acc=83.16% | Loss: 0.5371/0.6436 | Loss Ratio: 0.83 | LR: 0.000102 | Elapsed Time: 4.68 seconds
# Epoch 34: Train Acc=80.43% | Val Acc=92.61% | Loss: 0.5397/0.5250 | Loss Ratio: 1.03 | LR: 0.000105 | Elapsed Time: 4.70 seconds
# Epoch 35: Train Acc=83.26% | Val Acc=83.16% | Loss: 0.5122/0.5716 | Loss Ratio: 0.90 | LR: 0.000108 | Elapsed Time: 4.73 seconds
# Epoch 36: Train Acc=85.35% | Val Acc=90.72% | Loss: 0.4998/0.5143 | Loss Ratio: 0.97 | LR: 0.000111 | Elapsed Time: 4.70 seconds
# Epoch 37: Train Acc=82.32% | Val Acc=87.11% | Loss: 0.5201/0.5359 | Loss Ratio: 0.97 | LR: 0.000114 | Elapsed Time: 4.65 seconds
# Epoch 38: Train Acc=82.92% | Val Acc=90.03% | Loss: 0.5115/0.5673 | Loss Ratio: 0.90 | LR: 0.000118 | Elapsed Time: 4.65 seconds
# Epoch 39: Train Acc=85.48% | Val Acc=86.77% | Loss: 0.5031/0.5262 | Loss Ratio: 0.96 | LR: 0.000121 | Elapsed Time: 4.74 seconds
# Epoch 40: Train Acc=85.07% | Val Acc=91.75% | Loss: 0.5170/0.5373 | Loss Ratio: 0.96 | LR: 0.000124 | Elapsed Time: 4.66 seconds
# Epoch 41: Train Acc=82.54% | Val Acc=87.11% | Loss: 0.5206/0.5444 | Loss Ratio: 0.96 | LR: 0.000128 | Elapsed Time: 4.67 seconds
# Epoch 42: Train Acc=81.46% | Val Acc=83.33% | Loss: 0.5459/0.6690 | Loss Ratio: 0.82 | LR: 0.000132 | Elapsed Time: 4.69 seconds
# Epoch 43: Train Acc=79.14% | Val Acc=94.16% | Loss: 0.5510/0.5037 | Loss Ratio: 1.09 | LR: 0.000135 | Elapsed Time: 4.67 seconds
# Epoch 44: Train Acc=83.95% | Val Acc=88.49% | Loss: 0.5238/0.5277 | Loss Ratio: 0.99 | LR: 0.000139 | Elapsed Time: 4.67 seconds
# Epoch 45: Train Acc=84.05% | Val Acc=79.55% | Loss: 0.5130/0.5744 | Loss Ratio: 0.89 | LR: 0.000143 | Elapsed Time: 4.77 seconds
# Epoch 46: Train Acc=80.95% | Val Acc=87.11% | Loss: 0.5299/0.5522 | Loss Ratio: 0.96 | LR: 0.000147 | Elapsed Time: 4.68 seconds
# Epoch 47: Train Acc=79.62% | Val Acc=87.11% | Loss: 0.5659/0.5818 | Loss Ratio: 0.97 | LR: 0.000150 | Elapsed Time: 4.66 seconds
# Epoch 48: Train Acc=82.40% | Val Acc=91.41% | Loss: 0.5407/0.5114 | Loss Ratio: 1.06 | LR: 0.000154 | Elapsed Time: 4.65 seconds
# Epoch 49: Train Acc=83.93% | Val Acc=86.60% | Loss: 0.5098/0.5135 | Loss Ratio: 0.99 | LR: 0.000158 | Elapsed Time: 4.73 seconds
# Epoch 50: Train Acc=81.98% | Val Acc=83.33% | Loss: 0.5302/0.6671 | Loss Ratio: 0.79 | LR: 0.000163 | Elapsed Time: 4.66 seconds
# Epoch 51: Train Acc=79.85% | Val Acc=84.71% | Loss: 0.5437/0.6236 | Loss Ratio: 0.87 | LR: 0.000167 | Elapsed Time: 4.66 seconds
# Epoch 52: Train Acc=83.42% | Val Acc=94.16% | Loss: 0.5130/0.4826 | Loss Ratio: 1.06 | LR: 0.000171 | Elapsed Time: 4.75 seconds [BEST ACC]
# Epoch 53: Train Acc=78.60% | Val Acc=83.16% | Loss: 0.5689/0.6037 | Loss Ratio: 0.94 | LR: 0.000175 | Elapsed Time: 4.76 seconds
# Epoch 54: Train Acc=82.07% | Val Acc=94.16% | Loss: 0.5330/0.5206 | Loss Ratio: 1.02 | LR: 0.000179 | Elapsed Time: 4.72 seconds
# Epoch 55: Train Acc=82.73% | Val Acc=94.16% | Loss: 0.5274/0.5114 | Loss Ratio: 1.03 | LR: 0.000183 | Elapsed Time: 4.62 seconds
# Epoch 56: Train Acc=81.12% | Val Acc=94.16% | Loss: 0.5407/0.5395 | Loss Ratio: 1.00 | LR: 0.000188 | Elapsed Time: 4.71 seconds
# Epoch 57: Train Acc=84.48% | Val Acc=78.69% | Loss: 0.5122/0.6301 | Loss Ratio: 0.81 | LR: 0.000192 | Elapsed Time: 4.66 seconds
# Epoch 58: Train Acc=85.28% | Val Acc=87.11% | Loss: 0.5007/0.5911 | Loss Ratio: 0.85 | LR: 0.000197 | Elapsed Time: 4.68 seconds
# Epoch 59: Train Acc=81.22% | Val Acc=85.91% | Loss: 0.5483/0.6085 | Loss Ratio: 0.90 | LR: 0.000201 | Elapsed Time: 4.62 seconds
# Epoch 60: Train Acc=82.39% | Val Acc=87.11% | Loss: 0.5257/0.5556 | Loss Ratio: 0.95 | LR: 0.000205 | Elapsed Time: 4.69 seconds
# Epoch 61: Train Acc=83.11% | Val Acc=69.93% | Loss: 0.5217/0.6911 | Loss Ratio: 0.75 | LR: 0.000210 | Elapsed Time: 4.63 seconds
# Epoch 62: Train Acc=85.14% | Val Acc=85.22% | Loss: 0.5072/0.5266 | Loss Ratio: 0.96 | LR: 0.000215 | Elapsed Time: 4.67 seconds
# Epoch 63: Train Acc=88.08% | Val Acc=92.10% | Loss: 0.4762/0.5184 | Loss Ratio: 0.92 | LR: 0.000219 | Elapsed Time: 4.62 seconds
# Epoch 64: Train Acc=80.79% | Val Acc=87.11% | Loss: 0.5368/0.5396 | Loss Ratio: 0.99 | LR: 0.000224 | Elapsed Time: 4.71 seconds
# Epoch 65: Train Acc=77.33% | Val Acc=95.88% | Loss: 0.5746/0.5396 | Loss Ratio: 1.06 | LR: 0.000228 | Elapsed Time: 4.64 seconds [BEST ACC]
# Epoch 66: Train Acc=84.11% | Val Acc=84.88% | Loss: 0.5225/0.5801 | Loss Ratio: 0.90 | LR: 0.000233 | Elapsed Time: 4.63 seconds
# Epoch 67: Train Acc=83.89% | Val Acc=94.16% | Loss: 0.5160/0.5525 | Loss Ratio: 0.93 | LR: 0.000237 | Elapsed Time: 4.67 seconds
# Epoch 68: Train Acc=84.75% | Val Acc=85.40% | Loss: 0.5048/0.5326 | Loss Ratio: 0.95 | LR: 0.000242 | Elapsed Time: 4.60 seconds
# Epoch 69: Train Acc=82.21% | Val Acc=83.51% | Loss: 0.5302/0.5086 | Loss Ratio: 1.04 | LR: 0.000247 | Elapsed Time: 4.76 seconds
# Epoch 70: Train Acc=85.14% | Val Acc=83.85% | Loss: 0.5080/0.5537 | Loss Ratio: 0.92 | LR: 0.000251 | Elapsed Time: 4.68 seconds
# Epoch 71: Train Acc=81.76% | Val Acc=87.11% | Loss: 0.5295/0.5843 | Loss Ratio: 0.91 | LR: 0.000256 | Elapsed Time: 4.70 seconds
# Epoch 72: Train Acc=82.89% | Val Acc=83.51% | Loss: 0.5198/0.5406 | Loss Ratio: 0.96 | LR: 0.000261 | Elapsed Time: 4.64 seconds
# Epoch 73: Train Acc=81.91% | Val Acc=87.11% | Loss: 0.5347/0.5871 | Loss Ratio: 0.91 | LR: 0.000266 | Elapsed Time: 4.75 seconds
# Epoch 74: Train Acc=84.03% | Val Acc=94.16% | Loss: 0.5101/0.5075 | Loss Ratio: 1.01 | LR: 0.000270 | Elapsed Time: 4.68 seconds
# Epoch 75: Train Acc=85.38% | Val Acc=81.27% | Loss: 0.5125/0.5685 | Loss Ratio: 0.90 | LR: 0.000275 | Elapsed Time: 4.68 seconds
# Epoch 76: Train Acc=81.57% | Val Acc=87.11% | Loss: 0.5223/0.5042 | Loss Ratio: 1.04 | LR: 0.000280 | Elapsed Time: 4.68 seconds
# Epoch 77: Train Acc=82.74% | Val Acc=87.11% | Loss: 0.5454/0.5213 | Loss Ratio: 1.05 | LR: 0.000284 | Elapsed Time: 4.69 seconds
# Epoch 78: Train Acc=81.73% | Val Acc=88.66% | Loss: 0.5242/0.5371 | Loss Ratio: 0.98 | LR: 0.000289 | Elapsed Time: 4.70 seconds
# Epoch 79: Train Acc=82.28% | Val Acc=94.16% | Loss: 0.5307/0.5306 | Loss Ratio: 1.00 | LR: 0.000294 | Elapsed Time: 4.79 seconds
# Epoch 80: Train Acc=83.33% | Val Acc=85.22% | Loss: 0.5255/0.6306 | Loss Ratio: 0.83 | LR: 0.000299 | Elapsed Time: 4.65 seconds
# Epoch 81: Train Acc=82.41% | Val Acc=87.11% | Loss: 0.5321/0.6600 | Loss Ratio: 0.81 | LR: 0.000303 | Elapsed Time: 4.71 seconds
# Epoch 82: Train Acc=84.33% | Val Acc=88.14% | Loss: 0.5133/0.4868 | Loss Ratio: 1.05 | LR: 0.000308 | Elapsed Time: 4.68 seconds
# Epoch 83: Train Acc=82.49% | Val Acc=94.16% | Loss: 0.5206/0.5193 | Loss Ratio: 1.00 | LR: 0.000313 | Elapsed Time: 4.69 seconds
# Epoch 84: Train Acc=81.65% | Val Acc=87.11% | Loss: 0.5253/0.5315 | Loss Ratio: 0.99 | LR: 0.000317 | Elapsed Time: 4.71 seconds
# Epoch 85: Train Acc=80.76% | Val Acc=94.16% | Loss: 0.5293/0.4926 | Loss Ratio: 1.07 | LR: 0.000322 | Elapsed Time: 4.65 seconds
# Epoch 86: Train Acc=85.81% | Val Acc=94.16% | Loss: 0.5058/0.5162 | Loss Ratio: 0.98 | LR: 0.000326 | Elapsed Time: 4.64 seconds
# Epoch 87: Train Acc=84.41% | Val Acc=89.69% | Loss: 0.5009/0.5691 | Loss Ratio: 0.88 | LR: 0.000331 | Elapsed Time: 4.69 seconds
# Epoch 88: Train Acc=79.73% | Val Acc=94.16% | Loss: 0.5146/0.5299 | Loss Ratio: 0.97 | LR: 0.000336 | Elapsed Time: 4.68 seconds
# Epoch 89: Train Acc=83.81% | Val Acc=87.11% | Loss: 0.5198/0.5645 | Loss Ratio: 0.92 | LR: 0.000340 | Elapsed Time: 4.64 seconds
#
# ========================================
#   PROCESSING SUBJECT: 4
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=46.86% | Val Acc=86.43% | Loss: 0.7664/0.6808 | Loss Ratio: 1.13 | LR: 0.000050 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 2: Train Acc=62.62% | Val Acc=59.11% | Loss: 0.6780/0.7395 | Loss Ratio: 0.92 | LR: 0.000050 | Elapsed Time: 4.71 seconds
# Epoch 3: Train Acc=67.34% | Val Acc=78.87% | Loss: 0.6360/0.5631 | Loss Ratio: 1.13 | LR: 0.000050 | Elapsed Time: 4.70 seconds
# Epoch 4: Train Acc=75.79% | Val Acc=78.87% | Loss: 0.5965/0.5474 | Loss Ratio: 1.09 | LR: 0.000051 | Elapsed Time: 4.68 seconds
# Epoch 5: Train Acc=80.98% | Val Acc=88.14% | Loss: 0.5501/0.4611 | Loss Ratio: 1.19 | LR: 0.000051 | Elapsed Time: 4.68 seconds [BEST ACC]
# Epoch 6: Train Acc=79.35% | Val Acc=87.11% | Loss: 0.5748/0.5209 | Loss Ratio: 1.10 | LR: 0.000052 | Elapsed Time: 4.75 seconds
# Epoch 7: Train Acc=80.25% | Val Acc=83.68% | Loss: 0.5537/0.5108 | Loss Ratio: 1.08 | LR: 0.000052 | Elapsed Time: 4.64 seconds
# Epoch 8: Train Acc=81.19% | Val Acc=83.68% | Loss: 0.5405/0.5122 | Loss Ratio: 1.06 | LR: 0.000053 | Elapsed Time: 4.67 seconds
# Epoch 9: Train Acc=82.56% | Val Acc=83.68% | Loss: 0.5339/0.5985 | Loss Ratio: 0.89 | LR: 0.000054 | Elapsed Time: 4.81 seconds
# Epoch 10: Train Acc=79.80% | Val Acc=77.49% | Loss: 0.5633/0.8156 | Loss Ratio: 0.69 | LR: 0.000055 | Elapsed Time: 4.64 seconds
# Epoch 11: Train Acc=84.23% | Val Acc=92.78% | Loss: 0.5109/0.4771 | Loss Ratio: 1.07 | LR: 0.000056 | Elapsed Time: 4.69 seconds [BEST ACC]
# Epoch 12: Train Acc=85.13% | Val Acc=83.68% | Loss: 0.5096/0.4833 | Loss Ratio: 1.05 | LR: 0.000057 | Elapsed Time: 4.66 seconds
# Epoch 13: Train Acc=82.69% | Val Acc=83.68% | Loss: 0.5390/0.5493 | Loss Ratio: 0.98 | LR: 0.000058 | Elapsed Time: 4.67 seconds
# Epoch 14: Train Acc=82.99% | Val Acc=83.68% | Loss: 0.5317/0.5895 | Loss Ratio: 0.90 | LR: 0.000060 | Elapsed Time: 4.60 seconds
# Epoch 15: Train Acc=81.60% | Val Acc=83.68% | Loss: 0.5348/0.5595 | Loss Ratio: 0.96 | LR: 0.000061 | Elapsed Time: 4.66 seconds
# Epoch 16: Train Acc=85.81% | Val Acc=85.22% | Loss: 0.5021/0.4854 | Loss Ratio: 1.03 | LR: 0.000063 | Elapsed Time: 4.63 seconds
# Epoch 17: Train Acc=84.29% | Val Acc=78.87% | Loss: 0.5109/0.7361 | Loss Ratio: 0.69 | LR: 0.000064 | Elapsed Time: 4.67 seconds
# Epoch 18: Train Acc=81.62% | Val Acc=81.44% | Loss: 0.5482/0.6060 | Loss Ratio: 0.90 | LR: 0.000066 | Elapsed Time: 4.75 seconds
# Epoch 19: Train Acc=83.16% | Val Acc=83.68% | Loss: 0.5202/0.6104 | Loss Ratio: 0.85 | LR: 0.000068 | Elapsed Time: 4.75 seconds
# Epoch 20: Train Acc=83.22% | Val Acc=83.68% | Loss: 0.5448/0.6328 | Loss Ratio: 0.86 | LR: 0.000069 | Elapsed Time: 4.72 seconds
# Epoch 21: Train Acc=82.89% | Val Acc=58.93% | Loss: 0.5424/0.7939 | Loss Ratio: 0.68 | LR: 0.000071 | Elapsed Time: 4.75 seconds
# Epoch 22: Train Acc=82.80% | Val Acc=83.68% | Loss: 0.5454/0.6194 | Loss Ratio: 0.88 | LR: 0.000073 | Elapsed Time: 4.69 seconds
# Epoch 23: Train Acc=84.42% | Val Acc=83.68% | Loss: 0.5176/0.5880 | Loss Ratio: 0.88 | LR: 0.000076 | Elapsed Time: 4.64 seconds
# Epoch 24: Train Acc=85.57% | Val Acc=83.68% | Loss: 0.5141/0.6902 | Loss Ratio: 0.74 | LR: 0.000078 | Elapsed Time: 4.62 seconds
# Epoch 25: Train Acc=85.20% | Val Acc=83.68% | Loss: 0.5086/0.6021 | Loss Ratio: 0.84 | LR: 0.000080 | Elapsed Time: 4.62 seconds
# Epoch 26: Train Acc=84.54% | Val Acc=90.89% | Loss: 0.5151/0.4711 | Loss Ratio: 1.09 | LR: 0.000083 | Elapsed Time: 4.75 seconds
# Epoch 27: Train Acc=86.26% | Val Acc=83.68% | Loss: 0.5066/0.6561 | Loss Ratio: 0.77 | LR: 0.000085 | Elapsed Time: 4.63 seconds
# Epoch 28: Train Acc=84.14% | Val Acc=83.68% | Loss: 0.5197/0.6883 | Loss Ratio: 0.76 | LR: 0.000088 | Elapsed Time: 4.72 seconds
# Epoch 29: Train Acc=83.96% | Val Acc=83.68% | Loss: 0.5210/0.5995 | Loss Ratio: 0.87 | LR: 0.000090 | Elapsed Time: 4.63 seconds
# Epoch 30: Train Acc=82.65% | Val Acc=83.68% | Loss: 0.5197/0.6984 | Loss Ratio: 0.74 | LR: 0.000093 | Elapsed Time: 4.68 seconds
# Epoch 31: Train Acc=86.50% | Val Acc=83.68% | Loss: 0.5067/0.7277 | Loss Ratio: 0.70 | LR: 0.000096 | Elapsed Time: 4.71 seconds
# Epoch 32: Train Acc=86.58% | Val Acc=81.96% | Loss: 0.4949/0.7014 | Loss Ratio: 0.71 | LR: 0.000099 | Elapsed Time: 4.67 seconds
# Epoch 33: Train Acc=83.22% | Val Acc=78.69% | Loss: 0.5239/0.5965 | Loss Ratio: 0.88 | LR: 0.000102 | Elapsed Time: 4.64 seconds
# Epoch 34: Train Acc=85.21% | Val Acc=83.68% | Loss: 0.5063/0.5981 | Loss Ratio: 0.85 | LR: 0.000105 | Elapsed Time: 4.68 seconds
# Epoch 35: Train Acc=85.47% | Val Acc=83.68% | Loss: 0.5145/0.7094 | Loss Ratio: 0.73 | LR: 0.000108 | Elapsed Time: 4.63 seconds
#
# ========================================
#   PROCESSING SUBJECT: 5
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=49.08% | Val Acc=73.02% | Loss: 0.7640/0.7688 | Loss Ratio: 0.99 | LR: 0.000050 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 2: Train Acc=58.10% | Val Acc=64.43% | Loss: 0.7071/0.7571 | Loss Ratio: 0.93 | LR: 0.000050 | Elapsed Time: 4.70 seconds
# Epoch 3: Train Acc=67.09% | Val Acc=75.95% | Loss: 0.6602/0.6773 | Loss Ratio: 0.97 | LR: 0.000050 | Elapsed Time: 4.78 seconds [BEST ACC]
# Epoch 4: Train Acc=69.62% | Val Acc=78.87% | Loss: 0.6513/0.6199 | Loss Ratio: 1.05 | LR: 0.000051 | Elapsed Time: 4.72 seconds [BEST ACC]
# Epoch 5: Train Acc=73.45% | Val Acc=92.78% | Loss: 0.6197/0.5934 | Loss Ratio: 1.04 | LR: 0.000051 | Elapsed Time: 4.66 seconds [BEST ACC]
# Epoch 6: Train Acc=74.70% | Val Acc=95.19% | Loss: 0.6074/0.5580 | Loss Ratio: 1.09 | LR: 0.000052 | Elapsed Time: 4.62 seconds [BEST ACC]
# Epoch 7: Train Acc=79.08% | Val Acc=87.97% | Loss: 0.5758/0.5538 | Loss Ratio: 1.04 | LR: 0.000052 | Elapsed Time: 4.68 seconds
# Epoch 8: Train Acc=79.83% | Val Acc=100.00% | Loss: 0.5690/0.5144 | Loss Ratio: 1.11 | LR: 0.000053 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 9: Train Acc=80.73% | Val Acc=94.16% | Loss: 0.5676/0.5406 | Loss Ratio: 1.05 | LR: 0.000054 | Elapsed Time: 4.68 seconds
# Epoch 10: Train Acc=80.80% | Val Acc=92.96% | Loss: 0.5624/0.5243 | Loss Ratio: 1.07 | LR: 0.000055 | Elapsed Time: 4.64 seconds
# Epoch 11: Train Acc=83.46% | Val Acc=96.74% | Loss: 0.5371/0.5212 | Loss Ratio: 1.03 | LR: 0.000056 | Elapsed Time: 4.70 seconds
# Epoch 12: Train Acc=79.12% | Val Acc=93.81% | Loss: 0.5669/0.5087 | Loss Ratio: 1.11 | LR: 0.000057 | Elapsed Time: 4.61 seconds
# Epoch 13: Train Acc=81.35% | Val Acc=100.00% | Loss: 0.5405/0.4541 | Loss Ratio: 1.19 | LR: 0.000058 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 14: Train Acc=83.45% | Val Acc=94.16% | Loss: 0.5357/0.5025 | Loss Ratio: 1.07 | LR: 0.000060 | Elapsed Time: 4.63 seconds
# Epoch 15: Train Acc=82.81% | Val Acc=100.00% | Loss: 0.5267/0.4886 | Loss Ratio: 1.08 | LR: 0.000061 | Elapsed Time: 4.66 seconds [BEST ACC]
# Epoch 16: Train Acc=82.53% | Val Acc=100.00% | Loss: 0.5357/0.4634 | Loss Ratio: 1.16 | LR: 0.000063 | Elapsed Time: 4.63 seconds
# Epoch 17: Train Acc=83.97% | Val Acc=100.00% | Loss: 0.5431/0.4600 | Loss Ratio: 1.18 | LR: 0.000064 | Elapsed Time: 4.73 seconds [BEST ACC]
# Epoch 18: Train Acc=83.40% | Val Acc=95.88% | Loss: 0.5292/0.4681 | Loss Ratio: 1.13 | LR: 0.000066 | Elapsed Time: 4.56 seconds
# Epoch 19: Train Acc=81.33% | Val Acc=87.63% | Loss: 0.5457/0.5453 | Loss Ratio: 1.00 | LR: 0.000068 | Elapsed Time: 4.62 seconds
# Epoch 20: Train Acc=83.24% | Val Acc=96.74% | Loss: 0.5294/0.4487 | Loss Ratio: 1.18 | LR: 0.000069 | Elapsed Time: 4.65 seconds
# Epoch 21: Train Acc=84.84% | Val Acc=96.74% | Loss: 0.5096/0.4651 | Loss Ratio: 1.10 | LR: 0.000071 | Elapsed Time: 4.65 seconds
# Epoch 22: Train Acc=83.93% | Val Acc=97.59% | Loss: 0.5252/0.4753 | Loss Ratio: 1.10 | LR: 0.000073 | Elapsed Time: 4.67 seconds
# Epoch 23: Train Acc=83.16% | Val Acc=96.74% | Loss: 0.5295/0.4752 | Loss Ratio: 1.11 | LR: 0.000076 | Elapsed Time: 4.62 seconds
# Epoch 24: Train Acc=86.88% | Val Acc=92.44% | Loss: 0.5007/0.4823 | Loss Ratio: 1.04 | LR: 0.000078 | Elapsed Time: 4.64 seconds
# Epoch 25: Train Acc=84.38% | Val Acc=97.42% | Loss: 0.5141/0.4654 | Loss Ratio: 1.10 | LR: 0.000080 | Elapsed Time: 4.62 seconds
# Epoch 26: Train Acc=83.87% | Val Acc=95.88% | Loss: 0.5118/0.4808 | Loss Ratio: 1.06 | LR: 0.000083 | Elapsed Time: 4.66 seconds
# Epoch 27: Train Acc=86.04% | Val Acc=95.88% | Loss: 0.5089/0.4446 | Loss Ratio: 1.14 | LR: 0.000085 | Elapsed Time: 4.67 seconds
# Epoch 28: Train Acc=83.47% | Val Acc=100.00% | Loss: 0.5286/0.4064 | Loss Ratio: 1.30 | LR: 0.000088 | Elapsed Time: 4.69 seconds
# Epoch 29: Train Acc=87.70% | Val Acc=88.14% | Loss: 0.4765/0.4897 | Loss Ratio: 0.97 | LR: 0.000090 | Elapsed Time: 4.67 seconds
# Epoch 30: Train Acc=82.77% | Val Acc=100.00% | Loss: 0.5285/0.4575 | Loss Ratio: 1.16 | LR: 0.000093 | Elapsed Time: 4.70 seconds
# Epoch 31: Train Acc=82.96% | Val Acc=100.00% | Loss: 0.5384/0.4419 | Loss Ratio: 1.22 | LR: 0.000096 | Elapsed Time: 4.62 seconds
# Epoch 32: Train Acc=80.56% | Val Acc=100.00% | Loss: 0.5510/0.4488 | Loss Ratio: 1.23 | LR: 0.000099 | Elapsed Time: 4.67 seconds
# Epoch 33: Train Acc=85.03% | Val Acc=89.00% | Loss: 0.5020/0.4715 | Loss Ratio: 1.06 | LR: 0.000102 | Elapsed Time: 4.71 seconds
# Epoch 34: Train Acc=82.73% | Val Acc=94.16% | Loss: 0.5259/0.5116 | Loss Ratio: 1.03 | LR: 0.000105 | Elapsed Time: 4.67 seconds
# Epoch 35: Train Acc=84.06% | Val Acc=100.00% | Loss: 0.5261/0.4252 | Loss Ratio: 1.24 | LR: 0.000108 | Elapsed Time: 4.68 seconds [BEST ACC]
# Epoch 36: Train Acc=83.91% | Val Acc=96.74% | Loss: 0.5417/0.4391 | Loss Ratio: 1.23 | LR: 0.000111 | Elapsed Time: 4.65 seconds
# Epoch 37: Train Acc=84.27% | Val Acc=100.00% | Loss: 0.5140/0.4461 | Loss Ratio: 1.15 | LR: 0.000114 | Elapsed Time: 4.69 seconds [BEST ACC]
# Epoch 38: Train Acc=82.65% | Val Acc=95.88% | Loss: 0.5332/0.4749 | Loss Ratio: 1.12 | LR: 0.000118 | Elapsed Time: 4.62 seconds
# Epoch 39: Train Acc=84.93% | Val Acc=92.27% | Loss: 0.5028/0.4553 | Loss Ratio: 1.10 | LR: 0.000121 | Elapsed Time: 4.65 seconds
# Epoch 40: Train Acc=85.68% | Val Acc=100.00% | Loss: 0.5127/0.4432 | Loss Ratio: 1.16 | LR: 0.000124 | Elapsed Time: 4.64 seconds [BEST ACC]
# Epoch 41: Train Acc=85.12% | Val Acc=96.74% | Loss: 0.5256/0.4417 | Loss Ratio: 1.19 | LR: 0.000128 | Elapsed Time: 4.72 seconds
# Epoch 42: Train Acc=85.75% | Val Acc=95.88% | Loss: 0.4945/0.4798 | Loss Ratio: 1.03 | LR: 0.000132 | Elapsed Time: 4.62 seconds
# Epoch 43: Train Acc=85.28% | Val Acc=100.00% | Loss: 0.5073/0.5030 | Loss Ratio: 1.01 | LR: 0.000135 | Elapsed Time: 4.68 seconds
# Epoch 44: Train Acc=86.25% | Val Acc=95.88% | Loss: 0.5075/0.4516 | Loss Ratio: 1.12 | LR: 0.000139 | Elapsed Time: 4.63 seconds
# Epoch 45: Train Acc=85.29% | Val Acc=100.00% | Loss: 0.5078/0.4114 | Loss Ratio: 1.23 | LR: 0.000143 | Elapsed Time: 4.65 seconds
# Epoch 46: Train Acc=83.48% | Val Acc=100.00% | Loss: 0.5325/0.4332 | Loss Ratio: 1.23 | LR: 0.000147 | Elapsed Time: 4.64 seconds
# Epoch 47: Train Acc=82.59% | Val Acc=100.00% | Loss: 0.5434/0.4646 | Loss Ratio: 1.17 | LR: 0.000150 | Elapsed Time: 4.70 seconds
# Epoch 48: Train Acc=86.71% | Val Acc=100.00% | Loss: 0.5038/0.4580 | Loss Ratio: 1.10 | LR: 0.000154 | Elapsed Time: 4.64 seconds [BEST ACC]
# Epoch 49: Train Acc=81.14% | Val Acc=95.88% | Loss: 0.5482/0.4575 | Loss Ratio: 1.20 | LR: 0.000158 | Elapsed Time: 4.64 seconds
# Epoch 50: Train Acc=85.33% | Val Acc=92.27% | Loss: 0.5032/0.5366 | Loss Ratio: 0.94 | LR: 0.000163 | Elapsed Time: 4.72 seconds
# Epoch 51: Train Acc=85.53% | Val Acc=84.88% | Loss: 0.5136/0.5315 | Loss Ratio: 0.97 | LR: 0.000167 | Elapsed Time: 4.68 seconds
# Epoch 52: Train Acc=83.79% | Val Acc=100.00% | Loss: 0.5186/0.4032 | Loss Ratio: 1.29 | LR: 0.000171 | Elapsed Time: 4.69 seconds
# Epoch 53: Train Acc=85.34% | Val Acc=95.19% | Loss: 0.5211/0.4439 | Loss Ratio: 1.17 | LR: 0.000175 | Elapsed Time: 4.67 seconds
# Epoch 54: Train Acc=82.77% | Val Acc=100.00% | Loss: 0.5434/0.4005 | Loss Ratio: 1.36 | LR: 0.000179 | Elapsed Time: 4.71 seconds
# Epoch 55: Train Acc=86.46% | Val Acc=100.00% | Loss: 0.5044/0.4219 | Loss Ratio: 1.20 | LR: 0.000183 | Elapsed Time: 4.61 seconds
# Epoch 56: Train Acc=82.94% | Val Acc=95.88% | Loss: 0.5041/0.4507 | Loss Ratio: 1.12 | LR: 0.000188 | Elapsed Time: 4.65 seconds
# Epoch 57: Train Acc=83.99% | Val Acc=100.00% | Loss: 0.5165/0.4300 | Loss Ratio: 1.20 | LR: 0.000192 | Elapsed Time: 4.61 seconds
# Epoch 58: Train Acc=84.89% | Val Acc=91.07% | Loss: 0.5049/0.4820 | Loss Ratio: 1.05 | LR: 0.000197 | Elapsed Time: 4.71 seconds
# Epoch 59: Train Acc=86.08% | Val Acc=95.88% | Loss: 0.5003/0.4914 | Loss Ratio: 1.02 | LR: 0.000201 | Elapsed Time: 4.62 seconds
# Epoch 60: Train Acc=84.12% | Val Acc=100.00% | Loss: 0.5250/0.4169 | Loss Ratio: 1.26 | LR: 0.000205 | Elapsed Time: 4.78 seconds
# Epoch 61: Train Acc=86.54% | Val Acc=91.58% | Loss: 0.4859/0.5033 | Loss Ratio: 0.97 | LR: 0.000210 | Elapsed Time: 4.74 seconds
# Epoch 62: Train Acc=84.43% | Val Acc=100.00% | Loss: 0.5101/0.4219 | Loss Ratio: 1.21 | LR: 0.000215 | Elapsed Time: 4.59 seconds
# Epoch 63: Train Acc=78.76% | Val Acc=87.63% | Loss: 0.5446/0.5213 | Loss Ratio: 1.04 | LR: 0.000219 | Elapsed Time: 4.66 seconds
# Epoch 64: Train Acc=83.76% | Val Acc=92.44% | Loss: 0.5370/0.4639 | Loss Ratio: 1.16 | LR: 0.000224 | Elapsed Time: 4.62 seconds
# Epoch 65: Train Acc=84.05% | Val Acc=95.88% | Loss: 0.5285/0.4997 | Loss Ratio: 1.06 | LR: 0.000228 | Elapsed Time: 4.66 seconds
# Epoch 66: Train Acc=85.07% | Val Acc=95.88% | Loss: 0.5090/0.4383 | Loss Ratio: 1.16 | LR: 0.000233 | Elapsed Time: 4.65 seconds
# Epoch 67: Train Acc=83.15% | Val Acc=95.88% | Loss: 0.5389/0.5030 | Loss Ratio: 1.07 | LR: 0.000237 | Elapsed Time: 4.66 seconds
# Epoch 68: Train Acc=85.52% | Val Acc=92.27% | Loss: 0.5068/0.5065 | Loss Ratio: 1.00 | LR: 0.000242 | Elapsed Time: 4.65 seconds
# Epoch 69: Train Acc=82.43% | Val Acc=85.91% | Loss: 0.5316/0.6311 | Loss Ratio: 0.84 | LR: 0.000247 | Elapsed Time: 4.62 seconds
# Epoch 70: Train Acc=80.41% | Val Acc=92.78% | Loss: 0.5664/0.4908 | Loss Ratio: 1.15 | LR: 0.000251 | Elapsed Time: 4.64 seconds
# Epoch 71: Train Acc=86.12% | Val Acc=100.00% | Loss: 0.5047/0.4211 | Loss Ratio: 1.20 | LR: 0.000256 | Elapsed Time: 4.67 seconds
# Epoch 72: Train Acc=84.84% | Val Acc=92.27% | Loss: 0.5172/0.4521 | Loss Ratio: 1.14 | LR: 0.000261 | Elapsed Time: 4.66 seconds
#
# ========================================
#   PROCESSING SUBJECT: 6
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=57.90% | Val Acc=90.03% | Loss: 0.7101/0.5607 | Loss Ratio: 1.27 | LR: 0.000050 | Elapsed Time: 4.65 seconds [BEST ACC]
# Epoch 2: Train Acc=76.40% | Val Acc=95.36% | Loss: 0.5990/0.4993 | Loss Ratio: 1.20 | LR: 0.000050 | Elapsed Time: 4.66 seconds [BEST ACC]
# Epoch 3: Train Acc=81.38% | Val Acc=90.03% | Loss: 0.5449/0.5289 | Loss Ratio: 1.03 | LR: 0.000050 | Elapsed Time: 4.64 seconds
# Epoch 4: Train Acc=83.69% | Val Acc=92.96% | Loss: 0.5382/0.4903 | Loss Ratio: 1.10 | LR: 0.000051 | Elapsed Time: 4.67 seconds
# Epoch 5: Train Acc=85.12% | Val Acc=100.00% | Loss: 0.5140/0.4345 | Loss Ratio: 1.18 | LR: 0.000051 | Elapsed Time: 4.66 seconds [BEST ACC]
# Epoch 6: Train Acc=86.66% | Val Acc=96.74% | Loss: 0.5048/0.4521 | Loss Ratio: 1.12 | LR: 0.000052 | Elapsed Time: 4.65 seconds
# Epoch 7: Train Acc=83.84% | Val Acc=100.00% | Loss: 0.5126/0.4551 | Loss Ratio: 1.13 | LR: 0.000052 | Elapsed Time: 4.70 seconds
# Epoch 8: Train Acc=85.91% | Val Acc=88.83% | Loss: 0.5140/0.4774 | Loss Ratio: 1.08 | LR: 0.000053 | Elapsed Time: 4.61 seconds
# Epoch 9: Train Acc=83.92% | Val Acc=85.22% | Loss: 0.5158/0.5818 | Loss Ratio: 0.89 | LR: 0.000054 | Elapsed Time: 4.70 seconds
# Epoch 10: Train Acc=87.47% | Val Acc=85.22% | Loss: 0.4845/0.5053 | Loss Ratio: 0.96 | LR: 0.000055 | Elapsed Time: 4.68 seconds
# Epoch 11: Train Acc=87.94% | Val Acc=85.22% | Loss: 0.4844/0.6265 | Loss Ratio: 0.77 | LR: 0.000056 | Elapsed Time: 4.69 seconds
# Epoch 12: Train Acc=85.19% | Val Acc=86.60% | Loss: 0.5107/0.5335 | Loss Ratio: 0.96 | LR: 0.000057 | Elapsed Time: 4.64 seconds
# Epoch 13: Train Acc=86.91% | Val Acc=81.62% | Loss: 0.5048/0.6111 | Loss Ratio: 0.83 | LR: 0.000058 | Elapsed Time: 4.74 seconds
# Epoch 14: Train Acc=85.89% | Val Acc=91.92% | Loss: 0.5215/0.4573 | Loss Ratio: 1.14 | LR: 0.000060 | Elapsed Time: 4.63 seconds
# Epoch 15: Train Acc=85.81% | Val Acc=89.69% | Loss: 0.5056/0.5351 | Loss Ratio: 0.94 | LR: 0.000061 | Elapsed Time: 4.65 seconds
# Epoch 16: Train Acc=87.24% | Val Acc=100.00% | Loss: 0.5006/0.4491 | Loss Ratio: 1.11 | LR: 0.000063 | Elapsed Time: 4.63 seconds [BEST ACC]
# Epoch 17: Train Acc=87.39% | Val Acc=91.58% | Loss: 0.4888/0.4712 | Loss Ratio: 1.04 | LR: 0.000064 | Elapsed Time: 4.65 seconds
# Epoch 18: Train Acc=85.28% | Val Acc=85.22% | Loss: 0.5083/0.4936 | Loss Ratio: 1.03 | LR: 0.000066 | Elapsed Time: 4.66 seconds
# Epoch 19: Train Acc=85.39% | Val Acc=85.57% | Loss: 0.5214/0.5197 | Loss Ratio: 1.00 | LR: 0.000068 | Elapsed Time: 4.63 seconds
# Epoch 20: Train Acc=87.55% | Val Acc=96.74% | Loss: 0.4934/0.4271 | Loss Ratio: 1.16 | LR: 0.000069 | Elapsed Time: 4.69 seconds
# Epoch 21: Train Acc=87.10% | Val Acc=87.97% | Loss: 0.4918/0.5298 | Loss Ratio: 0.93 | LR: 0.000071 | Elapsed Time: 4.65 seconds
# Epoch 22: Train Acc=87.70% | Val Acc=91.92% | Loss: 0.4982/0.4904 | Loss Ratio: 1.02 | LR: 0.000073 | Elapsed Time: 4.66 seconds
# Epoch 23: Train Acc=88.07% | Val Acc=85.22% | Loss: 0.4913/0.5630 | Loss Ratio: 0.87 | LR: 0.000076 | Elapsed Time: 4.62 seconds
# Epoch 24: Train Acc=89.22% | Val Acc=85.22% | Loss: 0.4834/0.6116 | Loss Ratio: 0.79 | LR: 0.000078 | Elapsed Time: 4.68 seconds
# Epoch 25: Train Acc=87.29% | Val Acc=91.92% | Loss: 0.4914/0.4722 | Loss Ratio: 1.04 | LR: 0.000080 | Elapsed Time: 4.65 seconds
# Epoch 26: Train Acc=86.05% | Val Acc=88.49% | Loss: 0.5052/0.4882 | Loss Ratio: 1.03 | LR: 0.000083 | Elapsed Time: 4.74 seconds
# Epoch 27: Train Acc=86.64% | Val Acc=96.74% | Loss: 0.4807/0.4609 | Loss Ratio: 1.04 | LR: 0.000085 | Elapsed Time: 4.64 seconds
# Epoch 28: Train Acc=86.75% | Val Acc=91.92% | Loss: 0.4929/0.5063 | Loss Ratio: 0.97 | LR: 0.000088 | Elapsed Time: 4.71 seconds
# Epoch 29: Train Acc=86.23% | Val Acc=83.33% | Loss: 0.4970/0.6022 | Loss Ratio: 0.83 | LR: 0.000090 | Elapsed Time: 4.63 seconds
# Epoch 30: Train Acc=88.10% | Val Acc=86.43% | Loss: 0.4748/0.5648 | Loss Ratio: 0.84 | LR: 0.000093 | Elapsed Time: 4.68 seconds
# Epoch 31: Train Acc=88.90% | Val Acc=87.11% | Loss: 0.4640/0.5971 | Loss Ratio: 0.78 | LR: 0.000096 | Elapsed Time: 4.65 seconds
# Epoch 32: Train Acc=87.58% | Val Acc=87.46% | Loss: 0.4841/0.5904 | Loss Ratio: 0.82 | LR: 0.000099 | Elapsed Time: 4.77 seconds
# Epoch 33: Train Acc=87.85% | Val Acc=89.86% | Loss: 0.4802/0.5169 | Loss Ratio: 0.93 | LR: 0.000102 | Elapsed Time: 4.58 seconds
# Epoch 34: Train Acc=88.12% | Val Acc=83.51% | Loss: 0.4927/0.5087 | Loss Ratio: 0.97 | LR: 0.000105 | Elapsed Time: 4.60 seconds
# Epoch 35: Train Acc=85.79% | Val Acc=78.35% | Loss: 0.5018/0.6397 | Loss Ratio: 0.78 | LR: 0.000108 | Elapsed Time: 4.63 seconds
# Epoch 36: Train Acc=87.89% | Val Acc=85.22% | Loss: 0.4845/0.5440 | Loss Ratio: 0.89 | LR: 0.000111 | Elapsed Time: 4.57 seconds
# Epoch 37: Train Acc=88.69% | Val Acc=85.22% | Loss: 0.4812/0.5711 | Loss Ratio: 0.84 | LR: 0.000114 | Elapsed Time: 4.64 seconds
# Epoch 38: Train Acc=88.12% | Val Acc=77.49% | Loss: 0.4747/0.5928 | Loss Ratio: 0.80 | LR: 0.000118 | Elapsed Time: 4.62 seconds
# Epoch 39: Train Acc=88.16% | Val Acc=84.88% | Loss: 0.4732/0.5551 | Loss Ratio: 0.85 | LR: 0.000121 | Elapsed Time: 4.64 seconds
# Epoch 40: Train Acc=86.69% | Val Acc=91.41% | Loss: 0.4833/0.5327 | Loss Ratio: 0.91 | LR: 0.000124 | Elapsed Time: 4.62 seconds
#
# ========================================
#   PROCESSING SUBJECT: 7
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=46.95% | Val Acc=84.19% | Loss: 0.7788/0.7367 | Loss Ratio: 1.06 | LR: 0.000050 | Elapsed Time: 4.62 seconds [BEST ACC]
# Epoch 2: Train Acc=57.86% | Val Acc=65.81% | Loss: 0.7132/0.7044 | Loss Ratio: 1.01 | LR: 0.000050 | Elapsed Time: 4.70 seconds
# Epoch 3: Train Acc=64.38% | Val Acc=85.91% | Loss: 0.6596/0.5516 | Loss Ratio: 1.20 | LR: 0.000050 | Elapsed Time: 4.69 seconds [BEST ACC]
# Epoch 4: Train Acc=70.44% | Val Acc=91.92% | Loss: 0.6400/0.5573 | Loss Ratio: 1.15 | LR: 0.000051 | Elapsed Time: 4.78 seconds [BEST ACC]
# Epoch 5: Train Acc=78.54% | Val Acc=100.00% | Loss: 0.5783/0.4873 | Loss Ratio: 1.19 | LR: 0.000051 | Elapsed Time: 4.68 seconds [BEST ACC]
# Epoch 6: Train Acc=77.40% | Val Acc=91.24% | Loss: 0.5958/0.5419 | Loss Ratio: 1.10 | LR: 0.000052 | Elapsed Time: 4.66 seconds
# Epoch 7: Train Acc=77.57% | Val Acc=78.52% | Loss: 0.5819/0.5430 | Loss Ratio: 1.07 | LR: 0.000052 | Elapsed Time: 4.63 seconds
# Epoch 8: Train Acc=78.58% | Val Acc=100.00% | Loss: 0.5799/0.4364 | Loss Ratio: 1.33 | LR: 0.000053 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 9: Train Acc=79.35% | Val Acc=95.19% | Loss: 0.5748/0.4385 | Loss Ratio: 1.31 | LR: 0.000054 | Elapsed Time: 4.68 seconds
# Epoch 10: Train Acc=78.36% | Val Acc=100.00% | Loss: 0.5684/0.4523 | Loss Ratio: 1.26 | LR: 0.000055 | Elapsed Time: 4.70 seconds
# Epoch 11: Train Acc=82.22% | Val Acc=92.78% | Loss: 0.5414/0.4845 | Loss Ratio: 1.12 | LR: 0.000056 | Elapsed Time: 4.71 seconds
# Epoch 12: Train Acc=81.52% | Val Acc=95.19% | Loss: 0.5498/0.4634 | Loss Ratio: 1.19 | LR: 0.000057 | Elapsed Time: 4.63 seconds
# Epoch 13: Train Acc=82.36% | Val Acc=100.00% | Loss: 0.5387/0.4429 | Loss Ratio: 1.22 | LR: 0.000058 | Elapsed Time: 4.70 seconds [BEST ACC]
# ...
# Epoch 24: Train Acc=83.94% | Val Acc=78.35% | Loss: 0.5115/0.8022 | Loss Ratio: 0.64 | LR: 0.000078 | Elapsed Time: 4.76 seconds
# Epoch 25: Train Acc=84.84% | Val Acc=83.85% | Loss: 0.5125/0.6490 | Loss Ratio: 0.79 | LR: 0.000080 | Elapsed Time: 4.69 seconds [BEST ACC]
# Epoch 26: Train Acc=84.47% | Val Acc=86.43% | Loss: 0.5175/0.6641 | Loss Ratio: 0.78 | LR: 0.000083 | Elapsed Time: 4.74 seconds [BEST ACC]
# Epoch 27: Train Acc=83.04% | Val Acc=83.85% | Loss: 0.5348/0.6729 | Loss Ratio: 0.79 | LR: 0.000085 | Elapsed Time: 4.74 seconds
# Epoch 28: Train Acc=84.81% | Val Acc=83.85% | Loss: 0.5161/0.7264 | Loss Ratio: 0.71 | LR: 0.000088 | Elapsed Time: 4.74 seconds
# Epoch 29: Train Acc=81.04% | Val Acc=78.01% | Loss: 0.5169/0.6778 | Loss Ratio: 0.76 | LR: 0.000090 | Elapsed Time: 4.78 seconds
# Epoch 30: Train Acc=80.55% | Val Acc=82.99% | Loss: 0.5725/0.7638 | Loss Ratio: 0.75 | LR: 0.000093 | Elapsed Time: 4.81 seconds
# Epoch 31: Train Acc=84.48% | Val Acc=80.07% | Loss: 0.5019/0.7588 | Loss Ratio: 0.66 | LR: 0.000096 | Elapsed Time: 4.70 seconds
# Epoch 32: Train Acc=87.70% | Val Acc=70.79% | Loss: 0.4862/0.7200 | Loss Ratio: 0.68 | LR: 0.000099 | Elapsed Time: 4.68 seconds
# Epoch 33: Train Acc=86.39% | Val Acc=70.45% | Loss: 0.4974/0.7418 | Loss Ratio: 0.67 | LR: 0.000102 | Elapsed Time: 4.71 seconds
# Epoch 34: Train Acc=83.71% | Val Acc=77.84% | Loss: 0.5108/0.7968 | Loss Ratio: 0.64 | LR: 0.000105 | Elapsed Time: 4.69 seconds
# Epoch 35: Train Acc=83.20% | Val Acc=72.85% | Loss: 0.5137/0.7607 | Loss Ratio: 0.68 | LR: 0.000108 | Elapsed Time: 4.74 seconds
# Epoch 36: Train Acc=86.45% | Val Acc=83.85% | Loss: 0.4928/0.6562 | Loss Ratio: 0.75 | LR: 0.000111 | Elapsed Time: 4.67 seconds
# Epoch 37: Train Acc=85.29% | Val Acc=74.40% | Loss: 0.5072/0.6974 | Loss Ratio: 0.73 | LR: 0.000114 | Elapsed Time: 4.68 seconds
# Epoch 38: Train Acc=86.82% | Val Acc=83.85% | Loss: 0.4854/0.7040 | Loss Ratio: 0.69 | LR: 0.000118 | Elapsed Time: 4.71 seconds
# Epoch 39: Train Acc=86.09% | Val Acc=75.77% | Loss: 0.4926/0.7851 | Loss Ratio: 0.63 | LR: 0.000121 | Elapsed Time: 4.69 seconds
# Epoch 40: Train Acc=85.79% | Val Acc=75.09% | Loss: 0.4880/0.7375 | Loss Ratio: 0.66 | LR: 0.000124 | Elapsed Time: 4.71 seconds
# Epoch 41: Train Acc=82.38% | Val Acc=81.79% | Loss: 0.5357/0.6817 | Loss Ratio: 0.79 | LR: 0.000128 | Elapsed Time: 4.79 seconds
# Epoch 42: Train Acc=82.47% | Val Acc=79.38% | Loss: 0.5377/0.6924 | Loss Ratio: 0.78 | LR: 0.000132 | Elapsed Time: 4.68 seconds
# Epoch 43: Train Acc=83.81% | Val Acc=77.49% | Loss: 0.5063/0.7662 | Loss Ratio: 0.66 | LR: 0.000135 | Elapsed Time: 4.72 seconds
# Epoch 44: Train Acc=84.81% | Val Acc=82.47% | Loss: 0.5160/0.7723 | Loss Ratio: 0.67 | LR: 0.000139 | Elapsed Time: 4.76 seconds
# Epoch 45: Train Acc=86.73% | Val Acc=83.68% | Loss: 0.4983/0.6693 | Loss Ratio: 0.74 | LR: 0.000143 | Elapsed Time: 4.77 seconds
# Epoch 46: Train Acc=83.90% | Val Acc=74.40% | Loss: 0.5152/0.7410 | Loss Ratio: 0.70 | LR: 0.000147 | Elapsed Time: 4.63 seconds
# Epoch 47: Train Acc=86.26% | Val Acc=66.67% | Loss: 0.4959/0.8065 | Loss Ratio: 0.61 | LR: 0.000150 | Elapsed Time: 4.70 seconds
# Epoch 48: Train Acc=86.99% | Val Acc=70.62% | Loss: 0.4965/0.7969 | Loss Ratio: 0.62 | LR: 0.000154 | Elapsed Time: 4.66 seconds
# Epoch 49: Train Acc=86.39% | Val Acc=85.74% | Loss: 0.4965/0.5954 | Loss Ratio: 0.83 | LR: 0.000158 | Elapsed Time: 4.67 seconds
# Epoch 50: Train Acc=86.42% | Val Acc=76.80% | Loss: 0.4954/0.8076 | Loss Ratio: 0.61 | LR: 0.000163 | Elapsed Time: 4.73 seconds
#
# ========================================
#   PROCESSING SUBJECT: 14
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=46.57% | Val Acc=75.95% | Loss: 0.7767/0.7205 | Loss Ratio: 1.08 | LR: 0.000050 | Elapsed Time: 4.75 seconds [BEST ACC]
# Epoch 2: Train Acc=48.76% | Val Acc=24.05% | Loss: 0.7273/0.8338 | Loss Ratio: 0.87 | LR: 0.000050 | Elapsed Time: 4.71 seconds
# Epoch 3: Train Acc=61.33% | Val Acc=94.16% | Loss: 0.6891/0.5856 | Loss Ratio: 1.18 | LR: 0.000050 | Elapsed Time: 4.80 seconds [BEST ACC]
# Epoch 4: Train Acc=68.57% | Val Acc=64.26% | Loss: 0.6513/0.9943 | Loss Ratio: 0.65 | LR: 0.000051 | Elapsed Time: 4.71 seconds
# Epoch 5: Train Acc=66.23% | Val Acc=100.00% | Loss: 0.6567/0.4827 | Loss Ratio: 1.36 | LR: 0.000051 | Elapsed Time: 4.67 seconds [BEST ACC]
# Epoch 6: Train Acc=75.76% | Val Acc=98.63% | Loss: 0.5983/0.4659 | Loss Ratio: 1.28 | LR: 0.000052 | Elapsed Time: 4.66 seconds
# Epoch 7: Train Acc=75.56% | Val Acc=77.15% | Loss: 0.6095/0.6420 | Loss Ratio: 0.95 | LR: 0.000052 | Elapsed Time: 4.73 seconds
# Epoch 8: Train Acc=73.56% | Val Acc=77.15% | Loss: 0.6087/0.7204 | Loss Ratio: 0.84 | LR: 0.000053 | Elapsed Time: 4.70 seconds
# Epoch 9: Train Acc=76.98% | Val Acc=80.41% | Loss: 0.5756/0.6960 | Loss Ratio: 0.83 | LR: 0.000054 | Elapsed Time: 4.81 seconds
# Epoch 10: Train Acc=77.87% | Val Acc=78.35% | Loss: 0.5738/0.5962 | Loss Ratio: 0.96 | LR: 0.000055 | Elapsed Time: 4.65 seconds
# Epoch 11: Train Acc=82.41% | Val Acc=90.89% | Loss: 0.5359/0.5032 | Loss Ratio: 1.06 | LR: 0.000056 | Elapsed Time: 4.68 seconds
# Epoch 12: Train Acc=83.20% | Val Acc=90.89% | Loss: 0.5265/0.5076 | Loss Ratio: 1.04 | LR: 0.000057 | Elapsed Time: 4.75 seconds
# Epoch 13: Train Acc=80.36% | Val Acc=90.55% | Loss: 0.5484/0.4760 | Loss Ratio: 1.15 | LR: 0.000058 | Elapsed Time: 4.65 seconds
# Epoch 14: Train Acc=80.66% | Val Acc=80.93% | Loss: 0.5407/0.5677 | Loss Ratio: 0.95 | LR: 0.000060 | Elapsed Time: 4.79 seconds
# Epoch 15: Train Acc=84.16% | Val Acc=75.60% | Loss: 0.5195/0.6399 | Loss Ratio: 0.81 | LR: 0.000061 | Elapsed Time: 4.73 seconds
# Epoch 16: Train Acc=81.29% | Val Acc=76.29% | Loss: 0.5331/0.5601 | Loss Ratio: 0.95 | LR: 0.000063 | Elapsed Time: 4.75 seconds
# Epoch 17: Train Acc=82.90% | Val Acc=94.16% | Loss: 0.5211/0.5181 | Loss Ratio: 1.01 | LR: 0.000064 | Elapsed Time: 4.67 seconds
# Epoch 18: Train Acc=79.45% | Val Acc=85.05% | Loss: 0.5361/0.4896 | Loss Ratio: 1.09 | LR: 0.000066 | Elapsed Time: 4.76 seconds
# Epoch 19: Train Acc=85.45% | Val Acc=88.32% | Loss: 0.5135/0.4955 | Loss Ratio: 1.04 | LR: 0.000068 | Elapsed Time: 4.69 seconds
# Epoch 20: Train Acc=82.38% | Val Acc=83.33% | Loss: 0.5197/0.5755 | Loss Ratio: 0.90 | LR: 0.000069 | Elapsed Time: 4.85 seconds
# Epoch 21: Train Acc=82.24% | Val Acc=84.19% | Loss: 0.5265/0.5569 | Loss Ratio: 0.95 | LR: 0.000071 | Elapsed Time: 4.69 seconds
# Epoch 22: Train Acc=81.17% | Val Acc=84.19% | Loss: 0.5223/0.5728 | Loss Ratio: 0.91 | LR: 0.000073 | Elapsed Time: 4.73 seconds
# Epoch 23: Train Acc=77.01% | Val Acc=87.63% | Loss: 0.5685/0.5357 | Loss Ratio: 1.06 | LR: 0.000076 | Elapsed Time: 4.75 seconds
# Epoch 24: Train Acc=85.26% | Val Acc=81.79% | Loss: 0.4965/0.5171 | Loss Ratio: 0.96 | LR: 0.000078 | Elapsed Time: 4.71 seconds
# Epoch 25: Train Acc=86.77% | Val Acc=74.57% | Loss: 0.4782/0.5869 | Loss Ratio: 0.81 | LR: 0.000080 | Elapsed Time: 4.69 seconds
# Epoch 26: Train Acc=82.57% | Val Acc=94.16% | Loss: 0.5208/0.5153 | Loss Ratio: 1.01 | LR: 0.000083 | Elapsed Time: 4.79 seconds
# Epoch 27: Train Acc=85.49% | Val Acc=60.31% | Loss: 0.5152/0.8006 | Loss Ratio: 0.64 | LR: 0.000085 | Elapsed Time: 4.70 seconds
# Epoch 28: Train Acc=79.61% | Val Acc=80.93% | Loss: 0.5375/0.5858 | Loss Ratio: 0.92 | LR: 0.000088 | Elapsed Time: 4.70 seconds
# Epoch 29: Train Acc=85.99% | Val Acc=90.89% | Loss: 0.4952/0.5050 | Loss Ratio: 0.98 | LR: 0.000090 | Elapsed Time: 4.72 seconds
#
# ========================================
#   PROCESSING SUBJECT: 15
# ========================================
# Total Unique Videos (Across 3 Sessions): 72
# Training on: 57 | Testing on: 15
# [0.6267927  2.47172237]
# Epoch 1: Train Acc=54.21% | Val Acc=75.26% | Loss: 0.7763/0.7162 | Loss Ratio: 1.08 | LR: 0.000050 | Elapsed Time: 4.61 seconds [BEST ACC]
# Epoch 2: Train Acc=74.04% | Val Acc=61.68% | Loss: 0.5949/0.7354 | Loss Ratio: 0.81 | LR: 0.000050 | Elapsed Time: 4.72 seconds
# Epoch 3: Train Acc=82.39% | Val Acc=74.05% | Loss: 0.5264/0.5768 | Loss Ratio: 0.91 | LR: 0.000050 | Elapsed Time: 4.73 seconds
# Epoch 4: Train Acc=79.39% | Val Acc=100.00% | Loss: 0.5597/0.4544 | Loss Ratio: 1.23 | LR: 0.000051 | Elapsed Time: 4.73 seconds [BEST ACC]
# Epoch 5: Train Acc=82.08% | Val Acc=100.00% | Loss: 0.5394/0.4588 | Loss Ratio: 1.18 | LR: 0.000051 | Elapsed Time: 4.75 seconds [BEST ACC]
# Epoch 6: Train Acc=85.64% | Val Acc=90.55% | Loss: 0.5088/0.4685 | Loss Ratio: 1.09 | LR: 0.000052 | Elapsed Time: 4.76 seconds
# Epoch 7: Train Acc=83.05% | Val Acc=82.99% | Loss: 0.5278/0.5477 | Loss Ratio: 0.96 | LR: 0.000052 | Elapsed Time: 4.81 seconds
# Epoch 8: Train Acc=83.93% | Val Acc=85.74% | Loss: 0.5150/0.5026 | Loss Ratio: 1.02 | LR: 0.000053 | Elapsed Time: 4.71 seconds
# Epoch 9: Train Acc=86.34% | Val Acc=100.00% | Loss: 0.4975/0.4451 | Loss Ratio: 1.12 | LR: 0.000054 | Elapsed Time: 4.68 seconds [BEST ACC]
# Epoch 10: Train Acc=86.02% | Val Acc=90.55% | Loss: 0.5020/0.5012 | Loss Ratio: 1.00 | LR: 0.000055 | Elapsed Time: 4.71 seconds
# Epoch 11: Train Acc=86.41% | Val Acc=78.87% | Loss: 0.4896/0.5629 | Loss Ratio: 0.87 | LR: 0.000056 | Elapsed Time: 4.76 seconds
# Epoch 12: Train Acc=85.54% | Val Acc=100.00% | Loss: 0.5041/0.4502 | Loss Ratio: 1.12 | LR: 0.000057 | Elapsed Time: 4.66 seconds
# Epoch 13: Train Acc=85.10% | Val Acc=90.55% | Loss: 0.5128/0.4591 | Loss Ratio: 1.12 | LR: 0.000058 | Elapsed Time: 4.67 seconds
# Epoch 14: Train Acc=87.89% | Val Acc=92.27% | Loss: 0.4771/0.4330 | Loss Ratio: 1.10 | LR: 0.000060 | Elapsed Time: 4.63 seconds
# Epoch 15: Train Acc=86.53% | Val Acc=85.74% | Loss: 0.4934/0.4661 | Loss Ratio: 1.06 | LR: 0.000061 | Elapsed Time: 4.71 seconds
# Epoch 16: Train Acc=83.61% | Val Acc=85.74% | Loss: 0.5272/0.4632 | Loss Ratio: 1.14 | LR: 0.000063 | Elapsed Time: 4.72 seconds
# Epoch 17: Train Acc=86.56% | Val Acc=93.81% | Loss: 0.4948/0.4420 | Loss Ratio: 1.12 | LR: 0.000064 | Elapsed Time: 4.71 seconds
# Epoch 18: Train Acc=86.83% | Val Acc=85.74% | Loss: 0.4866/0.4673 | Loss Ratio: 1.04 | LR: 0.000066 | Elapsed Time: 4.64 seconds
# Epoch 19: Train Acc=87.44% | Val Acc=94.67% | Loss: 0.4819/0.4391 | Loss Ratio: 1.10 | LR: 0.000068 | Elapsed Time: 4.70 seconds
# Epoch 20: Train Acc=87.03% | Val Acc=86.60% | Loss: 0.5026/0.4847 | Loss Ratio: 1.04 | LR: 0.000069 | Elapsed Time: 4.67 seconds
# Epoch 21: Train Acc=88.76% | Val Acc=87.46% | Loss: 0.4808/0.4700 | Loss Ratio: 1.02 | LR: 0.000071 | Elapsed Time: 4.70 seconds
# Epoch 22: Train Acc=88.51% | Val Acc=100.00% | Loss: 0.4708/0.4342 | Loss Ratio: 1.08 | LR: 0.000073 | Elapsed Time: 4.74 seconds [BEST ACC]
# Epoch 23: Train Acc=88.67% | Val Acc=95.19% | Loss: 0.4747/0.4454 | Loss Ratio: 1.07 | LR: 0.000076 | Elapsed Time: 4.65 seconds
# Epoch 24: Train Acc=85.94% | Val Acc=85.74% | Loss: 0.5063/0.4689 | Loss Ratio: 1.08 | LR: 0.000078 | Elapsed Time: 4.76 seconds
# Epoch 25: Train Acc=87.33% | Val Acc=85.74% | Loss: 0.4823/0.5240 | Loss Ratio: 0.92 | LR: 0.000080 | Elapsed Time: 4.66 seconds
# Epoch 26: Train Acc=88.12% | Val Acc=90.55% | Loss: 0.4780/0.4539 | Loss Ratio: 1.05 | LR: 0.000083 | Elapsed Time: 4.68 seconds
# Epoch 27: Train Acc=87.11% | Val Acc=91.07% | Loss: 0.4864/0.4688 | Loss Ratio: 1.04 | LR: 0.000085 | Elapsed Time: 4.68 seconds
# Epoch 28: Train Acc=88.46% | Val Acc=85.74% | Loss: 0.4787/0.4763 | Loss Ratio: 1.01 | LR: 0.000088 | Elapsed Time: 4.67 seconds
# Epoch 29: Train Acc=87.92% | Val Acc=85.22% | Loss: 0.4945/0.5957 | Loss Ratio: 0.83 | LR: 0.000090 | Elapsed Time: 4.65 seconds
# Epoch 30: Train Acc=88.26% | Val Acc=99.31% | Loss: 0.4764/0.4343 | Loss Ratio: 1.10 | LR: 0.000093 | Elapsed Time: 4.74 seconds
# Epoch 31: Train Acc=87.70% | Val Acc=100.00% | Loss: 0.4893/0.4349 | Loss Ratio: 1.13 | LR: 0.000096 | Elapsed Time: 4.62 seconds
# Epoch 32: Train Acc=88.39% | Val Acc=95.19% | Loss: 0.4791/0.4388 | Loss Ratio: 1.09 | LR: 0.000099 | Elapsed Time: 4.69 seconds
# Epoch 33: Train Acc=86.93% | Val Acc=85.74% | Loss: 0.4806/0.4756 | Loss Ratio: 1.01 | LR: 0.000102 | Elapsed Time: 4.73 seconds
# Epoch 34: Train Acc=89.55% | Val Acc=85.74% | Loss: 0.4668/0.5297 | Loss Ratio: 0.88 | LR: 0.000105 | Elapsed Time: 4.68 seconds
# Epoch 35: Train Acc=87.93% | Val Acc=89.86% | Loss: 0.4765/0.4637 | Loss Ratio: 1.03 | LR: 0.000108 | Elapsed Time: 4.64 seconds
# Epoch 36: Train Acc=87.01% | Val Acc=90.55% | Loss: 0.4843/0.4848 | Loss Ratio: 1.00 | LR: 0.000111 | Elapsed Time: 4.66 seconds
# Epoch 37: Train Acc=85.90% | Val Acc=85.74% | Loss: 0.4991/0.4957 | Loss Ratio: 1.01 | LR: 0.000114 | Elapsed Time: 4.82 seconds
# Epoch 38: Train Acc=86.33% | Val Acc=96.39% | Loss: 0.4961/0.4408 | Loss Ratio: 1.13 | LR: 0.000118 | Elapsed Time: 4.73 seconds
# Epoch 39: Train Acc=88.69% | Val Acc=100.00% | Loss: 0.4838/0.4257 | Loss Ratio: 1.14 | LR: 0.000121 | Elapsed Time: 4.86 seconds [BEST ACC]
# Epoch 40: Train Acc=86.80% | Val Acc=76.80% | Loss: 0.4972/0.5614 | Loss Ratio: 0.89 | LR: 0.000124 | Elapsed Time: 4.74 seconds
# Epoch 41: Train Acc=89.51% | Val Acc=95.19% | Loss: 0.4656/0.4382 | Loss Ratio: 1.06 | LR: 0.000128 | Elapsed Time: 4.70 seconds
# Epoch 42: Train Acc=85.18% | Val Acc=95.19% | Loss: 0.5095/0.4826 | Loss Ratio: 1.06 | LR: 0.000132 | Elapsed Time: 4.77 seconds
# Epoch 43: Train Acc=86.10% | Val Acc=95.19% | Loss: 0.4923/0.4622 | Loss Ratio: 1.06 | LR: 0.000135 | Elapsed Time: 4.70 seconds
# Epoch 44: Train Acc=86.28% | Val Acc=86.43% | Loss: 0.4793/0.4839 | Loss Ratio: 0.99 | LR: 0.000139 | Elapsed Time: 4.71 seconds
# Epoch 45: Train Acc=88.26% | Val Acc=78.69% | Loss: 0.4698/0.5410 | Loss Ratio: 0.87 | LR: 0.000143 | Elapsed Time: 4.79 seconds
# Epoch 46: Train Acc=85.10% | Val Acc=93.13% | Loss: 0.5097/0.4507 | Loss Ratio: 1.13 | LR: 0.000147 | Elapsed Time: 4.73 seconds
# Epoch 47: Train Acc=86.98% | Val Acc=85.74% | Loss: 0.4850/0.4985 | Loss Ratio: 0.97 | LR: 0.000150 | Elapsed Time: 4.71 seconds
# Epoch 48: Train Acc=86.39% | Val Acc=98.11% | Loss: 0.4927/0.4348 | Loss Ratio: 1.13 | LR: 0.000154 | Elapsed Time: 4.69 seconds
# Epoch 49: Train Acc=87.28% | Val Acc=76.80% | Loss: 0.4763/0.5802 | Loss Ratio: 0.82 | LR: 0.000158 | Elapsed Time: 4.79 seconds
# Epoch 50: Train Acc=87.47% | Val Acc=77.32% | Loss: 0.4838/0.6985 | Loss Ratio: 0.69 | LR: 0.000163 | Elapsed Time: 4.69 seconds
# Epoch 51: Train Acc=87.34% | Val Acc=95.19% | Loss: 0.5025/0.5002 | Loss Ratio: 1.00 | LR: 0.000167 | Elapsed Time: 4.77 seconds
# Epoch 52: Train Acc=88.18% | Val Acc=80.07% | Loss: 0.4816/0.5598 | Loss Ratio: 0.86 | LR: 0.000171 | Elapsed Time: 4.68 seconds
# Epoch 53: Train Acc=89.71% | Val Acc=68.90% | Loss: 0.4690/0.6880 | Loss Ratio: 0.68 | LR: 0.000175 | Elapsed Time: 4.73 seconds
# Epoch 54: Train Acc=87.73% | Val Acc=85.74% | Loss: 0.4807/0.5076 | Loss Ratio: 0.95 | LR: 0.000179 | Elapsed Time: 4.80 seconds
# Epoch 55: Train Acc=86.74% | Val Acc=85.74% | Loss: 0.4847/0.5049 | Loss Ratio: 0.96 | LR: 0.000183 | Elapsed Time: 4.69 seconds
# Epoch 56: Train Acc=87.09% | Val Acc=80.07% | Loss: 0.4773/0.5155 | Loss Ratio: 0.93 | LR: 0.000188 | Elapsed Time: 4.64 seconds
# Epoch 57: Train Acc=89.12% | Val Acc=76.80% | Loss: 0.4598/0.5920 | Loss Ratio: 0.78 | LR: 0.000192 | Elapsed Time: 4.70 seconds
# Epoch 58: Train Acc=87.72% | Val Acc=85.74% | Loss: 0.4759/0.4667 | Loss Ratio: 1.02 | LR: 0.000197 | Elapsed Time: 4.67 seconds
# Epoch 59: Train Acc=88.29% | Val Acc=90.55% | Loss: 0.4733/0.4648 | Loss Ratio: 1.02 | LR: 0.000201 | Elapsed Time: 4.55 seconds
# Epoch 60: Train Acc=90.06% | Val Acc=70.79% | Loss: 0.4574/0.6633 | Loss Ratio: 0.69 | LR: 0.000205 | Elapsed Time: 4.64 seconds
# Epoch 61: Train Acc=88.40% | Val Acc=93.47% | Loss: 0.4723/0.4805 | Loss Ratio: 0.98 | LR: 0.000210 | Elapsed Time: 4.66 seconds
# Epoch 62: Train Acc=86.56% | Val Acc=100.00% | Loss: 0.4819/0.4394 | Loss Ratio: 1.10 | LR: 0.000215 | Elapsed Time: 4.61 seconds
# Epoch 63: Train Acc=86.97% | Val Acc=85.74% | Loss: 0.4879/0.4960 | Loss Ratio: 0.98 | LR: 0.000219 | Elapsed Time: 4.58 seconds

# %%
# --- FINAL RESULTS ---
avg_acc = sum(all_subject_accuracies) / len(all_subject_accuracies)
print(f"\n========================================")
print(f"FINAL AVERAGE ACCURACY: {avg_acc:.2f}%")
print(f"Detailed: {all_subject_accuracies}")
print(f"========================================")
# Out:
# ========================================
# FINAL AVERAGE ACCURACY: 94.86%
# Detailed: [86.76975945017182, 100.0, 95.87628865979381, 92.78350515463917, 100.0, 100.0, 100.0, 100.0, 96.73539518900344, 100.0, 88.31615120274914, 75.94501718213058, 86.42611683848797, 100.0, 100.0]
# ========================================

# %%
# --- PLOTTING ---
# 1. 5x3 Grid for individual subjects
fig, axes = plt.subplots(5, 3, figsize=(20, 15))
axes = axes.flatten()

for i, subject_id in enumerate(subjects):
    if i < len(axes):
        ax = axes[i]
        if subject_id in all_subject_histories:
            h = all_subject_histories[subject_id]
            ax.plot(h["train"], label="Train Acc")
            ax.plot(h["val"], label="Val Acc")
            ax.set_title(f"Subject {subject_id}")
            ax.set_xlabel("Epoch")
            ax.set_ylabel("Accuracy (%)")
            ax.legend()
            ax.grid(True)

plt.tight_layout()
plt.savefig("subject_accuracies.png")
print("Saved subject_accuracies.png")
plt.show()
# Out:
# Saved subject_accuracies.png

# %%
# 2. Average Plot
plt.figure(figsize=(10, 6))

# Find max epochs across all runs
max_epochs = 0
for h in all_subject_histories.values():
    max_epochs = max(max_epochs, len(h["train"]))

avg_train = []
avg_val = []

for e in range(max_epochs):
    t_vals = []
    v_vals = []
    for h in all_subject_histories.values():
        # Use last value if a subject finished early
        idx = min(e, len(h["train"]) - 1)
        t_vals.append(h["train"][idx])
        v_vals.append(h["val"][idx])

    avg_train.append(np.mean(t_vals))
    avg_val.append(np.mean(v_vals))

plt.plot(avg_train, label="Average Train Acc", linewidth=2)
plt.plot(avg_val, label="Average Val Acc", linewidth=2)
plt.title("Average Accuracy Across All Subjects")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True)
plt.savefig("average_accuracy.png")
print("Saved average_accuracy.png")
plt.show()
# Out:
# Saved average_accuracy.png
